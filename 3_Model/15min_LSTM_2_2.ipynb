# %% [markdown]
# ## Explanations below

# %% [markdown]
# This next code block dills the sailing folder with fake files (engine files), to check sanity of model construct.

# %%
import os
import shutil
import pandas as pd
import random

# Define the source and destination folders
source_folder = '../5_Data_Pipeline/time_sets_st_shortened'
destination_folder = '../5_Data_Pipeline/input/underway_using_engine'

# Ensure destination folder exists
os.makedirs(destination_folder, exist_ok=True)

# List to hold the files that meet the condition
valid_files = []

# Iterate over each file in the source folder
for filename in os.listdir(source_folder):
    # Check if the file is a CSV file
    if filename.endswith('.csv'):
        file_path = os.path.join(source_folder, filename)
        
        # Try to read the CSV file
        try:
            df = pd.read_csv(file_path)

            # Check if 'Navigational status' column exists and contains the value 'Under way sailing'
            if 'Navigational status' in df.columns and 'Under way using engine' in df['Navigational status'].values:
                # If the condition is met, add the file to the list
                valid_files.append(file_path)
        except Exception as e:
            print(f"Could not process {filename}: {e}")

# Randomly select up to 1000 files from the valid files
files_to_move = random.sample(valid_files, min(1000, len(valid_files)))

# Move the selected files to the destination folder
for file_path in files_to_move:
    filename = os.path.basename(file_path)
    shutil.move(file_path, os.path.join(destination_folder, filename))
    print(f"Moved: {filename}")

print("Script execution completed.")
# Out:
# Moved: filtered_219370000_20240604_0239-20240604_0254_standardized_10s.csv
# Moved: filtered_219017733_20240522_2049-20240522_2104_standardized_10s.csv
# Moved: filtered_255806463_20240426_2235-20240426_2250_standardized_10s.csv
# Moved: filtered_305509000_20240417_2053-20240417_2108_standardized_10s.csv
# Moved: filtered_230138350_20240330_1307-20240330_1321_standardized_10s.csv
# Moved: filtered_265177000_20240630_2040-20240630_2055_standardized_10s.csv
# Moved: filtered_209415000_20240326_1647-20240326_1702_standardized_10s.csv
# Moved: filtered_211302790_20240306_2047-20240306_2102_standardized_10s.csv
# Moved: filtered_219021321_20240416_1239-20240416_1254_standardized_10s.csv
# Moved: filtered_352003251_20240426_0742-20240426_0757_standardized_10s.csv
# Moved: filtered_518998637_20240406_1132-20240406_1147_standardized_10s.csv
# Moved: filtered_265410000_20240326_0415-20240326_0429_standardized_10s.csv
# Moved: filtered_220368000_20240526_1032-20240526_1047_standardized_10s.csv
# Moved: filtered_257588000_20240627_2347-20240628_0002_standardized_10s.csv
# Moved: filtered_626408000_20240324_1914-20240324_1929_standardized_10s.csv
# Moved: filtered_257069560_20240323_0357-20240323_0411_standardized_10s.csv
# Moved: filtered_477735800_20240320_2112-20240320_2127_standardized_10s.csv
# Moved: filtered_518998825_20240527_0557-20240527_0612_standardized_10s.csv
# Moved: filtered_220614000_20240520_0846-20240520_0900_standardized_10s.csv
# Moved: filtered_232023509_20240604_0720-20240604_0735_standardized_10s.csv
# Moved: filtered_258849000_20240613_2126-20240613_2140_standardized_10s.csv
# Moved: filtered_265781000_20240424_2115-20240424_2130_standardized_10s.csv
# Moved: filtered_219449000_20240525_1915-20240525_1930_standardized_10s.csv
# Moved: filtered_636022047_20240607_2317-20240607_2332_standardized_10s.csv
# Moved: filtered_257962000_20240605_2138-20240605_2153_standardized_10s.csv
# Moved: filtered_266076000_20240409_1115-20240409_1130_standardized_10s.csv
# Moved: filtered_273396130_20240626_1434-20240626_1449_standardized_10s.csv
# Moved: filtered_211302930_20240430_0722-20240430_0737_standardized_10s.csv
# Moved: filtered_563221100_20240625_0433-20240625_0448_standardized_10s.csv
# Moved: filtered_538008878_20240314_2028-20240314_2043_standardized_10s.csv
# Moved: filtered_256220000_20240411_0316-20240411_0331_standardized_10s.csv
# Moved: filtered_244059000_20240430_0558-20240430_0613_standardized_10s.csv
# Moved: filtered_229767000_20240521_1552-20240521_1607_standardized_10s.csv
# Moved: filtered_229077000_20240314_0336-20240314_0351_standardized_10s.csv
# Moved: filtered_255962000_20240315_1246-20240315_1301_standardized_10s.csv
# Moved: filtered_245302000_20240324_0226-20240324_0241_standardized_10s.csv
# Moved: filtered_636021135_20240419_1525-20240419_1540_standardized_10s.csv
# Moved: filtered_232031538_20240425_1043-20240425_1058_standardized_10s.csv
# Moved: filtered_636019971_20240528_0810-20240528_0825_standardized_10s.csv
# Moved: filtered_218816000_20241126_0958-20241126_1013_standardized_10s.csv
# Moved: filtered_304688000_20240325_1501-20240325_1516_standardized_10s.csv
# Moved: filtered_538010460_20241127_2355-20241128_0010_standardized_10s.csv
# Moved: filtered_219022257_20240627_2346-20240628_0000_standardized_10s.csv
# Moved: filtered_257031080_20240301_2221-20240301_2235_standardized_10s.csv
# Moved: filtered_235103057_20240530_0904-20240530_0919_standardized_10s.csv
# Moved: filtered_636016293_20240606_0656-20240606_0711_standardized_10s.csv
# Moved: filtered_314609000_20240307_1456-20240307_1510_standardized_10s.csv
# Moved: filtered_219019936_20240320_0838-20240320_0853_standardized_10s.csv
# Moved: filtered_255806522_20240523_2349-20240524_0004_standardized_10s.csv
# Moved: filtered_255806329_20240610_0946-20240610_1001_standardized_10s.csv
# Moved: filtered_232974000_20240409_2013-20240409_2028_standardized_10s.csv
# Moved: filtered_229077000_20240425_1800-20240425_1815_standardized_10s.csv
# Moved: filtered_219021321_20240621_0252-20240621_0307_standardized_10s.csv
# Moved: filtered_212018000_20240311_2334-20240311_2349_standardized_10s.csv
# Moved: filtered_538008213_20240414_0215-20240414_0230_standardized_10s.csv
# Moved: filtered_636093200_20240622_0553-20240622_0608_standardized_10s.csv
# Moved: filtered_219007477_20240331_0428-20240331_0443_standardized_10s.csv
# Moved: filtered_235102532_20240326_1526-20240326_1541_standardized_10s.csv
# Moved: filtered_246497000_20240601_2018-20240601_2033_standardized_10s.csv
# Moved: filtered_257754000_20240528_1002-20240528_1017_standardized_10s.csv
# Moved: filtered_563706000_20240331_1559-20240331_1614_standardized_10s.csv
# Moved: filtered_244790608_20240604_2245-20240604_2300_standardized_10s.csv
# Moved: filtered_354537000_20240525_0318-20240525_0333_standardized_10s.csv
# Moved: filtered_636016149_20240305_0208-20240305_0223_standardized_10s.csv
# Moved: filtered_538090667_20241129_1923-20241129_1938_standardized_10s.csv
# Moved: filtered_219028337_20240328_1503-20240328_1518_standardized_10s.csv
# Moved: filtered_219616000_20240529_0916-20240529_0931_standardized_10s.csv
# Moved: filtered_266158000_20240422_1550-20240422_1605_standardized_10s.csv
# Moved: filtered_319060600_20240325_1819-20240325_1834_standardized_10s.csv
# Moved: filtered_230707000_20240303_0140-20240303_0155_standardized_10s.csv
# Moved: filtered_257086660_20240324_1212-20240324_1227_standardized_10s.csv
# Moved: filtered_220018000_20241122_0911-20241122_0926_standardized_10s.csv
# Moved: filtered_257086660_20240423_1551-20240423_1605_standardized_10s.csv
# Moved: filtered_304244000_20240606_1821-20240606_1836_standardized_10s.csv
# Moved: filtered_538007532_20240317_1539-20240317_1553_standardized_10s.csv
# Moved: filtered_232025009_20240326_0831-20240326_0846_standardized_10s.csv
# Moved: filtered_247290000_20240529_1414-20240529_1429_standardized_10s.csv
# Moved: filtered_244090224_20240627_0003-20240627_0017_standardized_10s.csv
# Moved: filtered_257998000_20240414_0632-20240414_0647_standardized_10s.csv
# Moved: filtered_255801580_20240324_2317-20240324_2332_standardized_10s.csv
# Moved: filtered_219244000_20240314_0546-20240314_0601_standardized_10s.csv
# Moved: filtered_273617460_20240311_0937-20240311_0952_standardized_10s.csv
# Moved: filtered_538007841_20240627_1712-20240627_1727_standardized_10s.csv
# Moved: filtered_244059000_20240626_2150-20240626_2205_standardized_10s.csv
# Moved: filtered_230007000_20240629_0151-20240629_0206_standardized_10s.csv
# Moved: filtered_229807000_20240329_0146-20240329_0201_standardized_10s.csv
# Moved: filtered_538006140_20240606_1637-20240606_1652_standardized_10s.csv
# Moved: filtered_259222000_20240404_1905-20240404_1920_standardized_10s.csv
# Moved: filtered_231355000_20241122_2148-20241122_2203_standardized_10s.csv
# Moved: filtered_232023509_20240521_0837-20240521_0852_standardized_10s.csv
# Moved: filtered_304932000_20240609_0431-20240609_0446_standardized_10s.csv
# Moved: filtered_309924000_20240421_1632-20240421_1647_standardized_10s.csv
# Moved: filtered_255805754_20240530_1118-20240530_1133_standardized_10s.csv
# Moved: filtered_219614000_20241125_0210-20241125_0225_standardized_10s.csv
# Moved: filtered_354711000_20240617_0544-20240617_0558_standardized_10s.csv
# Moved: filtered_266459000_20240430_0302-20240430_0316_standardized_10s.csv
# Moved: filtered_218321000_20240311_0908-20240311_0923_standardized_10s.csv
# Moved: filtered_220253000_20240303_1222-20240303_1237_standardized_10s.csv
# Moved: filtered_374308000_20240527_1745-20240527_1800_standardized_10s.csv
# Moved: filtered_245097000_20240415_0156-20240415_0211_standardized_10s.csv
# Moved: filtered_257084390_20240320_1637-20240320_1652_standardized_10s.csv
# Moved: filtered_311027700_20240615_1347-20240615_1401_standardized_10s.csv
# Moved: filtered_231803000_20241129_1943-20241129_1957_standardized_10s.csv
# Moved: filtered_256380000_20240425_0849-20240425_0904_standardized_10s.csv
# Moved: filtered_209008000_20240609_2212-20240609_2227_standardized_10s.csv
# Moved: filtered_538010263_20240531_2121-20240531_2135_standardized_10s.csv
# Moved: filtered_305102000_20240519_1852-20240519_1907_standardized_10s.csv
# Moved: filtered_244870072_20240321_1213-20240321_1228_standardized_10s.csv
# Moved: filtered_256281000_20240524_1600-20240524_1615_standardized_10s.csv
# Moved: filtered_219370000_20240322_0230-20240322_0245_standardized_10s.csv
# Moved: filtered_257086660_20240405_0251-20240405_0306_standardized_10s.csv
# Moved: filtered_220446000_20240304_1316-20240304_1331_standardized_10s.csv
# Moved: filtered_305502000_20240608_2340-20240608_2355_standardized_10s.csv
# Moved: filtered_636022047_20240408_0210-20240408_0225_standardized_10s.csv
# Moved: filtered_620999376_20240323_0246-20240323_0301_standardized_10s.csv
# Moved: filtered_249547000_20240430_1530-20240430_1545_standardized_10s.csv
# Moved: filtered_566090000_20240307_0405-20240307_0420_standardized_10s.csv
# Moved: filtered_314586000_20240607_1845-20240607_1900_standardized_10s.csv
# Moved: filtered_255801580_20240625_0445-20240625_0459_standardized_10s.csv
# Moved: filtered_220307000_20240328_0127-20240328_0141_standardized_10s.csv
# Moved: filtered_636021117_20240404_0125-20240404_0140_standardized_10s.csv
# Moved: filtered_636019890_20240620_0102-20240620_0117_standardized_10s.csv
# Moved: filtered_636022047_20240307_0059-20240307_0114_standardized_10s.csv
# Moved: filtered_265022000_20240608_1925-20240608_1940_standardized_10s.csv
# Moved: filtered_219022257_20240303_1631-20240303_1646_standardized_10s.csv
# Moved: filtered_311995000_20241125_1205-20241125_1220_standardized_10s.csv
# Moved: filtered_311307000_20240615_1621-20240615_1636_standardized_10s.csv
# Moved: filtered_246436000_20240626_0207-20240626_0222_standardized_10s.csv
# Moved: filtered_232023509_20240623_1150-20240623_1205_standardized_10s.csv
# Moved: filtered_219002827_20240628_0215-20240628_0229_standardized_10s.csv
# Moved: filtered_229131000_20240526_1639-20240526_1654_standardized_10s.csv
# Moved: filtered_219031237_20240321_0646-20240321_0701_standardized_10s.csv
# Moved: filtered_219309000_20240419_1505-20240419_1519_standardized_10s.csv
# Moved: filtered_230007000_20240527_2112-20240527_2127_standardized_10s.csv
# Moved: filtered_258407000_20240322_1343-20240322_1358_standardized_10s.csv
# Moved: filtered_538010371_20240617_0645-20240617_0700_standardized_10s.csv
# Moved: filtered_219027298_20240326_1001-20240326_1016_standardized_10s.csv
# Moved: filtered_314238000_20240612_0857-20240612_0912_standardized_10s.csv
# Moved: filtered_219166000_20240522_1711-20240522_1726_standardized_10s.csv
# Moved: filtered_211141000_20240302_2017-20240302_2032_standardized_10s.csv
# Moved: filtered_255801580_20241124_0227-20241124_0242_standardized_10s.csv
# Moved: filtered_220464000_20240606_0351-20240606_0406_standardized_10s.csv
# Moved: filtered_219435000_20240301_0504-20240301_0519_standardized_10s.csv
# Moved: filtered_255924000_20240425_0427-20240425_0441_standardized_10s.csv
# Moved: filtered_220177000_20240324_0307-20240324_0322_standardized_10s.csv
# Moved: filtered_219002827_20240415_0433-20240415_0448_standardized_10s.csv
# Moved: filtered_220600000_20240530_2323-20240530_2338_standardized_10s.csv
# Moved: filtered_235102532_20240302_0741-20240302_0756_standardized_10s.csv
# Moved: filtered_266436000_20240313_1203-20240313_1218_standardized_10s.csv
# Moved: filtered_636023031_20240408_1327-20240408_1342_standardized_10s.csv
# Moved: filtered_266467000_20240425_1136-20240425_1151_standardized_10s.csv
# Moved: filtered_211234480_20240317_1315-20240317_1330_standardized_10s.csv
# Moved: filtered_236652000_20240321_2317-20240321_2332_standardized_10s.csv
# Moved: filtered_265410000_20240328_1630-20240328_1644_standardized_10s.csv
# Moved: filtered_232040897_20240326_2102-20240326_2117_standardized_10s.csv
# Moved: filtered_220600000_20240605_1552-20240605_1607_standardized_10s.csv
# Moved: filtered_235108529_20240306_1608-20240306_1623_standardized_10s.csv
# Moved: filtered_305509000_20240304_2324-20240304_2339_standardized_10s.csv
# Moved: filtered_255806300_20240326_0810-20240326_0825_standardized_10s.csv
# Moved: filtered_354711000_20240630_2144-20240630_2159_standardized_10s.csv
# Moved: filtered_372002000_20240621_1115-20240621_1130_standardized_10s.csv
# Moved: filtered_256800000_20240603_1324-20240603_1339_standardized_10s.csv
# Moved: filtered_319130500_20240416_0410-20240416_0425_standardized_10s.csv
# Moved: filtered_314207000_20240603_0032-20240603_0047_standardized_10s.csv
# Moved: filtered_352002488_20240519_2028-20240519_2043_standardized_10s.csv
# Moved: filtered_219023786_20240617_2207-20240617_2222_standardized_10s.csv
# Moved: filtered_219437000_20241122_1838-20241122_1853_standardized_10s.csv
# Moved: filtered_219019936_20240520_0742-20240520_0757_standardized_10s.csv
# Moved: filtered_258763000_20240606_1106-20240606_1121_standardized_10s.csv
# Moved: filtered_566679000_20240629_1956-20240629_2011_standardized_10s.csv
# Moved: filtered_244178000_20240305_1506-20240305_1521_standardized_10s.csv
# Moved: filtered_219022580_20240525_2021-20240525_2036_standardized_10s.csv
# Moved: filtered_244103000_20240327_0826-20240327_0841_standardized_10s.csv
# Moved: filtered_211141000_20240528_2318-20240528_2333_standardized_10s.csv
# Moved: filtered_219010873_20240530_2108-20240530_2123_standardized_10s.csv
# Moved: filtered_211219630_20240627_1235-20240627_1250_standardized_10s.csv
# Moved: filtered_538009362_20240327_0235-20240327_0250_standardized_10s.csv
# Moved: filtered_354711000_20240408_0341-20240408_0356_standardized_10s.csv
# Moved: filtered_255806320_20240424_0441-20240424_0456_standardized_10s.csv
# Moved: filtered_235102532_20240312_0556-20240312_0611_standardized_10s.csv
# Moved: filtered_215114000_20240610_0201-20240610_0216_standardized_10s.csv
# Moved: filtered_304577000_20240331_0619-20240331_0634_standardized_10s.csv
# Moved: filtered_578001700_20241122_0015-20241122_0030_standardized_10s.csv
# Moved: filtered_266076000_20240311_1403-20240311_1418_standardized_10s.csv
# Moved: filtered_636017156_20240616_1343-20240616_1358_standardized_10s.csv
# Moved: filtered_219017733_20240425_1145-20240425_1200_standardized_10s.csv
# Moved: filtered_244103000_20240313_0711-20240313_0726_standardized_10s.csv
# Moved: filtered_232025009_20240310_0546-20240310_0601_standardized_10s.csv
# Moved: filtered_229077000_20240421_1930-20240421_1945_standardized_10s.csv
# Moved: filtered_373834000_20240423_0711-20240423_0725_standardized_10s.csv
# Moved: filtered_219596000_20240522_2140-20240522_2155_standardized_10s.csv
# Moved: filtered_538007668_20240614_1457-20240614_1511_standardized_10s.csv
# Moved: filtered_220368000_20240312_1017-20240312_1032_standardized_10s.csv
# Moved: filtered_255806507_20240621_0721-20240621_0736_standardized_10s.csv
# Moved: filtered_219592000_20240312_0000-20240312_0014_standardized_10s.csv
# Moved: filtered_311001025_20240323_0401-20240323_0416_standardized_10s.csv
# Moved: filtered_257861000_20241130_1348-20241130_1403_standardized_10s.csv
# Moved: filtered_255806444_20240316_0859-20240316_0914_standardized_10s.csv
# Moved: filtered_244830818_20240620_0733-20240620_0748_standardized_10s.csv
# Moved: filtered_255806196_20240619_1504-20240619_1519_standardized_10s.csv
# Moved: filtered_229025000_20240303_1810-20240303_1825_standardized_10s.csv
# Moved: filtered_304688000_20240408_0200-20240408_0215_standardized_10s.csv
# Moved: filtered_219825000_20241122_1525-20241122_1539_standardized_10s.csv
# Moved: filtered_630001042_20240623_0841-20240623_0855_standardized_10s.csv
# Moved: filtered_305210000_20240422_1109-20240422_1124_standardized_10s.csv
# Moved: filtered_246630000_20240429_1514-20240429_1529_standardized_10s.csv
# Moved: filtered_244010871_20240416_2337-20240416_2352_standardized_10s.csv
# Moved: filtered_249547000_20240430_1615-20240430_1630_standardized_10s.csv
# Moved: filtered_370236000_20240324_2205-20240324_2220_standardized_10s.csv
# Moved: filtered_538009835_20241124_1842-20241124_1857_standardized_10s.csv
# Moved: filtered_257084120_20240411_0006-20240411_0021_standardized_10s.csv
# Moved: filtered_636023392_20240411_0145-20240411_0200_standardized_10s.csv
# Moved: filtered_253172000_20240519_0429-20240519_0443_standardized_10s.csv
# Moved: filtered_236166000_20240626_1235-20240626_1250_standardized_10s.csv
# Moved: filtered_244890472_20240630_1835-20240630_1850_standardized_10s.csv
# Moved: filtered_219031446_20240311_1130-20240311_1145_standardized_10s.csv
# Moved: filtered_352002353_20240402_0111-20240402_0126_standardized_10s.csv
# Moved: filtered_305773000_20240430_0634-20240430_0649_standardized_10s.csv
# Moved: filtered_212669000_20240316_0130-20240316_0145_standardized_10s.csv
# Moved: filtered_255806138_20240413_0259-20240413_0314_standardized_10s.csv
# Moved: filtered_220368000_20240519_0215-20240519_0229_standardized_10s.csv
# Moved: filtered_566626000_20240429_2132-20240429_2147_standardized_10s.csv
# Moved: filtered_219001343_20240523_2343-20240523_2358_standardized_10s.csv
# Moved: filtered_219021321_20240625_0007-20240625_0022_standardized_10s.csv
# Moved: filtered_219014012_20240313_1556-20240313_1611_standardized_10s.csv
# Moved: filtered_257998000_20240519_1148-20240519_1203_standardized_10s.csv
# Moved: filtered_538005402_20240628_2112-20240628_2127_standardized_10s.csv
# Moved: filtered_261004881_20240529_1430-20240529_1445_standardized_10s.csv
# Moved: filtered_265012140_20240620_1848-20240620_1903_standardized_10s.csv
# Moved: filtered_219000219_20240522_2153-20240522_2207_standardized_10s.csv
# Moved: filtered_219115000_20241124_2355-20241125_0010_standardized_10s.csv
# Moved: filtered_538010400_20240302_1803-20240302_1818_standardized_10s.csv
# Moved: filtered_230712000_20240623_0445-20240623_0500_standardized_10s.csv
# Moved: filtered_257086830_20240314_0824-20240314_0839_standardized_10s.csv
# Moved: filtered_636022668_20240414_2254-20240414_2308_standardized_10s.csv
# Moved: filtered_219613000_20240621_0129-20240621_0144_standardized_10s.csv
# Moved: filtered_219358000_20240319_2027-20240319_2042_standardized_10s.csv
# Moved: filtered_636093236_20240324_0724-20240324_0739_standardized_10s.csv
# Moved: filtered_257207000_20240310_2130-20240310_2145_standardized_10s.csv
# Moved: filtered_219019936_20240523_1447-20240523_1502_standardized_10s.csv
# Moved: filtered_219592000_20240328_2200-20240328_2215_standardized_10s.csv
# Moved: filtered_636019292_20240410_1633-20240410_1648_standardized_10s.csv
# Moved: filtered_219613000_20240329_2309-20240329_2324_standardized_10s.csv
# Moved: filtered_311000766_20240318_1326-20240318_1341_standardized_10s.csv
# Moved: filtered_311000929_20240530_0119-20240530_0134_standardized_10s.csv
# Moved: filtered_235087256_20241129_0349-20241129_0404_standardized_10s.csv
# Moved: filtered_538008326_20240321_0718-20240321_0733_standardized_10s.csv
# Moved: filtered_636017495_20240606_1855-20240606_1910_standardized_10s.csv
# Moved: filtered_311000971_20241130_0024-20241130_0039_standardized_10s.csv
# Moved: filtered_314703000_20240430_0042-20240430_0056_standardized_10s.csv
# Moved: filtered_255806300_20240526_1310-20240526_1324_standardized_10s.csv
# Moved: filtered_210553000_20240307_1423-20240307_1437_standardized_10s.csv
# Moved: filtered_246466000_20240312_0638-20240312_0652_standardized_10s.csv
# Moved: filtered_636093262_20240302_1343-20240302_1357_standardized_10s.csv
# Moved: filtered_219014012_20240619_0558-20240619_0613_standardized_10s.csv
# Moved: filtered_244170427_20240408_1149-20240408_1204_standardized_10s.csv
# Moved: filtered_257601000_20241126_0911-20241126_0925_standardized_10s.csv
# Moved: filtered_232023509_20240526_0637-20240526_0652_standardized_10s.csv
# Moved: filtered_210548000_20240430_0838-20240430_0853_standardized_10s.csv
# Moved: filtered_209275000_20240328_0926-20240328_0941_standardized_10s.csv
# Moved: filtered_311032200_20240618_1921-20240618_1935_standardized_10s.csv
# Moved: filtered_245953000_20240311_1731-20240311_1746_standardized_10s.csv
# Moved: filtered_246663000_20240318_0824-20240318_0839_standardized_10s.csv
# Moved: filtered_265002000_20240312_2115-20240312_2129_standardized_10s.csv
# Moved: filtered_538005696_20240409_1744-20240409_1758_standardized_10s.csv
# Moved: filtered_352001011_20240301_1522-20240301_1537_standardized_10s.csv
# Moved: filtered_636023154_20240525_1250-20240525_1305_standardized_10s.csv
# Moved: filtered_219459000_20240307_1309-20240307_1324_standardized_10s.csv
# Moved: filtered_405000242_20241126_2226-20241126_2240_standardized_10s.csv
# Moved: filtered_258809000_20240618_1216-20240618_1230_standardized_10s.csv
# Moved: filtered_265410000_20240529_0844-20240529_0859_standardized_10s.csv
# Moved: filtered_259140000_20240606_0043-20240606_0058_standardized_10s.csv
# Moved: filtered_219027298_20240621_1251-20240621_1306_standardized_10s.csv
# Moved: filtered_219020398_20240615_0352-20240615_0406_standardized_10s.csv
# Moved: filtered_256325000_20240323_2032-20240323_2047_standardized_10s.csv
# Moved: filtered_235102532_20240321_1426-20240321_1441_standardized_10s.csv
# Moved: filtered_255801580_20240309_1832-20240309_1847_standardized_10s.csv
# Moved: filtered_423520100_20240322_1151-20240322_1206_standardized_10s.csv
# Moved: filtered_211870240_20240531_1817-20240531_1832_standardized_10s.csv
# Moved: filtered_311000971_20240331_0637-20240331_0652_standardized_10s.csv
# Moved: filtered_375378000_20240528_0732-20240528_0747_standardized_10s.csv
# Moved: filtered_255845000_20240616_0619-20240616_0634_standardized_10s.csv
# Moved: filtered_314463000_20240616_0249-20240616_0304_standardized_10s.csv
# Moved: filtered_311001445_20240628_1905-20240628_1920_standardized_10s.csv
# Moved: filtered_314431000_20240610_1929-20240610_1943_standardized_10s.csv
# Moved: filtered_219022257_20240416_0253-20240416_0308_standardized_10s.csv
# Moved: filtered_245535000_20240311_1025-20240311_1040_standardized_10s.csv
# Moved: filtered_375671000_20240415_0615-20240415_0630_standardized_10s.csv
# Moved: filtered_305507000_20240626_1835-20240626_1850_standardized_10s.csv
# Moved: filtered_219015298_20240519_0915-20240519_0930_standardized_10s.csv
# Moved: filtered_258715000_20240519_0311-20240519_0326_standardized_10s.csv
# Moved: filtered_219019936_20240614_1150-20240614_1205_standardized_10s.csv
# Moved: filtered_477867700_20240418_1822-20240418_1837_standardized_10s.csv
# Moved: filtered_266465000_20240619_1224-20240619_1239_standardized_10s.csv
# Moved: filtered_266454000_20240619_2350-20240620_0005_standardized_10s.csv
# Moved: filtered_255954000_20240301_0355-20240301_0410_standardized_10s.csv
# Moved: filtered_219543000_20240605_2213-20240605_2228_standardized_10s.csv
# Moved: filtered_636017971_20240308_1435-20240308_1450_standardized_10s.csv
# Moved: filtered_249934000_20240531_0559-20240531_0614_standardized_10s.csv
# Moved: filtered_219022257_20240601_0716-20240601_0730_standardized_10s.csv
# Moved: filtered_305857000_20240621_1415-20240621_1430_standardized_10s.csv
# Moved: filtered_219030533_20240531_0825-20240531_0840_standardized_10s.csv
# Moved: filtered_249386000_20240521_0815-20240521_0829_standardized_10s.csv
# Moved: filtered_220223000_20240406_1908-20240406_1923_standardized_10s.csv
# Moved: filtered_311000851_20240618_2111-20240618_2126_standardized_10s.csv
# Moved: filtered_238251000_20240404_0658-20240404_0713_standardized_10s.csv
# Moved: filtered_246802000_20240606_0412-20240606_0427_standardized_10s.csv
# Moved: filtered_636021648_20240429_1912-20240429_1927_standardized_10s.csv
# Moved: filtered_230350000_20240403_0338-20240403_0353_standardized_10s.csv
# Moved: filtered_255805883_20240519_1406-20240519_1420_standardized_10s.csv
# Moved: filtered_255806190_20240528_1824-20240528_1838_standardized_10s.csv
# Moved: filtered_259029000_20240328_1707-20240328_1722_standardized_10s.csv
# Moved: filtered_230357000_20240619_1434-20240619_1449_standardized_10s.csv
# Moved: filtered_219613000_20240630_1059-20240630_1114_standardized_10s.csv
# Moved: filtered_371090000_20240406_0831-20240406_0846_standardized_10s.csv
# Moved: filtered_257115000_20240529_2242-20240529_2257_standardized_10s.csv
# Moved: filtered_265012140_20240629_1118-20240629_1133_standardized_10s.csv
# Moved: filtered_255801580_20240322_0348-20240322_0403_standardized_10s.csv
# Moved: filtered_255806368_20240610_1451-20240610_1506_standardized_10s.csv
# Moved: filtered_212821000_20240530_1623-20240530_1638_standardized_10s.csv
# Moved: filtered_235362000_20240327_2101-20240327_2116_standardized_10s.csv
# Moved: filtered_538007116_20240620_0035-20240620_0050_standardized_10s.csv
# Moved: filtered_219026706_20240521_1056-20240521_1111_standardized_10s.csv
# Moved: filtered_257900000_20241122_0828-20241122_0842_standardized_10s.csv
# Moved: filtered_266467000_20240423_0706-20240423_0721_standardized_10s.csv
# Moved: filtered_235102532_20240630_1332-20240630_1347_standardized_10s.csv
# Moved: filtered_212503000_20240623_1338-20240623_1353_standardized_10s.csv
# Moved: filtered_413687000_20240414_0722-20240414_0737_standardized_10s.csv
# Moved: filtered_246388000_20240614_1119-20240614_1134_standardized_10s.csv
# Moved: filtered_630001042_20240425_0813-20240425_0827_standardized_10s.csv
# Moved: filtered_220339000_20240525_0953-20240525_1008_standardized_10s.csv
# Moved: filtered_304323000_20240627_0242-20240627_0257_standardized_10s.csv
# Moved: filtered_209314000_20240528_0332-20240528_0347_standardized_10s.csv
# Moved: filtered_247305000_20240321_0354-20240321_0409_standardized_10s.csv
# Moved: filtered_563003300_20240415_0405-20240415_0420_standardized_10s.csv
# Moved: filtered_311000534_20241123_2310-20241123_2325_standardized_10s.csv
# Moved: filtered_244020000_20240316_0457-20240316_0512_standardized_10s.csv
# Moved: filtered_566042000_20240404_1958-20240404_2013_standardized_10s.csv
# Moved: filtered_257066860_20241127_1136-20241127_1150_standardized_10s.csv
# Moved: filtered_247118700_20240426_1158-20240426_1213_standardized_10s.csv
# Moved: filtered_266472000_20240305_1409-20240305_1424_standardized_10s.csv
# Moved: filtered_304955000_20240602_1639-20240602_1654_standardized_10s.csv
# Moved: filtered_538009152_20240429_0859-20240429_0914_standardized_10s.csv
# Moved: filtered_219023617_20240320_0429-20240320_0444_standardized_10s.csv
# Moved: filtered_247391400_20240421_0535-20240421_0550_standardized_10s.csv
# Moved: filtered_636021061_20240629_1715-20240629_1730_standardized_10s.csv
# Moved: filtered_246051000_20240309_0002-20240309_0017_standardized_10s.csv
# Moved: filtered_255806190_20240623_1402-20240623_1416_standardized_10s.csv
# Moved: filtered_219022257_20240411_0108-20240411_0123_standardized_10s.csv
# Moved: filtered_219029785_20240626_1816-20240626_1831_standardized_10s.csv
# Moved: filtered_215903000_20240527_1619-20240527_1634_standardized_10s.csv
# Moved: filtered_220339000_20240523_1108-20240523_1123_standardized_10s.csv
# Moved: filtered_220307000_20240329_0042-20240329_0056_standardized_10s.csv
# Moved: filtered_235060914_20240601_1907-20240601_1922_standardized_10s.csv
# Moved: filtered_246125000_20240420_1731-20240420_1746_standardized_10s.csv
# Moved: filtered_219110000_20240407_0238-20240407_0253_standardized_10s.csv
# Moved: filtered_219592000_20240322_2230-20240322_2245_standardized_10s.csv
# Moved: filtered_235006480_20240627_0812-20240627_0827_standardized_10s.csv
# Moved: filtered_244870072_20240525_0500-20240525_0515_standardized_10s.csv
# Moved: filtered_636016437_20240315_0736-20240315_0750_standardized_10s.csv
# Moved: filtered_219945000_20240608_2335-20240608_2350_standardized_10s.csv
# Moved: filtered_273529800_20240305_0511-20240305_0526_standardized_10s.csv
# Moved: filtered_229077000_20240411_0230-20240411_0245_standardized_10s.csv
# Moved: filtered_372837000_20240419_1129-20240419_1144_standardized_10s.csv
# Moved: filtered_375219000_20240615_2043-20240615_2058_standardized_10s.csv
# Moved: filtered_257538000_20240429_2320-20240429_2335_standardized_10s.csv
# Moved: filtered_352001928_20240612_0201-20240612_0215_standardized_10s.csv
# Moved: filtered_265002000_20241123_1113-20241123_1128_standardized_10s.csv
# Moved: filtered_248148000_20240529_0243-20240529_0258_standardized_10s.csv
# Moved: filtered_352001148_20240627_0122-20240627_0137_standardized_10s.csv
# Moved: filtered_538008262_20240602_0645-20240602_0700_standardized_10s.csv
# Moved: filtered_245015000_20241123_2045-20241123_2100_standardized_10s.csv
# Moved: filtered_314238000_20240323_1206-20240323_1221_standardized_10s.csv
# Moved: filtered_538010045_20240406_0110-20240406_0125_standardized_10s.csv
# Moved: filtered_229536000_20240422_1532-20240422_1546_standardized_10s.csv
# Moved: filtered_636022835_20240417_0415-20240417_0430_standardized_10s.csv
# Moved: filtered_220620000_20240424_1748-20240424_1803_standardized_10s.csv
# Moved: filtered_246141000_20240628_1733-20240628_1748_standardized_10s.csv
# Moved: filtered_231794000_20240303_1735-20240303_1750_standardized_10s.csv
# Moved: filtered_219020398_20240607_1037-20240607_1051_standardized_10s.csv
# Moved: filtered_538006129_20240406_0046-20240406_0101_standardized_10s.csv
# Moved: filtered_261148000_20240317_2323-20240317_2337_standardized_10s.csv
# Moved: filtered_518998923_20240616_0238-20240616_0253_standardized_10s.csv
# Moved: filtered_311000340_20240612_1500-20240612_1515_standardized_10s.csv
# Moved: filtered_636015105_20240528_1649-20240528_1704_standardized_10s.csv
# Moved: filtered_244063000_20240624_2234-20240624_2249_standardized_10s.csv
# Moved: filtered_305279000_20240316_0255-20240316_0310_standardized_10s.csv
# Moved: filtered_219022257_20240402_0253-20240402_0308_standardized_10s.csv
# Moved: filtered_305426000_20241122_0510-20241122_0525_standardized_10s.csv
# Moved: filtered_636023266_20240607_2001-20240607_2016_standardized_10s.csv
# Moved: filtered_209313000_20240419_0344-20240419_0359_standardized_10s.csv
# Moved: filtered_232023509_20240521_0822-20240521_0837_standardized_10s.csv
# Moved: filtered_538005608_20240327_1451-20240327_1505_standardized_10s.csv
# Moved: filtered_236729000_20240328_1402-20240328_1417_standardized_10s.csv
# Moved: filtered_230357000_20240313_0742-20240313_0757_standardized_10s.csv
# Moved: filtered_210046000_20240629_0131-20240629_0146_standardized_10s.csv
# Moved: filtered_257694000_20240308_1023-20240308_1038_standardized_10s.csv
# Moved: filtered_219825000_20240602_1113-20240602_1128_standardized_10s.csv
# Moved: filtered_244255000_20240622_2035-20240622_2050_standardized_10s.csv
# Moved: filtered_219829000_20240523_1508-20240523_1523_standardized_10s.csv
# Moved: filtered_246777000_20240317_2226-20240317_2241_standardized_10s.csv
# Moved: filtered_219616000_20240617_1412-20240617_1427_standardized_10s.csv
# Moved: filtered_220368000_20240409_1715-20240409_1730_standardized_10s.csv
# Moved: filtered_257182000_20240413_0015-20240413_0029_standardized_10s.csv
# Moved: filtered_266254000_20241126_0533-20241126_0548_standardized_10s.csv
# Moved: filtered_265410000_20241123_0059-20241123_0114_standardized_10s.csv
# Moved: filtered_220189000_20240618_0055-20240618_0110_standardized_10s.csv
# Moved: filtered_538009326_20240310_2054-20240310_2109_standardized_10s.csv
# Moved: filtered_372669000_20240415_2209-20240415_2224_standardized_10s.csv
# Moved: filtered_636016922_20240521_1933-20240521_1948_standardized_10s.csv
# Moved: filtered_255805899_20240605_0838-20240605_0853_standardized_10s.csv
# Moved: filtered_257086830_20240314_1154-20240314_1209_standardized_10s.csv
# Moved: filtered_257617000_20240621_1430-20240621_1445_standardized_10s.csv
# Moved: filtered_636022668_20240414_2124-20240414_2138_standardized_10s.csv
# Moved: filtered_273391650_20240316_1041-20240316_1056_standardized_10s.csv
# Moved: filtered_371950000_20240521_1954-20240521_2009_standardized_10s.csv
# Moved: filtered_219015298_20240319_0827-20240319_0842_standardized_10s.csv
# Moved: filtered_246518000_20240605_1200-20240605_1215_standardized_10s.csv
# Moved: filtered_219421000_20240615_0953-20240615_1008_standardized_10s.csv
# Moved: filtered_229807000_20240527_1904-20240527_1919_standardized_10s.csv
# Moved: filtered_352003862_20240604_1227-20240604_1242_standardized_10s.csv
# Moved: filtered_352002401_20240530_0513-20240530_0528_standardized_10s.csv
# Moved: filtered_219010873_20240411_2330-20240411_2345_standardized_10s.csv
# Moved: filtered_636022445_20240622_0543-20240622_0558_standardized_10s.csv
# Moved: filtered_244110938_20240321_0604-20240321_0619_standardized_10s.csv
# Moved: filtered_548907000_20240307_0418-20240307_0433_standardized_10s.csv
# Moved: filtered_219861000_20240601_0840-20240601_0854_standardized_10s.csv
# Moved: filtered_636023164_20240410_0737-20240410_0752_standardized_10s.csv
# Moved: filtered_219019936_20240330_1323-20240330_1338_standardized_10s.csv
# Moved: filtered_305612000_20240303_0948-20240303_1003_standardized_10s.csv
# Moved: filtered_210051000_20240531_1857-20240531_1912_standardized_10s.csv
# Moved: filtered_636022010_20240608_0900-20240608_0915_standardized_10s.csv
# Moved: filtered_232031538_20240613_1544-20240613_1559_standardized_10s.csv
# Moved: filtered_215031000_20240627_0139-20240627_0154_standardized_10s.csv
# Moved: filtered_257182000_20240519_1839-20240519_1854_standardized_10s.csv
# Moved: filtered_219945000_20240307_2215-20240307_2230_standardized_10s.csv
# Moved: filtered_210167000_20241122_2153-20241122_2208_standardized_10s.csv
# Moved: filtered_245491000_20240304_0844-20240304_0859_standardized_10s.csv
# Moved: filtered_220417000_20240430_1904-20240430_1919_standardized_10s.csv
# Moved: filtered_352001425_20240531_1923-20240531_1938_standardized_10s.csv
# Moved: filtered_246179000_20241130_1852-20241130_1907_standardized_10s.csv
# Moved: filtered_215936000_20240401_1404-20240401_1419_standardized_10s.csv
# Moved: filtered_255805952_20240422_1020-20240422_1034_standardized_10s.csv
# Moved: filtered_219014012_20240525_0557-20240525_0612_standardized_10s.csv
# Moved: filtered_375103000_20240414_0037-20240414_0052_standardized_10s.csv
# Moved: filtered_256717000_20240619_0501-20240619_0516_standardized_10s.csv
# Moved: filtered_266286000_20240526_0655-20240526_0710_standardized_10s.csv
# Moved: filtered_538006206_20240402_0647-20240402_0702_standardized_10s.csv
# Moved: filtered_257980000_20240404_0740-20240404_0755_standardized_10s.csv
# Moved: filtered_244700959_20240521_1322-20240521_1337_standardized_10s.csv
# Moved: filtered_230941700_20240530_2115-20240530_2130_standardized_10s.csv
# Moved: filtered_314415000_20240313_2010-20240313_2025_standardized_10s.csv
# Moved: filtered_210048000_20240430_1805-20240430_1820_standardized_10s.csv
# Moved: filtered_236669000_20240609_1045-20240609_1100_standardized_10s.csv
# Moved: filtered_219007477_20240330_0328-20240330_0343_standardized_10s.csv
# Moved: filtered_219027298_20240604_0751-20240604_0806_standardized_10s.csv
# Moved: filtered_244267000_20240623_1611-20240623_1625_standardized_10s.csv
# Moved: filtered_636017416_20240414_1418-20240414_1433_standardized_10s.csv
# Moved: filtered_636016951_20241127_1947-20241127_2002_standardized_10s.csv
# Moved: filtered_219015153_20240630_1548-20240630_1603_standardized_10s.csv
# Moved: filtered_257115000_20240619_1311-20240619_1325_standardized_10s.csv
# Moved: filtered_374124000_20240407_2248-20240407_2303_standardized_10s.csv
# Moved: filtered_246478000_20240529_1930-20240529_1945_standardized_10s.csv
# Moved: filtered_219421000_20240627_1853-20240627_1908_standardized_10s.csv
# Moved: filtered_244870072_20240525_1701-20240525_1716_standardized_10s.csv
# Moved: filtered_219459000_20240527_0043-20240527_0058_standardized_10s.csv
# Moved: filtered_372837000_20240408_1759-20240408_1814_standardized_10s.csv
# Moved: filtered_244178000_20240330_0851-20240330_0906_standardized_10s.csv
# Moved: filtered_219001343_20240527_2114-20240527_2128_standardized_10s.csv
# Moved: filtered_248132000_20240426_1210-20240426_1225_standardized_10s.csv
# Moved: filtered_314544000_20241122_0346-20241122_0401_standardized_10s.csv
# Moved: filtered_244340000_20240527_2123-20240527_2138_standardized_10s.csv
# Moved: filtered_257364000_20240415_0230-20240415_0245_standardized_10s.csv
# Moved: filtered_636019791_20240522_0036-20240522_0051_standardized_10s.csv
# Moved: filtered_219110000_20240311_2050-20240311_2105_standardized_10s.csv
# Moved: filtered_219449000_20240525_1632-20240525_1647_standardized_10s.csv
# Moved: filtered_219014012_20240530_1014-20240530_1028_standardized_10s.csv
# Moved: filtered_566598000_20240326_0740-20240326_0755_standardized_10s.csv
# Moved: filtered_210155000_20240611_0000-20240611_0015_standardized_10s.csv
# Moved: filtered_219236000_20240313_1521-20240313_1536_standardized_10s.csv
# Moved: filtered_255802940_20240321_1548-20240321_1603_standardized_10s.csv
# Moved: filtered_636014184_20240319_0857-20240319_0912_standardized_10s.csv
# Moved: filtered_538005521_20240308_1901-20240308_1916_standardized_10s.csv
# Moved: filtered_220141000_20240408_1950-20240408_2005_standardized_10s.csv
# Moved: filtered_266120000_20240321_0904-20240321_0919_standardized_10s.csv
# Moved: filtered_229725000_20240306_2012-20240306_2027_standardized_10s.csv
# Moved: filtered_314606000_20240610_1747-20240610_1802_standardized_10s.csv
# Moved: filtered_219001343_20240527_0013-20240527_0028_standardized_10s.csv
# Moved: filtered_256793000_20240522_0820-20240522_0835_standardized_10s.csv
# Moved: filtered_210155000_20240609_2130-20240609_2145_standardized_10s.csv
# Moved: filtered_311001076_20240321_1159-20240321_1214_standardized_10s.csv
# Moved: filtered_219032609_20240309_0749-20240309_0804_standardized_10s.csv
# Moved: filtered_209671000_20240324_1628-20240324_1643_standardized_10s.csv
# Moved: filtered_244024000_20240410_1417-20240410_1432_standardized_10s.csv
# Moved: filtered_538008269_20240401_0608-20240401_0622_standardized_10s.csv
# Moved: filtered_257182000_20240525_0109-20240525_0124_standardized_10s.csv
# Moved: filtered_538007372_20240327_0922-20240327_0937_standardized_10s.csv
# Moved: filtered_219022257_20240303_1501-20240303_1516_standardized_10s.csv
# Moved: filtered_538007623_20240611_0325-20240611_0340_standardized_10s.csv
# Moved: filtered_259888000_20240411_0530-20240411_0545_standardized_10s.csv
# Moved: filtered_305279000_20240325_0325-20240325_0340_standardized_10s.csv
# Moved: filtered_209535000_20240527_1305-20240527_1320_standardized_10s.csv
# Moved: filtered_219027752_20241123_1014-20241123_1029_standardized_10s.csv
# Moved: filtered_219027298_20240328_1101-20240328_1116_standardized_10s.csv
# Moved: filtered_518998709_20240313_2024-20240313_2038_standardized_10s.csv
# Moved: filtered_244790608_20240411_1604-20240411_1619_standardized_10s.csv
# Moved: filtered_372078000_20240521_1811-20240521_1826_standardized_10s.csv
# Moved: filtered_308192000_20240527_1518-20240527_1533_standardized_10s.csv
# Moved: filtered_235087256_20240307_1903-20240307_1918_standardized_10s.csv
# Moved: filtered_566679000_20240629_1941-20240629_1956_standardized_10s.csv
# Moved: filtered_314661000_20240613_0828-20240613_0843_standardized_10s.csv
# Moved: filtered_229807000_20240316_0817-20240316_0831_standardized_10s.csv
# Moved: filtered_266274000_20240519_1906-20240519_1921_standardized_10s.csv
# Moved: filtered_314702000_20240413_2128-20240413_2143_standardized_10s.csv
# Moved: filtered_215936000_20240408_1404-20240408_1419_standardized_10s.csv
# Moved: filtered_244580000_20240419_2212-20240419_2227_standardized_10s.csv
# Moved: filtered_518999201_20240527_1040-20240527_1055_standardized_10s.csv
# Moved: filtered_255769000_20240526_0230-20240526_0244_standardized_10s.csv
# Moved: filtered_265177000_20240303_2256-20240303_2311_standardized_10s.csv
# Moved: filtered_209671000_20240527_0127-20240527_0142_standardized_10s.csv
# Moved: filtered_636022010_20240626_1341-20240626_1356_standardized_10s.csv
# Moved: filtered_351660000_20240427_1412-20240427_1427_standardized_10s.csv
# Moved: filtered_373834000_20240423_0541-20240423_0555_standardized_10s.csv
# Moved: filtered_266465000_20240626_1854-20240626_1909_standardized_10s.csv
# Moved: filtered_538010600_20240317_1702-20240317_1717_standardized_10s.csv
# Moved: filtered_219017733_20240622_1700-20240622_1715_standardized_10s.csv
# Moved: filtered_352002532_20240425_0835-20240425_0850_standardized_10s.csv
# Moved: filtered_248006000_20240406_2036-20240406_2051_standardized_10s.csv
# Moved: filtered_258812000_20241122_1340-20241122_1355_standardized_10s.csv
# Moved: filtered_231068000_20240329_0717-20240329_0731_standardized_10s.csv
# Moved: filtered_314415000_20240613_1211-20240613_1226_standardized_10s.csv
# Moved: filtered_352001928_20240612_0045-20240612_0100_standardized_10s.csv
# Moved: filtered_273356870_20240309_2046-20240309_2101_standardized_10s.csv
# Moved: filtered_244090800_20240628_2251-20240628_2306_standardized_10s.csv
# Moved: filtered_255806256_20240317_1601-20240317_1616_standardized_10s.csv
# Moved: filtered_414576000_20240605_1031-20240605_1046_standardized_10s.csv
# Moved: filtered_241166000_20240529_0257-20240529_0311_standardized_10s.csv
# Moved: filtered_538010680_20240620_1042-20240620_1057_standardized_10s.csv
# Moved: filtered_219945000_20240412_2218-20240412_2233_standardized_10s.csv
# Moved: filtered_314463000_20240616_1019-20240616_1034_standardized_10s.csv
# Moved: filtered_311000076_20240428_2245-20240428_2300_standardized_10s.csv
# Moved: filtered_304829000_20240401_0957-20240401_1012_standardized_10s.csv
# Moved: filtered_219002827_20240522_2127-20240522_2141_standardized_10s.csv
# Moved: filtered_255806081_20240305_0140-20240305_0155_standardized_10s.csv
# Moved: filtered_244834000_20240521_1046-20240521_1101_standardized_10s.csv
# Moved: filtered_219945000_20240615_2135-20240615_2150_standardized_10s.csv
# Moved: filtered_257066860_20240519_1735-20240519_1750_standardized_10s.csv
# Moved: filtered_229807000_20240526_1034-20240526_1049_standardized_10s.csv
# Moved: filtered_376205000_20240323_1316-20240323_1331_standardized_10s.csv
# Moved: filtered_311001499_20240522_0644-20240522_0658_standardized_10s.csv
# Moved: filtered_220339000_20240526_1330-20240526_1345_standardized_10s.csv
# Moved: filtered_219029726_20240312_0110-20240312_0125_standardized_10s.csv
# Moved: filtered_613003808_20240409_0221-20240409_0235_standardized_10s.csv
# Moved: filtered_563025500_20241123_1925-20241123_1940_standardized_10s.csv
# Moved: filtered_246545000_20240408_0509-20240408_0524_standardized_10s.csv
# Moved: filtered_247224200_20240526_2106-20240526_2121_standardized_10s.csv
# Moved: filtered_266464000_20240306_0808-20240306_0823_standardized_10s.csv
# Moved: filtered_538010923_20240303_0636-20240303_0651_standardized_10s.csv
# Moved: filtered_538004215_20240424_0910-20240424_0925_standardized_10s.csv
# Moved: filtered_219029726_20240626_0330-20240626_0345_standardized_10s.csv
# Moved: filtered_244890472_20240520_0013-20240520_0028_standardized_10s.csv
# Moved: filtered_266076000_20240423_0545-20240423_0600_standardized_10s.csv
# Moved: filtered_244834000_20240527_1231-20240527_1246_standardized_10s.csv
# Moved: filtered_246366000_20240302_2156-20240302_2211_standardized_10s.csv
# Moved: filtered_636017076_20240621_1455-20240621_1510_standardized_10s.csv
# Moved: filtered_232005533_20240304_1609-20240304_1624_standardized_10s.csv
# Moved: filtered_219945000_20240329_0100-20240329_0115_standardized_10s.csv
# Moved: filtered_538005452_20241128_0559-20241128_0614_standardized_10s.csv
# Moved: filtered_352211000_20240528_0920-20240528_0935_standardized_10s.csv
# Moved: filtered_626422000_20240328_0225-20240328_0240_standardized_10s.csv
# Moved: filtered_219030432_20240606_1320-20240606_1335_standardized_10s.csv
# Moved: filtered_218098000_20240614_1150-20240614_1205_standardized_10s.csv
# Moved: filtered_244700959_20240527_0852-20240527_0907_standardized_10s.csv
# Moved: filtered_220368000_20240313_1132-20240313_1147_standardized_10s.csv
# Moved: filtered_247019600_20240311_0055-20240311_0110_standardized_10s.csv
# Moved: filtered_211417590_20240628_1527-20240628_1541_standardized_10s.csv
# Moved: filtered_636018830_20240415_0144-20240415_0159_standardized_10s.csv
# Moved: filtered_246497000_20240601_2033-20240601_2048_standardized_10s.csv
# Moved: filtered_441992000_20240304_1313-20240304_1328_standardized_10s.csv
# Moved: filtered_236180000_20240629_1928-20240629_1943_standardized_10s.csv
# Moved: filtered_219010873_20240529_2338-20240529_2353_standardized_10s.csv
# Moved: filtered_238045000_20241130_2204-20241130_2219_standardized_10s.csv
# Moved: filtered_273290820_20240404_0318-20240404_0333_standardized_10s.csv
# Moved: filtered_244790047_20240423_0257-20240423_0312_standardized_10s.csv
# Moved: filtered_352002003_20240630_1824-20240630_1839_standardized_10s.csv
# Moved: filtered_636022640_20241129_0038-20241129_0052_standardized_10s.csv
# Moved: filtered_229807000_20240527_0234-20240527_0249_standardized_10s.csv
# Moved: filtered_266158000_20240422_1735-20240422_1750_standardized_10s.csv
# Moved: filtered_636016699_20240614_0947-20240614_1002_standardized_10s.csv
# Moved: filtered_309924000_20240421_1902-20240421_1917_standardized_10s.csv
# Moved: filtered_305026000_20240427_0451-20240427_0506_standardized_10s.csv
# Moved: filtered_257941000_20240428_2312-20240428_2326_standardized_10s.csv
# Moved: filtered_304968000_20240321_2246-20240321_2301_standardized_10s.csv
# Moved: filtered_265043000_20240619_1538-20240619_1552_standardized_10s.csv
# Moved: filtered_231789000_20240316_0712-20240316_0727_standardized_10s.csv
# Moved: filtered_230351000_20240525_0520-20240525_0535_standardized_10s.csv
# Moved: filtered_257960000_20240323_1238-20240323_1253_standardized_10s.csv
# Moved: filtered_219166000_20240308_1856-20240308_1911_standardized_10s.csv
# Moved: filtered_511101065_20240322_1742-20240322_1757_standardized_10s.csv
# Moved: filtered_220368000_20240526_0532-20240526_0547_standardized_10s.csv
# Moved: filtered_538004413_20240609_2229-20240609_2244_standardized_10s.csv
# Moved: filtered_209608000_20240426_0110-20240426_0125_standardized_10s.csv
# Moved: filtered_212018000_20240311_2119-20240311_2134_standardized_10s.csv
# Moved: filtered_538009477_20240607_1714-20240607_1729_standardized_10s.csv
# Moved: filtered_636021830_20241123_0831-20241123_0846_standardized_10s.csv
# Moved: filtered_232023509_20240527_0823-20240527_0838_standardized_10s.csv
# Moved: filtered_636017417_20240309_0814-20240309_0829_standardized_10s.csv
# Moved: filtered_375103000_20240519_0623-20240519_0638_standardized_10s.csv
# Moved: filtered_265177000_20240617_1925-20240617_1940_standardized_10s.csv
# Moved: filtered_477150700_20240531_0304-20240531_0319_standardized_10s.csv
# Moved: filtered_265012140_20240304_0459-20240304_0514_standardized_10s.csv
# Moved: filtered_209715000_20240628_0017-20240628_0032_standardized_10s.csv
# Moved: filtered_305279000_20240303_0425-20240303_0440_standardized_10s.csv
# Moved: filtered_230091950_20240309_2128-20240309_2143_standardized_10s.csv
# Moved: filtered_230694000_20240616_0136-20240616_0151_standardized_10s.csv
# Moved: filtered_255806139_20240322_0542-20240322_0557_standardized_10s.csv
# Moved: filtered_431156000_20240402_0505-20240402_0520_standardized_10s.csv
# Moved: filtered_244059000_20240627_2209-20240627_2224_standardized_10s.csv
# Moved: filtered_311018000_20240531_0924-20240531_0939_standardized_10s.csv
# Moved: filtered_220600000_20240628_0107-20240628_0122_standardized_10s.csv
# Moved: filtered_266392000_20240424_2138-20240424_2153_standardized_10s.csv
# Moved: filtered_211141000_20240623_1006-20240623_1020_standardized_10s.csv
# Moved: filtered_219449000_20240525_0100-20240525_0114_standardized_10s.csv
# Moved: filtered_257723000_20240608_0239-20240608_0254_standardized_10s.csv
# Moved: filtered_626413000_20240609_2017-20240609_2031_standardized_10s.csv
# Moved: filtered_236729000_20240324_1032-20240324_1047_standardized_10s.csv
# Moved: filtered_538005408_20240403_0817-20240403_0832_standardized_10s.csv
# Moved: filtered_636022653_20240426_0129-20240426_0144_standardized_10s.csv
# Moved: filtered_231840000_20241127_0451-20241127_0506_standardized_10s.csv
# Moved: filtered_314261000_20240309_1037-20240309_1052_standardized_10s.csv
# Moved: filtered_219613000_20241122_1630-20241122_1645_standardized_10s.csv
# Moved: filtered_219014012_20240523_1303-20240523_1318_standardized_10s.csv
# Moved: filtered_636017617_20240624_2357-20240625_0012_standardized_10s.csv
# Moved: filtered_247386800_20240523_2005-20240523_2020_standardized_10s.csv
# Moved: filtered_314790000_20240410_0325-20240410_0339_standardized_10s.csv
# Moved: filtered_219244000_20240524_1247-20240524_1302_standardized_10s.csv
# Moved: filtered_244790314_20240305_1726-20240305_1741_standardized_10s.csv
# Moved: filtered_219370000_20240305_0718-20240305_0732_standardized_10s.csv
# Moved: filtered_277029000_20240402_0650-20240402_0705_standardized_10s.csv
# Moved: filtered_247206000_20240619_0122-20240619_0137_standardized_10s.csv
# ...
# Moved: filtered_265039000_20240601_1004-20240601_1019_standardized_10s.csv
# Moved: filtered_636021850_20240312_0005-20240312_0020_standardized_10s.csv
# Moved: filtered_212882000_20240519_0957-20240519_1012_standardized_10s.csv
# Moved: filtered_636093261_20240417_0946-20240417_1001_standardized_10s.csv
# Moved: filtered_626413000_20240417_0403-20240417_0418_standardized_10s.csv
# Moved: filtered_246051000_20240619_0911-20240619_0926_standardized_10s.csv
# Moved: filtered_219001343_20240528_1745-20240528_1800_standardized_10s.csv
# Moved: filtered_232023509_20240523_0722-20240523_0737_standardized_10s.csv
# Moved: filtered_636093239_20240312_2051-20240312_2106_standardized_10s.csv
# Moved: filtered_220223000_20240424_0453-20240424_0508_standardized_10s.csv
# Moved: filtered_229807000_20240304_1716-20240304_1731_standardized_10s.csv
# Moved: filtered_244103000_20240627_1132-20240627_1147_standardized_10s.csv
# Moved: filtered_244700959_20240625_0644-20240625_0659_standardized_10s.csv
# Moved: filtered_255915747_20240419_2249-20240419_2304_standardized_10s.csv
# Moved: filtered_219027298_20240307_0846-20240307_0901_standardized_10s.csv
# Moved: filtered_257314000_20240419_2347-20240420_0002_standardized_10s.csv
# Moved: filtered_258858000_20240619_0035-20240619_0050_standardized_10s.csv
# Moved: filtered_210553000_20240329_1353-20240329_1407_standardized_10s.csv
# Moved: filtered_477591300_20240617_0153-20240617_0208_standardized_10s.csv
# Moved: filtered_257561000_20240523_1535-20240523_1550_standardized_10s.csv
# Moved: filtered_311000455_20240318_1929-20240318_1944_standardized_10s.csv
# Moved: filtered_205681000_20240412_0057-20240412_0112_standardized_10s.csv
# Moved: filtered_257446000_20240412_0421-20240412_0435_standardized_10s.csv
# Moved: filtered_257617000_20240422_0816-20240422_0830_standardized_10s.csv
# Moved: filtered_266068000_20240328_1246-20240328_1301_standardized_10s.csv
# Moved: filtered_255769000_20240629_1010-20240629_1025_standardized_10s.csv
# Moved: filtered_249934000_20240417_0803-20240417_0818_standardized_10s.csv
# Moved: filtered_353732000_20240526_0922-20240526_0937_standardized_10s.csv
# Moved: filtered_538005791_20240523_2354-20240524_0009_standardized_10s.csv
# Moved: filtered_219027752_20241127_0959-20241127_1014_standardized_10s.csv
# Moved: filtered_258059000_20240529_1833-20240529_1848_standardized_10s.csv
# Moved: filtered_210553000_20240406_1441-20240406_1456_standardized_10s.csv
# Moved: filtered_219281000_20240603_0310-20240603_0325_standardized_10s.csv
# Moved: filtered_311000608_20240626_1833-20240626_1848_standardized_10s.csv
# Moved: filtered_245279000_20240407_2201-20240407_2216_standardized_10s.csv
# Moved: filtered_257207000_20240622_1245-20240622_1300_standardized_10s.csv
# Moved: filtered_636022764_20240411_0200-20240411_0215_standardized_10s.csv
# Moved: filtered_257701000_20240328_2300-20240328_2315_standardized_10s.csv
# Moved: filtered_258824000_20240309_0708-20240309_0723_standardized_10s.csv
# Moved: filtered_220368000_20240525_0332-20240525_0347_standardized_10s.csv
# Moved: filtered_352002271_20240604_0247-20240604_0302_standardized_10s.csv
# Moved: filtered_220516000_20240629_0708-20240629_0722_standardized_10s.csv
# Moved: filtered_246518000_20240605_1230-20240605_1245_standardized_10s.csv
# Moved: filtered_636016827_20240311_1026-20240311_1041_standardized_10s.csv
# Moved: filtered_210051000_20241123_2114-20241123_2129_standardized_10s.csv
# Moved: filtered_219015382_20240627_0015-20240627_0030_standardized_10s.csv
# Moved: filtered_218481000_20240613_1430-20240613_1444_standardized_10s.csv
# Moved: filtered_370638000_20240607_1335-20240607_1350_standardized_10s.csv
# Moved: filtered_259222000_20240404_0050-20240404_0105_standardized_10s.csv
# Moved: filtered_266286000_20240526_2040-20240526_2055_standardized_10s.csv
# Moved: filtered_636093289_20240419_2058-20240419_2113_standardized_10s.csv
# Moved: filtered_311087000_20240405_0855-20240405_0909_standardized_10s.csv
# Moved: filtered_244700959_20240525_1007-20240525_1022_standardized_10s.csv
# Moved: filtered_538009752_20240530_2226-20240530_2241_standardized_10s.csv
# Moved: filtered_219945000_20240519_2242-20240519_2257_standardized_10s.csv
# Moved: filtered_352001616_20240604_1024-20240604_1039_standardized_10s.csv
# Moved: filtered_563209600_20240324_0111-20240324_0126_standardized_10s.csv
# Moved: filtered_266150000_20240529_2100-20240529_2115_standardized_10s.csv
# Moved: filtered_352002271_20240622_1432-20240622_1447_standardized_10s.csv
# Moved: filtered_256717000_20240620_0316-20240620_0331_standardized_10s.csv
# Moved: filtered_257071620_20240412_0743-20240412_0758_standardized_10s.csv
# Moved: filtered_209184000_20241124_0713-20241124_0728_standardized_10s.csv
# Moved: filtered_538005498_20240626_2007-20240626_2022_standardized_10s.csv
# Moved: filtered_210586000_20240330_1251-20240330_1306_standardized_10s.csv
# Moved: filtered_219022257_20240520_0343-20240520_0358_standardized_10s.csv
# Moved: filtered_372918000_20240620_1330-20240620_1345_standardized_10s.csv
# Moved: filtered_257341000_20241127_0830-20241127_0845_standardized_10s.csv
# Moved: filtered_231809000_20240613_1549-20240613_1604_standardized_10s.csv
# Moved: filtered_538010193_20240630_1425-20240630_1440_standardized_10s.csv
# Moved: filtered_211219630_20241122_1627-20241122_1642_standardized_10s.csv
# Moved: filtered_244870189_20240524_1012-20240524_1027_standardized_10s.csv
# Moved: filtered_257960000_20240409_1501-20240409_1516_standardized_10s.csv
# Moved: filtered_257643000_20241123_0814-20241123_0829_standardized_10s.csv
# Moved: filtered_257516000_20240413_1340-20240413_1355_standardized_10s.csv
# Moved: filtered_375103000_20240307_0442-20240307_0457_standardized_10s.csv
# Moved: filtered_229807000_20240422_0247-20240422_0302_standardized_10s.csv
# Moved: filtered_259110000_20240523_1455-20240523_1510_standardized_10s.csv
# Moved: filtered_636017986_20240630_0246-20240630_0301_standardized_10s.csv
# Moved: filtered_219023786_20240627_0107-20240627_0122_standardized_10s.csv
# Moved: filtered_372867000_20240613_0720-20240613_0734_standardized_10s.csv
# Moved: filtered_251141000_20240531_1245-20240531_1300_standardized_10s.csv
# Moved: filtered_257115000_20240529_2042-20240529_2057_standardized_10s.csv
# Moved: filtered_257066860_20240530_2103-20240530_2118_standardized_10s.csv
# Moved: filtered_219027298_20240519_0952-20240519_1007_standardized_10s.csv
# Moved: filtered_258824000_20240307_1029-20240307_1044_standardized_10s.csv
# Moved: filtered_219244000_20240314_2116-20240314_2131_standardized_10s.csv
# Moved: filtered_219019936_20240527_1457-20240527_1512_standardized_10s.csv
# Moved: filtered_244103000_20240627_0747-20240627_0801_standardized_10s.csv
# Moved: filtered_246051000_20240305_1239-20240305_1254_standardized_10s.csv
# Moved: filtered_352003316_20240403_0025-20240403_0040_standardized_10s.csv
# Moved: filtered_538010364_20240627_1056-20240627_1111_standardized_10s.csv
# Moved: filtered_265177000_20240602_0840-20240602_0855_standardized_10s.csv
# Moved: filtered_244103000_20240623_0917-20240623_0931_standardized_10s.csv
# Moved: filtered_215698000_20240331_0510-20240331_0524_standardized_10s.csv
# Moved: filtered_314633000_20240307_2119-20240307_2134_standardized_10s.csv
# Moved: filtered_311000987_20240421_0014-20240421_0029_standardized_10s.csv
# Moved: filtered_244321000_20240630_0812-20240630_0827_standardized_10s.csv
# Moved: filtered_219026490_20241122_0315-20241122_0330_standardized_10s.csv
# Moved: filtered_210445000_20240630_0321-20240630_0336_standardized_10s.csv
# Moved: filtered_257182000_20240312_1958-20240312_2013_standardized_10s.csv
# Moved: filtered_248208000_20240311_0208-20240311_0223_standardized_10s.csv
# Moved: filtered_210290000_20240530_2332-20240530_2346_standardized_10s.csv
# Moved: filtered_244347000_20240426_1659-20240426_1714_standardized_10s.csv
# Moved: filtered_219339000_20240615_0258-20240615_0313_standardized_10s.csv
# Moved: filtered_413279020_20240314_0302-20240314_0317_standardized_10s.csv
# Moved: filtered_255806446_20240524_0900-20240524_0914_standardized_10s.csv
# Moved: filtered_256505000_20240608_1406-20240608_1421_standardized_10s.csv
# Moved: filtered_636017971_20240308_1550-20240308_1605_standardized_10s.csv
# Moved: filtered_257064430_20240616_1707-20240616_1722_standardized_10s.csv
# Moved: filtered_538009036_20240408_2146-20240408_2201_standardized_10s.csv
# Moved: filtered_255806344_20240322_0651-20240322_0705_standardized_10s.csv
# Moved: filtered_357340000_20240324_2109-20240324_2124_standardized_10s.csv
# Moved: filtered_244279000_20240612_2320-20240612_2335_standardized_10s.csv
# Moved: filtered_229077000_20240623_1622-20240623_1637_standardized_10s.csv
# Moved: filtered_220339000_20240618_0652-20240618_0707_standardized_10s.csv
# Moved: filtered_255924000_20240523_0244-20240523_0259_standardized_10s.csv
# Moved: filtered_256525000_20240625_1408-20240625_1423_standardized_10s.csv
# Moved: filtered_244656000_20240629_0510-20240629_0525_standardized_10s.csv
# Moved: filtered_305662000_20240614_0719-20240614_0734_standardized_10s.csv
# Moved: filtered_232025009_20240301_2116-20240301_2131_standardized_10s.csv
# Moved: filtered_230601000_20240624_0531-20240624_0546_standardized_10s.csv
# Moved: filtered_244590000_20240519_1103-20240519_1118_standardized_10s.csv
# Moved: filtered_304010515_20240313_0523-20240313_0538_standardized_10s.csv
# Moved: filtered_563175800_20240607_1149-20240607_1203_standardized_10s.csv
# Moved: filtered_275525000_20240624_1709-20240624_1724_standardized_10s.csv
# Moved: filtered_212669000_20240316_0015-20240316_0030_standardized_10s.csv
# Moved: filtered_314721000_20240620_1618-20240620_1633_standardized_10s.csv
# Moved: filtered_376128000_20241128_0022-20241128_0037_standardized_10s.csv
# Moved: filtered_259222000_20241122_0130-20241122_0145_standardized_10s.csv
# Moved: filtered_538004027_20240525_0115-20240525_0130_standardized_10s.csv
# Moved: filtered_538009659_20240521_2108-20240521_2123_standardized_10s.csv
# Moved: filtered_215672000_20240610_1524-20240610_1539_standardized_10s.csv
# Moved: filtered_636022982_20240325_1945-20240325_2000_standardized_10s.csv
# Moved: filtered_261004881_20240527_2200-20240527_2214_standardized_10s.csv
# Moved: filtered_257203000_20240604_1251-20240604_1306_standardized_10s.csv
# Moved: filtered_219021235_20240325_0145-20240325_0200_standardized_10s.csv
# Moved: filtered_273391650_20240618_0724-20240618_0739_standardized_10s.csv
# Moved: filtered_219281000_20240401_0537-20240401_0552_standardized_10s.csv
# Moved: filtered_636021568_20241123_1500-20241123_1515_standardized_10s.csv
# Moved: filtered_219022257_20240420_2008-20240420_2023_standardized_10s.csv
# Moved: filtered_259029000_20240629_0854-20240629_0909_standardized_10s.csv
# Moved: filtered_255915611_20240330_0043-20240330_0058_standardized_10s.csv
# Moved: filtered_355390000_20240318_0738-20240318_0753_standardized_10s.csv
# Moved: filtered_314189000_20240618_1221-20240618_1236_standardized_10s.csv
# Moved: filtered_219007477_20240620_1926-20240620_1941_standardized_10s.csv
# Moved: filtered_219419000_20240327_0255-20240327_0310_standardized_10s.csv
# Moved: filtered_219459000_20240627_1856-20240627_1910_standardized_10s.csv
# Moved: filtered_235060914_20241122_0454-20241122_0509_standardized_10s.csv
# Moved: filtered_266472000_20240304_0416-20240304_0431_standardized_10s.csv
# Moved: filtered_355444000_20240301_1347-20240301_1402_standardized_10s.csv
# Moved: filtered_372078000_20240521_1711-20240521_1726_standardized_10s.csv
# Moved: filtered_538005397_20240307_1530-20240307_1545_standardized_10s.csv
# Moved: filtered_232023509_20240626_0950-20240626_1005_standardized_10s.csv
# Moved: filtered_245945000_20240530_1958-20240530_2013_standardized_10s.csv
# Moved: filtered_245593000_20240613_1901-20240613_1916_standardized_10s.csv
# Moved: filtered_636016416_20240309_0730-20240309_0745_standardized_10s.csv
# Moved: filtered_258407000_20240301_2058-20240301_2113_standardized_10s.csv
# Moved: filtered_538006785_20240521_0515-20240521_0530_standardized_10s.csv
# Moved: filtered_219825000_20240521_2047-20240521_2102_standardized_10s.csv
# Moved: filtered_305279000_20240618_1230-20240618_1245_standardized_10s.csv
# Moved: filtered_235102532_20240330_0511-20240330_0526_standardized_10s.csv
# Moved: filtered_565592000_20240316_1453-20240316_1508_standardized_10s.csv
# Moved: filtered_613003808_20240409_0121-20240409_0135_standardized_10s.csv
# Moved: filtered_314207000_20240603_0017-20240603_0032_standardized_10s.csv
# Moved: filtered_636017409_20240402_2030-20240402_2045_standardized_10s.csv
# Moved: filtered_205743000_20240623_0949-20240623_1004_standardized_10s.csv
# Moved: filtered_219023786_20240519_2234-20240519_2249_standardized_10s.csv
# Moved: filtered_219027989_20240313_0217-20240313_0232_standardized_10s.csv
# Moved: filtered_447173000_20240330_0629-20240330_0644_standardized_10s.csv
# Moved: filtered_219592000_20240429_2145-20240429_2159_standardized_10s.csv
# Moved: filtered_273542050_20240601_1335-20240601_1350_standardized_10s.csv
# Moved: filtered_563025500_20241123_1840-20241123_1855_standardized_10s.csv
# Moved: filtered_311697000_20240416_1750-20240416_1805_standardized_10s.csv
# Moved: filtered_232012490_20240314_1423-20240314_1438_standardized_10s.csv
# Moved: filtered_538006140_20240606_1622-20240606_1637_standardized_10s.csv
# Moved: filtered_219301000_20240319_2246-20240319_2301_standardized_10s.csv
# Moved: filtered_244519000_20240304_2147-20240304_2202_standardized_10s.csv
# Moved: filtered_314238000_20240620_0957-20240620_1012_standardized_10s.csv
# Moved: filtered_230006000_20240324_0647-20240324_0702_standardized_10s.csv
# Moved: filtered_219244000_20240618_1215-20240618_1230_standardized_10s.csv
# Moved: filtered_215173000_20240520_2118-20240520_2133_standardized_10s.csv
# Moved: filtered_265586020_20240626_0044-20240626_0059_standardized_10s.csv
# Moved: filtered_255801580_20240526_0855-20240526_0910_standardized_10s.csv
# Moved: filtered_538007957_20240630_1719-20240630_1734_standardized_10s.csv
# Moved: filtered_219613000_20240529_0245-20240529_0300_standardized_10s.csv
# Moved: filtered_235104739_20240423_0338-20240423_0353_standardized_10s.csv
# Moved: filtered_220339000_20240308_1019-20240308_1034_standardized_10s.csv
# Moved: filtered_248006000_20240303_1727-20240303_1742_standardized_10s.csv
# Moved: filtered_257601000_20241126_0811-20241126_0825_standardized_10s.csv
# Moved: filtered_244569000_20240326_0536-20240326_0551_standardized_10s.csv
# Moved: filtered_211879700_20240313_1409-20240313_1424_standardized_10s.csv
# Moved: filtered_232046824_20240610_0837-20240610_0851_standardized_10s.csv
# Moved: filtered_219437000_20240409_2041-20240409_2056_standardized_10s.csv
# Moved: filtered_219043000_20240314_2003-20240314_2018_standardized_10s.csv
# Moved: filtered_636091866_20240607_1929-20240607_1944_standardized_10s.csv
# Moved: filtered_357169000_20240615_1609-20240615_1624_standardized_10s.csv
# Moved: filtered_241618000_20240622_2003-20240622_2018_standardized_10s.csv
# Moved: filtered_246667000_20240313_1553-20240313_1608_standardized_10s.csv
# Moved: filtered_212376000_20240622_0157-20240622_0211_standardized_10s.csv
# Moved: filtered_538010377_20240302_1012-20240302_1027_standardized_10s.csv
# Moved: filtered_265177000_20240614_0855-20240614_0910_standardized_10s.csv
# Moved: filtered_244013009_20240320_1528-20240320_1543_standardized_10s.csv
# Moved: filtered_368160000_20240317_1222-20240317_1237_standardized_10s.csv
# Moved: filtered_219002827_20240611_0000-20240611_0014_standardized_10s.csv
# Moved: filtered_246854000_20240628_0309-20240628_0324_standardized_10s.csv
# Moved: filtered_219304000_20241122_1116-20241122_1131_standardized_10s.csv
# Moved: filtered_231836000_20240412_0525-20240412_0540_standardized_10s.csv
# Moved: filtered_219543000_20240529_0638-20240529_0653_standardized_10s.csv
# Moved: filtered_219026706_20240401_1230-20240401_1245_standardized_10s.csv
# Moved: filtered_636093238_20240603_2040-20240603_2055_standardized_10s.csv
# Moved: filtered_219018271_20240317_0305-20240317_0320_standardized_10s.csv
# Moved: filtered_305411000_20240612_1846-20240612_1901_standardized_10s.csv
# Script execution completed.

# %%
import os
import numpy as np
import pandas as pd
import random
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
import matplotlib.pyplot as plt
import seaborn as sns

# Paths to the folders
folder_underway = "../5_Data_Pipeline/input/underway_using_engine"
folder_sailing = "../5_Data_Pipeline/input/under_way_sailing"

# Parameters
sequence_length = 60  # Length of time sequences (e.g., 1 hour if sampled every minute)
features = ['SOG', 'COG', 'Heading']  # Columns to use as features
num_samples = 900  # Number of files to use per category (undersampling)

# Function to randomly select files for undersampling
def get_sampled_files(folder, num_samples):
    all_files = [f for f in os.listdir(folder) if f.endswith('.csv')]
    return random.sample(all_files, min(num_samples, len(all_files)))

# Function to load and preprocess data
def load_and_preprocess_data(folder, file_list, label, sequence_length, features):
    data = []
    labels = []
    file_origins = []
    for file in file_list:
        df = pd.read_csv(os.path.join(folder, file))
        # Normalize SOG
        scaler = MinMaxScaler()
        df['SOG'] = scaler.fit_transform(df[['SOG']])
        
        # Encode COG and Heading cyclically
        df['COG_x'] = np.sin(np.radians(df['COG']))
        df['COG_y'] = np.cos(np.radians(df['COG']))
        df['Heading_x'] = np.sin(np.radians(df['Heading']))
        df['Heading_y'] = np.cos(np.radians(df['Heading']))
        
        # Select features
        feature_columns = ['SOG', 'COG_x', 'COG_y', 'Heading_x', 'Heading_y']
        df = df[feature_columns]
        
        # Create sequences
        for i in range(len(df) - sequence_length + 1):
            sequence = df.iloc[i:i + sequence_length].values
            data.append(sequence)
            labels.append(label)
            file_origins.append(file)  # Track the file name for this sequence
    return np.array(data), np.array(labels), np.array(file_origins)

# Select a balanced subset of files
files_underway = get_sampled_files(folder_underway, num_samples)
files_sailing = get_sampled_files(folder_sailing, num_samples)

# Load data from both folders
data_underway, labels_underway, files_underway = load_and_preprocess_data(folder_underway, files_underway, 0, sequence_length, features)
data_sailing, labels_sailing, files_sailing = load_and_preprocess_data(folder_sailing, files_sailing, 1, sequence_length, features)

# Combine data
X = np.concatenate([data_underway, data_sailing], axis=0)
y = np.concatenate([labels_underway, labels_sailing], axis=0)
file_origins = np.concatenate([files_underway, files_sailing], axis=0)

# Train-test split (include file origins)
X_train, X_test, y_train, y_test, files_train, files_test = train_test_split(
    X, y, file_origins, test_size=0.2, random_state=42, stratify=y
)

# Build the LSTM model
model = Sequential([
    LSTM(64, input_shape=(sequence_length, X.shape[2]), return_sequences=True),
    Dropout(0.3),
    LSTM(32),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid')  # Binary classification
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=200,
    batch_size=32,
    callbacks=[early_stopping],
    verbose=1
)

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f"Test Accuracy: {accuracy:.2f}")

# Predict probabilities and binary labels
y_pred_prob = model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype('int')

# Store results in a DataFrame
results = pd.DataFrame({
    'file': files_test,
    'true_label': y_test,
    'predicted_label': y_pred.flatten()
})

# Add a column for misclassification
results['misclassified'] = results['true_label'] != results['predicted_label']

# Group by file and count misclassifications
misclassified_summary = results.groupby('file')['misclassified'].sum().reset_index()
misclassified_summary = misclassified_summary.sort_values(by='misclassified', ascending=False)

# Display files with the most misclassifications
print("Files with the most misclassified sequences:")
print(misclassified_summary.head(10))

# Save misclassification summary to a CSV file
misclassified_summary.to_csv('misclassified_summary.csv', index=False)

# Plot Learning Curves
def plot_learning_curve(history):
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

# ROC Curve
def plot_roc_curve(y_true, y_pred_prob):
    fpr, tpr, thresholds = roc_curve(y_true, y_pred_prob)
    roc_auc = auc(fpr, tpr)

    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, color='b', label=f'ROC curve (area = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
    plt.title('Receiver Operating Characteristic Curve')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend(loc='lower right')
    plt.show()

# Confusion Matrix
def plot_confusion_matrix(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Underway', 'Sailing'], yticklabels=['Underway', 'Sailing'])
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.show()

# Print Classification Report
def print_classification_report(y_true, y_pred):
    print(classification_report(y_true, y_pred))

# Visualizations and Metrics
plot_learning_curve(history)
plot_roc_curve(y_test, y_pred_prob)
plot_confusion_matrix(y_test, y_pred)
print_classification_report(y_test, y_pred)
# Out:
# Epoch 1/200
# 1116/1116 [==============================] - 21s 10ms/step - loss: 0.6933 - accuracy: 0.5041 - val_loss: 0.6915 - val_accuracy: 0.5110
# Epoch 2/200
# 1116/1116 [==============================] - 9s 8ms/step - loss: 0.6919 - accuracy: 0.5140 - val_loss: 0.6943 - val_accuracy: 0.5058
# Epoch 3/200
# 1116/1116 [==============================] - 9s 8ms/step - loss: 0.6939 - accuracy: 0.5013 - val_loss: 0.6930 - val_accuracy: 0.5084
# Epoch 4/200
# 1116/1116 [==============================] - 9s 8ms/step - loss: 0.6916 - accuracy: 0.5029 - val_loss: 0.6887 - val_accuracy: 0.5053
# Epoch 5/200
# 1116/1116 [==============================] - 9s 8ms/step - loss: 0.6900 - accuracy: 0.5077 - val_loss: 0.6879 - val_accuracy: 0.5172
# Epoch 6/200
# 1116/1116 [==============================] - 9s 8ms/step - loss: 0.6899 - accuracy: 0.5132 - val_loss: 0.6870 - val_accuracy: 0.5068
# Epoch 7/200
# 1116/1116 [==============================] - 9s 8ms/step - loss: 0.6896 - accuracy: 0.5087 - val_loss: 0.6874 - val_accuracy: 0.5132
# Epoch 8/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.6889 - accuracy: 0.5134 - val_loss: 0.6872 - val_accuracy: 0.5131
# Epoch 9/200
# 1116/1116 [==============================] - 11s 10ms/step - loss: 0.6880 - accuracy: 0.5121 - val_loss: 0.6864 - val_accuracy: 0.5143
# Epoch 10/200
# 1116/1116 [==============================] - 11s 10ms/step - loss: 0.6857 - accuracy: 0.5206 - val_loss: 0.6850 - val_accuracy: 0.5179
# Epoch 11/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.6836 - accuracy: 0.5252 - val_loss: 0.6819 - val_accuracy: 0.5240
# Epoch 12/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.6816 - accuracy: 0.5287 - val_loss: 0.6789 - val_accuracy: 0.5278
# Epoch 13/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.6793 - accuracy: 0.5323 - val_loss: 0.6739 - val_accuracy: 0.5244
# Epoch 14/200
# 1116/1116 [==============================] - 9s 8ms/step - loss: 0.6860 - accuracy: 0.5184 - val_loss: 0.6787 - val_accuracy: 0.5215
# Epoch 15/200
# 1116/1116 [==============================] - 9s 8ms/step - loss: 0.6801 - accuracy: 0.5241 - val_loss: 0.6911 - val_accuracy: 0.5171
# Epoch 16/200
# 1116/1116 [==============================] - 9s 8ms/step - loss: 0.6838 - accuracy: 0.5187 - val_loss: 0.6807 - val_accuracy: 0.5197
# Epoch 17/200
# 1116/1116 [==============================] - 9s 8ms/step - loss: 0.6800 - accuracy: 0.5256 - val_loss: 0.6765 - val_accuracy: 0.5287
# Epoch 18/200
# 1116/1116 [==============================] - 9s 8ms/step - loss: 0.6785 - accuracy: 0.5324 - val_loss: 0.6800 - val_accuracy: 0.5299
# Epoch 19/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.6821 - accuracy: 0.5335 - val_loss: 0.6775 - val_accuracy: 0.5338
# Epoch 20/200
# 1116/1116 [==============================] - 9s 8ms/step - loss: 0.6774 - accuracy: 0.5349 - val_loss: 0.6745 - val_accuracy: 0.5407
# Epoch 21/200
# 1116/1116 [==============================] - 9s 8ms/step - loss: 0.6769 - accuracy: 0.5310 - val_loss: 0.6739 - val_accuracy: 0.5422
# Epoch 22/200
# 1116/1116 [==============================] - 9s 8ms/step - loss: 0.6734 - accuracy: 0.5404 - val_loss: 0.6657 - val_accuracy: 0.5497
# Epoch 23/200
# 1116/1116 [==============================] - 9s 8ms/step - loss: 0.6711 - accuracy: 0.5425 - val_loss: 0.6707 - val_accuracy: 0.5348
# Epoch 24/200
# 1116/1116 [==============================] - 9s 8ms/step - loss: 0.6678 - accuracy: 0.5469 - val_loss: 0.6695 - val_accuracy: 0.5431
# Epoch 25/200
# 1116/1116 [==============================] - 9s 8ms/step - loss: 0.6706 - accuracy: 0.5460 - val_loss: 0.6763 - val_accuracy: 0.5519
# Epoch 26/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.6691 - accuracy: 0.5549 - val_loss: 0.6624 - val_accuracy: 0.5561
# Epoch 27/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.6580 - accuracy: 0.5650 - val_loss: 0.6549 - val_accuracy: 0.5682
# Epoch 28/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.6574 - accuracy: 0.5674 - val_loss: 0.6655 - val_accuracy: 0.5540
# Epoch 29/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.6562 - accuracy: 0.5626 - val_loss: 0.6472 - val_accuracy: 0.5727
# Epoch 30/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.6544 - accuracy: 0.5676 - val_loss: 0.6513 - val_accuracy: 0.5720
# Epoch 31/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.6466 - accuracy: 0.5747 - val_loss: 0.6440 - val_accuracy: 0.5754
# Epoch 32/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.6493 - accuracy: 0.5729 - val_loss: 0.6469 - val_accuracy: 0.5664
# Epoch 33/200
# 1116/1116 [==============================] - 9s 8ms/step - loss: 0.6442 - accuracy: 0.5777 - val_loss: 0.6445 - val_accuracy: 0.5715
# Epoch 34/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.6397 - accuracy: 0.5787 - val_loss: 0.6447 - val_accuracy: 0.5808
# Epoch 35/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.6397 - accuracy: 0.5808 - val_loss: 0.6665 - val_accuracy: 0.5660
# Epoch 36/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.6551 - accuracy: 0.5738 - val_loss: 0.6543 - val_accuracy: 0.5647
# Epoch 37/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.6467 - accuracy: 0.5747 - val_loss: 0.6445 - val_accuracy: 0.5700
# Epoch 38/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.6397 - accuracy: 0.5831 - val_loss: 0.6586 - val_accuracy: 0.5694
# Epoch 39/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.6352 - accuracy: 0.5874 - val_loss: 0.6314 - val_accuracy: 0.5789
# Epoch 40/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.6305 - accuracy: 0.5870 - val_loss: 0.6300 - val_accuracy: 0.5793
# Epoch 41/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.6310 - accuracy: 0.5905 - val_loss: 0.6380 - val_accuracy: 0.5754
# Epoch 42/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.6317 - accuracy: 0.5840 - val_loss: 0.6265 - val_accuracy: 0.5885
# Epoch 43/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.6246 - accuracy: 0.5932 - val_loss: 0.6372 - val_accuracy: 0.5836
# Epoch 44/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.6348 - accuracy: 0.5817 - val_loss: 0.6252 - val_accuracy: 0.5846
# Epoch 45/200
# 1116/1116 [==============================] - 43s 39ms/step - loss: 0.6284 - accuracy: 0.5924 - val_loss: 0.6322 - val_accuracy: 0.5886
# Epoch 46/200
# 1116/1116 [==============================] - 72s 65ms/step - loss: 0.6248 - accuracy: 0.5938 - val_loss: 0.6237 - val_accuracy: 0.5800
# Epoch 47/200
# 1116/1116 [==============================] - 77s 69ms/step - loss: 0.6193 - accuracy: 0.5969 - val_loss: 0.6317 - val_accuracy: 0.5909
# Epoch 48/200
# 1116/1116 [==============================] - 83s 75ms/step - loss: 0.6158 - accuracy: 0.6026 - val_loss: 0.6123 - val_accuracy: 0.6019
# Epoch 49/200
# 1116/1116 [==============================] - 80s 72ms/step - loss: 0.6182 - accuracy: 0.6000 - val_loss: 0.6184 - val_accuracy: 0.5957
# Epoch 50/200
# 1116/1116 [==============================] - 52s 47ms/step - loss: 0.6155 - accuracy: 0.6045 - val_loss: 0.6143 - val_accuracy: 0.5938
# Epoch 51/200
# 1116/1116 [==============================] - 16s 14ms/step - loss: 0.6194 - accuracy: 0.6016 - val_loss: 0.6230 - val_accuracy: 0.6028
# Epoch 52/200
# 1116/1116 [==============================] - 13s 12ms/step - loss: 0.6197 - accuracy: 0.6004 - val_loss: 0.6142 - val_accuracy: 0.6029
# Epoch 53/200
# 1116/1116 [==============================] - 12s 10ms/step - loss: 0.6083 - accuracy: 0.6112 - val_loss: 0.6114 - val_accuracy: 0.6041
# Epoch 54/200
# 1116/1116 [==============================] - 11s 10ms/step - loss: 0.6096 - accuracy: 0.6112 - val_loss: 0.6039 - val_accuracy: 0.6085
# Epoch 55/200
# 1116/1116 [==============================] - 11s 10ms/step - loss: 0.6063 - accuracy: 0.6098 - val_loss: 0.6060 - val_accuracy: 0.6120
# Epoch 56/200
# 1116/1116 [==============================] - 12s 10ms/step - loss: 0.6072 - accuracy: 0.6114 - val_loss: 0.5982 - val_accuracy: 0.6196
# Epoch 57/200
# 1116/1116 [==============================] - 11s 10ms/step - loss: 0.6013 - accuracy: 0.6158 - val_loss: 0.6011 - val_accuracy: 0.6185
# Epoch 58/200
# 1116/1116 [==============================] - 11s 10ms/step - loss: 0.6049 - accuracy: 0.6129 - val_loss: 0.6053 - val_accuracy: 0.6137
# Epoch 59/200
# 1116/1116 [==============================] - 11s 10ms/step - loss: 0.6013 - accuracy: 0.6172 - val_loss: 0.5973 - val_accuracy: 0.6198
# Epoch 60/200
# 1116/1116 [==============================] - 11s 10ms/step - loss: 0.6028 - accuracy: 0.6125 - val_loss: 0.6398 - val_accuracy: 0.5748
# Epoch 61/200
# 1116/1116 [==============================] - 11s 10ms/step - loss: 0.6110 - accuracy: 0.6117 - val_loss: 0.6005 - val_accuracy: 0.6181
# Epoch 62/200
# 1116/1116 [==============================] - 11s 10ms/step - loss: 0.5966 - accuracy: 0.6244 - val_loss: 0.5975 - val_accuracy: 0.6244
# Epoch 63/200
# 1116/1116 [==============================] - 11s 10ms/step - loss: 0.5993 - accuracy: 0.6220 - val_loss: 0.6161 - val_accuracy: 0.6062
# Epoch 64/200
# 1116/1116 [==============================] - 11s 10ms/step - loss: 0.6031 - accuracy: 0.6240 - val_loss: 0.5921 - val_accuracy: 0.6276
# Epoch 65/200
# 1116/1116 [==============================] - 11s 10ms/step - loss: 0.5928 - accuracy: 0.6284 - val_loss: 0.6004 - val_accuracy: 0.6304
# Epoch 66/200
# 1116/1116 [==============================] - 11s 10ms/step - loss: 0.5892 - accuracy: 0.6333 - val_loss: 0.5749 - val_accuracy: 0.6430
# Epoch 67/200
# 1116/1116 [==============================] - 14s 13ms/step - loss: 0.5889 - accuracy: 0.6307 - val_loss: 0.5835 - val_accuracy: 0.6352
# Epoch 68/200
# 1116/1116 [==============================] - 18s 16ms/step - loss: 0.5788 - accuracy: 0.6425 - val_loss: 0.5931 - val_accuracy: 0.6272
# Epoch 69/200
# 1116/1116 [==============================] - 17s 15ms/step - loss: 0.5744 - accuracy: 0.6452 - val_loss: 0.5607 - val_accuracy: 0.6556
# Epoch 70/200
# 1116/1116 [==============================] - 18s 16ms/step - loss: 0.5673 - accuracy: 0.6504 - val_loss: 0.5669 - val_accuracy: 0.6502
# Epoch 71/200
# 1116/1116 [==============================] - 17s 15ms/step - loss: 0.5759 - accuracy: 0.6469 - val_loss: 0.5790 - val_accuracy: 0.6492
# Epoch 72/200
# 1116/1116 [==============================] - 17s 16ms/step - loss: 0.5656 - accuracy: 0.6529 - val_loss: 0.5591 - val_accuracy: 0.6519
# Epoch 73/200
# 1116/1116 [==============================] - 17s 16ms/step - loss: 0.5610 - accuracy: 0.6573 - val_loss: 0.5526 - val_accuracy: 0.6651
# Epoch 74/200
# 1116/1116 [==============================] - 18s 16ms/step - loss: 0.5595 - accuracy: 0.6602 - val_loss: 0.5852 - val_accuracy: 0.6458
# Epoch 75/200
# 1116/1116 [==============================] - 17s 15ms/step - loss: 0.5647 - accuracy: 0.6557 - val_loss: 0.5562 - val_accuracy: 0.6570
# Epoch 76/200
# 1116/1116 [==============================] - 17s 15ms/step - loss: 0.5635 - accuracy: 0.6541 - val_loss: 0.5650 - val_accuracy: 0.6490
# Epoch 77/200
# 1116/1116 [==============================] - 17s 15ms/step - loss: 0.5671 - accuracy: 0.6509 - val_loss: 0.5871 - val_accuracy: 0.6410
# Epoch 78/200
# 1116/1116 [==============================] - 17s 15ms/step - loss: 0.5774 - accuracy: 0.6464 - val_loss: 0.5793 - val_accuracy: 0.6533
# Epoch 79/200
# 1116/1116 [==============================] - 17s 15ms/step - loss: 0.5595 - accuracy: 0.6583 - val_loss: 0.5538 - val_accuracy: 0.6654
# Epoch 80/200
# 1116/1116 [==============================] - 17s 15ms/step - loss: 0.5517 - accuracy: 0.6659 - val_loss: 0.5569 - val_accuracy: 0.6577
# Epoch 81/200
# 1116/1116 [==============================] - 17s 15ms/step - loss: 0.5611 - accuracy: 0.6609 - val_loss: 0.5614 - val_accuracy: 0.6517
# Epoch 82/200
# 1116/1116 [==============================] - 17s 15ms/step - loss: 0.5516 - accuracy: 0.6701 - val_loss: 0.5432 - val_accuracy: 0.6718
# Epoch 83/200
# 1116/1116 [==============================] - 17s 15ms/step - loss: 0.5428 - accuracy: 0.6728 - val_loss: 0.5444 - val_accuracy: 0.6747
# Epoch 84/200
# 1116/1116 [==============================] - 17s 15ms/step - loss: 0.5413 - accuracy: 0.6765 - val_loss: 0.5444 - val_accuracy: 0.6766
# Epoch 85/200
# 1116/1116 [==============================] - 17s 15ms/step - loss: 0.5403 - accuracy: 0.6746 - val_loss: 0.5379 - val_accuracy: 0.6832
# Epoch 86/200
# 1116/1116 [==============================] - 18s 16ms/step - loss: 0.5477 - accuracy: 0.6716 - val_loss: 0.5463 - val_accuracy: 0.6755
# Epoch 87/200
# 1116/1116 [==============================] - 17s 15ms/step - loss: 0.5381 - accuracy: 0.6815 - val_loss: 0.5450 - val_accuracy: 0.6775
# Epoch 88/200
# 1116/1116 [==============================] - 17s 16ms/step - loss: 0.5362 - accuracy: 0.6816 - val_loss: 0.5585 - val_accuracy: 0.6558
# Epoch 89/200
# 1116/1116 [==============================] - 15s 13ms/step - loss: 0.5379 - accuracy: 0.6796 - val_loss: 0.5224 - val_accuracy: 0.6941
# Epoch 90/200
# 1116/1116 [==============================] - 11s 10ms/step - loss: 0.5314 - accuracy: 0.6872 - val_loss: 0.5229 - val_accuracy: 0.6897
# Epoch 91/200
# 1116/1116 [==============================] - 11s 10ms/step - loss: 0.5331 - accuracy: 0.6852 - val_loss: 0.5204 - val_accuracy: 0.6872
# Epoch 92/200
# 1116/1116 [==============================] - 11s 10ms/step - loss: 0.5291 - accuracy: 0.6862 - val_loss: 0.5197 - val_accuracy: 0.6935
# Epoch 93/200
# 1116/1116 [==============================] - 11s 10ms/step - loss: 0.5323 - accuracy: 0.6849 - val_loss: 0.5158 - val_accuracy: 0.7005
# Epoch 94/200
# 1116/1116 [==============================] - 14s 12ms/step - loss: 0.5293 - accuracy: 0.6913 - val_loss: 0.5294 - val_accuracy: 0.6892
# Epoch 95/200
# 1116/1116 [==============================] - 17s 15ms/step - loss: 0.5242 - accuracy: 0.6941 - val_loss: 0.5168 - val_accuracy: 0.7030
# Epoch 96/200
# 1116/1116 [==============================] - 18s 16ms/step - loss: 0.5121 - accuracy: 0.6982 - val_loss: 0.5038 - val_accuracy: 0.7030
# Epoch 97/200
# 1116/1116 [==============================] - 18s 16ms/step - loss: 0.5118 - accuracy: 0.7014 - val_loss: 0.5057 - val_accuracy: 0.7088
# Epoch 98/200
# 1116/1116 [==============================] - 17s 15ms/step - loss: 0.5150 - accuracy: 0.6983 - val_loss: 0.4956 - val_accuracy: 0.7096
# Epoch 99/200
# 1116/1116 [==============================] - 17s 15ms/step - loss: 0.5104 - accuracy: 0.7009 - val_loss: 0.4940 - val_accuracy: 0.7173
# Epoch 100/200
# 1116/1116 [==============================] - 17s 15ms/step - loss: 0.5090 - accuracy: 0.7034 - val_loss: 0.4984 - val_accuracy: 0.7061
# Epoch 101/200
# 1116/1116 [==============================] - 17s 16ms/step - loss: 0.4993 - accuracy: 0.7126 - val_loss: 0.4949 - val_accuracy: 0.7142
# Epoch 102/200
# 1116/1116 [==============================] - 17s 15ms/step - loss: 0.5119 - accuracy: 0.7055 - val_loss: 0.4860 - val_accuracy: 0.7204
# Epoch 103/200
# 1116/1116 [==============================] - 17s 15ms/step - loss: 0.5000 - accuracy: 0.7139 - val_loss: 0.4979 - val_accuracy: 0.7148
# Epoch 104/200
# 1116/1116 [==============================] - 17s 15ms/step - loss: 0.5013 - accuracy: 0.7127 - val_loss: 0.4860 - val_accuracy: 0.7240
# Epoch 105/200
# 1116/1116 [==============================] - 17s 15ms/step - loss: 0.4916 - accuracy: 0.7190 - val_loss: 0.4929 - val_accuracy: 0.7334
# Epoch 106/200
# 1116/1116 [==============================] - 17s 15ms/step - loss: 0.4992 - accuracy: 0.7211 - val_loss: 0.4799 - val_accuracy: 0.7308
# Epoch 107/200
# 1116/1116 [==============================] - 15s 13ms/step - loss: 0.5400 - accuracy: 0.6933 - val_loss: 0.5048 - val_accuracy: 0.7166
# Epoch 108/200
# 1116/1116 [==============================] - 11s 10ms/step - loss: 0.4934 - accuracy: 0.7235 - val_loss: 0.4848 - val_accuracy: 0.7302
# Epoch 109/200
# 1116/1116 [==============================] - 11s 10ms/step - loss: 0.4898 - accuracy: 0.7252 - val_loss: 0.4992 - val_accuracy: 0.7210
# Epoch 110/200
# 1116/1116 [==============================] - 11s 10ms/step - loss: 0.4940 - accuracy: 0.7218 - val_loss: 0.4729 - val_accuracy: 0.7369
# Epoch 111/200
# 1116/1116 [==============================] - 11s 10ms/step - loss: 0.4798 - accuracy: 0.7302 - val_loss: 0.4639 - val_accuracy: 0.7388
# Epoch 112/200
# 1116/1116 [==============================] - 11s 10ms/step - loss: 0.4822 - accuracy: 0.7305 - val_loss: 0.4670 - val_accuracy: 0.7405
# Epoch 113/200
# 1116/1116 [==============================] - 11s 10ms/step - loss: 0.5059 - accuracy: 0.7162 - val_loss: 0.4868 - val_accuracy: 0.7298
# Epoch 114/200
# 1116/1116 [==============================] - 11s 10ms/step - loss: 0.4808 - accuracy: 0.7304 - val_loss: 0.4815 - val_accuracy: 0.7314
# Epoch 115/200
# 1116/1116 [==============================] - 11s 10ms/step - loss: 0.4769 - accuracy: 0.7329 - val_loss: 0.4790 - val_accuracy: 0.7258
# Epoch 116/200
# 1116/1116 [==============================] - 11s 10ms/step - loss: 0.4675 - accuracy: 0.7384 - val_loss: 0.4433 - val_accuracy: 0.7583
# Epoch 117/200
# 1116/1116 [==============================] - 11s 10ms/step - loss: 0.4719 - accuracy: 0.7378 - val_loss: 0.4494 - val_accuracy: 0.7537
# Epoch 118/200
# 1116/1116 [==============================] - 11s 10ms/step - loss: 0.4634 - accuracy: 0.7441 - val_loss: 0.4604 - val_accuracy: 0.7516
# Epoch 119/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.4552 - accuracy: 0.7495 - val_loss: 0.4898 - val_accuracy: 0.7238
# Epoch 120/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.4476 - accuracy: 0.7502 - val_loss: 0.4852 - val_accuracy: 0.7331
# Epoch 121/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.4476 - accuracy: 0.7526 - val_loss: 0.4394 - val_accuracy: 0.7571
# Epoch 122/200
# 1116/1116 [==============================] - 11s 9ms/step - loss: 0.4437 - accuracy: 0.7574 - val_loss: 0.4367 - val_accuracy: 0.7596
# Epoch 123/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.4457 - accuracy: 0.7555 - val_loss: 0.4391 - val_accuracy: 0.7642
# Epoch 124/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.4525 - accuracy: 0.7517 - val_loss: 0.4343 - val_accuracy: 0.7571
# Epoch 125/200
# 1116/1116 [==============================] - 11s 9ms/step - loss: 0.4454 - accuracy: 0.7588 - val_loss: 0.4248 - val_accuracy: 0.7697
# Epoch 126/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.4435 - accuracy: 0.7606 - val_loss: 0.4281 - val_accuracy: 0.7746
# Epoch 127/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.4268 - accuracy: 0.7732 - val_loss: 0.4072 - val_accuracy: 0.7796
# Epoch 128/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.4201 - accuracy: 0.7706 - val_loss: 0.4076 - val_accuracy: 0.7835
# Epoch 129/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.4306 - accuracy: 0.7670 - val_loss: 0.4125 - val_accuracy: 0.7746
# Epoch 130/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.4230 - accuracy: 0.7725 - val_loss: 0.4381 - val_accuracy: 0.7693
# Epoch 131/200
# 1116/1116 [==============================] - 11s 9ms/step - loss: 0.4351 - accuracy: 0.7680 - val_loss: 0.4332 - val_accuracy: 0.7715
# Epoch 132/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.4321 - accuracy: 0.7676 - val_loss: 0.4193 - val_accuracy: 0.7748
# Epoch 133/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.4250 - accuracy: 0.7757 - val_loss: 0.4338 - val_accuracy: 0.7707
# Epoch 134/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.5048 - accuracy: 0.7167 - val_loss: 0.5226 - val_accuracy: 0.7026
# Epoch 135/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.4838 - accuracy: 0.7299 - val_loss: 0.4376 - val_accuracy: 0.7666
# Epoch 136/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.4375 - accuracy: 0.7616 - val_loss: 0.4099 - val_accuracy: 0.7761
# Epoch 137/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.4249 - accuracy: 0.7747 - val_loss: 0.3954 - val_accuracy: 0.7816
# Epoch 138/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.4976 - accuracy: 0.7216 - val_loss: 0.4772 - val_accuracy: 0.7322
# Epoch 139/200
# 1116/1116 [==============================] - 11s 10ms/step - loss: 0.4456 - accuracy: 0.7578 - val_loss: 0.4291 - val_accuracy: 0.7718
# Epoch 140/200
# 1116/1116 [==============================] - 11s 10ms/step - loss: 0.4097 - accuracy: 0.7803 - val_loss: 0.3878 - val_accuracy: 0.7942
# Epoch 141/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.4017 - accuracy: 0.7877 - val_loss: 0.3758 - val_accuracy: 0.8019
# Epoch 142/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.3942 - accuracy: 0.7893 - val_loss: 0.4074 - val_accuracy: 0.7786
# Epoch 143/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.4053 - accuracy: 0.7846 - val_loss: 0.4022 - val_accuracy: 0.7867
# Epoch 144/200
# 1116/1116 [==============================] - 11s 10ms/step - loss: 0.3931 - accuracy: 0.7911 - val_loss: 0.3893 - val_accuracy: 0.7889
# Epoch 145/200
# 1116/1116 [==============================] - 11s 9ms/step - loss: 0.3883 - accuracy: 0.7942 - val_loss: 0.3817 - val_accuracy: 0.7963
# Epoch 146/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.3958 - accuracy: 0.7937 - val_loss: 0.3824 - val_accuracy: 0.8010
# Epoch 147/200
# 1116/1116 [==============================] - 12s 10ms/step - loss: 0.3834 - accuracy: 0.8021 - val_loss: 0.3927 - val_accuracy: 0.7903
# Epoch 148/200
# 1116/1116 [==============================] - 11s 10ms/step - loss: 0.3729 - accuracy: 0.8048 - val_loss: 0.3611 - val_accuracy: 0.8138
# Epoch 149/200
# 1116/1116 [==============================] - 21s 19ms/step - loss: 0.3671 - accuracy: 0.8075 - val_loss: 0.3689 - val_accuracy: 0.8033
# Epoch 150/200
# 1116/1116 [==============================] - 15s 13ms/step - loss: 0.3817 - accuracy: 0.8038 - val_loss: 0.3979 - val_accuracy: 0.7927
# Epoch 151/200
# 1116/1116 [==============================] - 102s 91ms/step - loss: 0.3675 - accuracy: 0.8090 - val_loss: 0.3419 - val_accuracy: 0.8246
# Epoch 152/200
# 1116/1116 [==============================] - 56s 50ms/step - loss: 0.3700 - accuracy: 0.8069 - val_loss: 0.3601 - val_accuracy: 0.8096
# Epoch 153/200
# 1116/1116 [==============================] - 66s 59ms/step - loss: 0.3661 - accuracy: 0.8091 - val_loss: 0.3553 - val_accuracy: 0.8118
# Epoch 154/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.3514 - accuracy: 0.8166 - val_loss: 0.3516 - val_accuracy: 0.8171
# Epoch 155/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.3639 - accuracy: 0.8118 - val_loss: 0.3487 - val_accuracy: 0.8150
# Epoch 156/200
# 1116/1116 [==============================] - 11s 9ms/step - loss: 0.3511 - accuracy: 0.8190 - val_loss: 0.3343 - val_accuracy: 0.8248
# Epoch 157/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.3453 - accuracy: 0.8241 - val_loss: 0.3434 - val_accuracy: 0.8205
# Epoch 158/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.3465 - accuracy: 0.8212 - val_loss: 0.3141 - val_accuracy: 0.8349
# Epoch 159/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.3528 - accuracy: 0.8210 - val_loss: 0.3825 - val_accuracy: 0.7986
# Epoch 160/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.3430 - accuracy: 0.8254 - val_loss: 0.3490 - val_accuracy: 0.8264
# Epoch 161/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.4093 - accuracy: 0.7843 - val_loss: 0.5300 - val_accuracy: 0.6903
# Epoch 162/200
# 1116/1116 [==============================] - 16s 14ms/step - loss: 0.4536 - accuracy: 0.7503 - val_loss: 0.3959 - val_accuracy: 0.7898
# Epoch 163/200
# 1116/1116 [==============================] - 12s 11ms/step - loss: 0.3609 - accuracy: 0.8172 - val_loss: 0.3339 - val_accuracy: 0.8243
# Epoch 164/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.3356 - accuracy: 0.8285 - val_loss: 0.3188 - val_accuracy: 0.8359
# Epoch 165/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.3345 - accuracy: 0.8294 - val_loss: 0.3119 - val_accuracy: 0.8407
# Epoch 166/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.3265 - accuracy: 0.8354 - val_loss: 0.3292 - val_accuracy: 0.8293
# Epoch 167/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.3320 - accuracy: 0.8303 - val_loss: 0.3039 - val_accuracy: 0.8440
# Epoch 168/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.3272 - accuracy: 0.8350 - val_loss: 0.2903 - val_accuracy: 0.8527
# Epoch 169/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.3120 - accuracy: 0.8429 - val_loss: 0.2936 - val_accuracy: 0.8497
# Epoch 170/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.3350 - accuracy: 0.8345 - val_loss: 0.3515 - val_accuracy: 0.8219
# Epoch 171/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.3246 - accuracy: 0.8373 - val_loss: 0.3076 - val_accuracy: 0.8513
# Epoch 172/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.4048 - accuracy: 0.7983 - val_loss: 0.3556 - val_accuracy: 0.8231
# Epoch 173/200
# 1116/1116 [==============================] - 10s 9ms/step - loss: 0.3532 - accuracy: 0.8246 - val_loss: 0.3217 - val_accuracy: 0.8416
# Epoch 174/200
# 1116/1116 [==============================] - 16s 14ms/step - loss: 0.3353 - accuracy: 0.8345 - val_loss: 0.3133 - val_accuracy: 0.8421
# Epoch 175/200
# 1116/1116 [==============================] - 16s 14ms/step - loss: 0.3287 - accuracy: 0.8373 - val_loss: 0.3029 - val_accuracy: 0.8514
# Epoch 176/200
# 1116/1116 [==============================] - 17s 15ms/step - loss: 0.3223 - accuracy: 0.8435 - val_loss: 0.3400 - val_accuracy: 0.8383
# Epoch 177/200
# 1116/1116 [==============================] - 17s 15ms/step - loss: 0.3217 - accuracy: 0.8405 - val_loss: 0.3051 - val_accuracy: 0.8485
# Epoch 178/200
# 1116/1116 [==============================] - 16s 14ms/step - loss: 0.3104 - accuracy: 0.8480 - val_loss: 0.3129 - val_accuracy: 0.8472
# Test Accuracy: 0.85
# 349/349 [==============================] - 2s 4ms/step
# Files with the most misclassified sequences:
#                                                    file  misclassified
# 369   filtered_219459000_20240313_1954-20240313_2009...             13
# 75    filtered_211870240_20240531_1817-20240531_1832...             10
# 493   filtered_220614000_20240520_0831-20240520_0845...             10
# 959   filtered_256956000_20240411_1410-20240411_1425...             10
# 1399  filtered_352001928_20240612_0201-20240612_0215...              9
# 488   filtered_220516000_20240629_0708-20240629_0722...              9
# 1166  filtered_265781000_20240418_1300-20240418_1315...              9
# 1538  filtered_538005408_20240403_0817-20240403_0832...              9
# 1793  filtered_636093289_20240521_0633-20240521_0648...              9
# 782   filtered_245953000_20240311_1731-20240311_1746...              9
#               precision    recall  f1-score   support
#
#            0       0.85      0.85      0.85      5580
#            1       0.85      0.85      0.85      5580
#
#     accuracy                           0.85     11160
#    macro avg       0.85      0.85      0.85     11160
# weighted avg       0.85      0.85      0.85     11160

# %%
# Save the model
model.save("navstat_classifier_binary_sail.h5")

# %% [markdown]
# # Explanation:
#
# ### 1. **Loading CSV Files from the Folder:**
#    - The function loops through the CSV files in the given folder, one by one. It reads each CSV file using `pandas.read_csv()` and processes the data.
#    - These CSV files contain the vessel's movement data with columns like `SOG`, `COG`, and `Heading`.
#
#    **Example of data loaded from a CSV file:**
#
#    | Timestamp | SOG | COG  | Heading |
#    |-----------|-----|------|---------|
#    | 00:00     | 5.4 | 45   | 60      |
#    | 00:01     | 5.6 | 47   | 61      |
#    | 00:02     | 5.7 | 50   | 62      |
#    | ...       | ... | ...  | ...     |
#
#    Here, **SOG** is the speed of the vessel, **COG** is the course (direction), and **Heading** is the heading angle.
#
# ### 2. **Normalization of `SOG` (Speed Over Ground):**
#    - The `SOG` column is normalized using a `MinMaxScaler`, which scales all values to a range between 0 and 1.
#    - **Normalization** is important because it brings different feature scales (e.g., speed vs. angle) to a similar range, making the training process more efficient.
#
#    **Before normalization:**
#
#    | Timestamp | SOG | COG  | Heading |
#    |-----------|-----|------|---------|
#    | 00:00     | 5.4 | 45   | 60      |
#    | 00:01     | 5.6 | 47   | 61      |
#
#    **After normalization:**
#
#    The new values for `SOG` are calculated using:
#    \[
#    \text{Normalized SOG} = \frac{\text{SOG} - \text{min(SOG)}}{\text{max(SOG)} - \text{min(SOG)}}
#    \]
#
#    | Timestamp | Normalized SOG | COG  | Heading |
#    |-----------|----------------|------|---------|
#    | 00:00     | 0.00           | 45   | 60      |
#    | 00:01     | 0.33           | 47   | 61      |
#
# ### 3. **Cyclic Encoding of `COG` and `Heading`:**
#    - Both `COG` (Course Over Ground) and `Heading` are angular values, and as such, they have a **cyclic nature**: 0 degrees is the same as 360 degrees.
#    - To properly handle this, **sine** and **cosine** transformations are applied:
#      \[
#      \text{COG}_x = \sin(\text{COG})
#      \]
#      \[
#      \text{COG}_y = \cos(\text{COG})
#      \]
#      Similarly for `Heading`:
#      \[
#      \text{Heading}_x = \sin(\text{Heading})
#      \]
#      \[
#      \text{Heading}_y = \cos(\text{Heading})
#      \]
#    - These transformations convert the angular values into two components that are easier for the model to learn from and capture cyclic relationships.
#
#    **Example before and after cyclic encoding:**
#
#    - **Before** (COG = 350 degrees, Heading = 10 degrees):
#
#    | Timestamp | COG | Heading |
#    |-----------|-----|---------|
#    | 00:00     | 350 | 10      |
#
#    - **After** (Apply sine and cosine transformations):
#
#    | Timestamp | COG_x      | COG_y      | Heading_x  | Heading_y  |
#    |-----------|------------|------------|------------|------------|
#    | 00:00     | 0.1745     | 0.9848     | 0.1736     | 0.9848     |
#
# ### 4. **Selecting Relevant Features:**
#    - After encoding the `COG` and `Heading`, the relevant features are selected: `SOG`, `COG_x`, `COG_y`, `Heading_x`, and `Heading_y`.
#    - These features represent the vessel's speed and directional information in a form that the LSTM model can process.
#
#    **Features selected for each time step:**
#
#    | Timestamp | Normalized SOG | COG_x      | COG_y      | Heading_x  | Heading_y  |
#    |-----------|----------------|------------|------------|------------|------------|
#    | 00:00     | 0.00           | 0.1745     | 0.9848     | 0.1736     | 0.9848     |
#
# ### 5. **Creating Sequences:**
#    - The LSTM model requires input data in the form of sequences (i.e., multiple time steps). Here, a sliding window approach is used to create sequences of `sequence_length` (e.g., 60 time steps).
#    - For each sequence of 60 time steps, the features for those 60 steps are stacked into a 3D array (time steps, features per time step, and the number of sequences).
#    - This helps the model learn patterns over time (e.g., how the vessel's behavior changes over an hour).
#
#    **Example of sequences:**
#
#    For a sequence length of 3, if the first 3 time steps look like this:
#
#    | Timestamp | Normalized SOG | COG_x      | COG_y      | Heading_x  | Heading_y  |
#    |-----------|----------------|------------|------------|------------|------------|
#    | 00:00     | 0.00           | 0.1745     | 0.9848     | 0.1736     | 0.9848     |
#    | 00:01     | 0.33           | 0.1736     | 0.9848     | 0.1732     | 0.9849     |
#    | 00:02     | 0.50           | 0.1727     | 0.9850     | 0.1725     | 0.9850     |
#
#    The model will receive a sequence of these 3 time steps as input for training.
#
# ### 6. **Labeling the Sequences:**
#    - Each sequence is labeled with a binary value, depending on the activity of the vessel:
#      - **0** for "underway using engine".
#      - **1** for "engaged in fishing".
#    - This label helps the model learn the relationship between the features and the vessel's activity.
#
# ### 7. **Loading and Combining Data:**
#    - The function `load_and_preprocess_data` is called twice, once for the "underway" data and once for the "fishing" data.
#    - After processing, the resulting feature arrays (`data_underway` and `data_fishing`) are concatenated together to form the complete dataset `X`, and their corresponding labels (`labels_underway` and `labels_fishing`) are concatenated to form the labels array `y`.
#
# ### Final Data Structure:
#    After combining the data, you end up with:
#
#    - **X**: A 3D array where each element represents a sequence of features (e.g., 60 time steps × 5 features per step = 300 features per sequence).
#
#    - **y**: A 1D array with binary labels (0 or 1) indicating the vessel activity for each sequence.
#
# ---
#
# ### **Visualization of Sequences:**
#
# Here’s how the sequences would look when plotted for `SOG`, `COG_x`, and `Heading_x` for a few time steps:
#
# #### Example:
#
# - **Sequence Data (3 time steps):**
#
#   - `SOG`: [0.00, 0.33, 0.50]
#   - `COG_x`: [0.1745, 0.1736, 0.1727]
#   - `Heading_x`: [0.1736, 0.1732, 0.1725]

# %%
# Example sequences, like explained above.

import matplotlib.pyplot as plt

time_steps = [0, 1, 2]
SOG = [0.00, 0.33, 0.50]
COG_x = [0.1745, 0.1736, 0.1727]
Heading_x = [0.1736, 0.1732, 0.1725]

plt.figure(figsize=(12, 4))

plt.subplot(1, 3, 1)
plt.plot(time_steps, SOG, label="SOG", color="blue")
plt.title("SOG over Time")
plt.xlabel("Time Steps")
plt.ylabel("Normalized SOG")

plt.subplot(1, 3, 2)
plt.plot(time_steps, COG_x, label="COG_x", color="green")
plt.title("COG_x over Time")
plt.xlabel("Time Steps")
plt.ylabel("COG_x")

plt.subplot(1, 3, 3)
plt.plot(time_steps, Heading_x, label="Heading_x", color="red")
plt.title("Heading_x over Time")
plt.xlabel("Time Steps")
plt.ylabel("Heading_x")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Sliding Window in Sequence Creation
#
# In the current model setup, the **sliding window** approach is used to create sequences of a fixed length. This means that the **length of each sequence is constant** throughout the model's training process.
#
# ### What is the Sliding Window Approach?
#
# The sliding window technique extracts **overlapping sequences** from the raw time series data. The key idea is that the **window size** (i.e., the number of time steps per sequence) remains constant, and the window "slides" over the data to generate sequences.
#
# ### Key Points:
# 1. **Fixed Sequence Length**:
#    - The length of each sequence remains **constant**. In this case, the sequence length is defined by the `sequence_length` parameter (e.g., 60 time steps).
#    - This means every sequence the model receives has exactly the same number of time steps, no matter where the window starts.
#
# 2. **Sliding Window**:
#    - As the window moves across the dataset, each new sequence will **overlap** with the previous one by all but one time step.
#    - The window shifts one time step at a time, ensuring that each sequence captures information over a fixed duration.
#
# ### Example:
# Let’s assume we have raw data sampled every minute, and we set `sequence_length = 60`, meaning each sequence will consist of 60 time steps. If the raw data is as follows:
#
# | Timestamp | SOG | COG | Heading |
# |-----------|-----|-----|---------|
# | 00:00     | 5.4 | 45  | 60      |
# | 00:01     | 5.6 | 47  | 61      |
# | ...       | ... | ... | ...     |
# | 00:59     | 5.7 | 50  | 62      |
# | 01:00     | 5.8 | 52  | 63      |
#
# Then the sliding window works as follows:
# - **First sequence**: Consists of data from `00:00` to `00:59` (60 time steps).
# - **Second sequence**: Starts at `00:01` and goes to `01:00` (another 60 time steps).
# - **Third sequence**: Starts at `00:02` and goes to `01:01` (another 60 time steps), and so on.
#
# ### Sequence Structure:
# For each sequence, the LSTM model will receive a 3D array with:
# - **Time Steps (e.g., 60)**: The number of time steps per sequence.
# - **Features per Time Step (e.g., 5)**: The number of features recorded for each time step (like `SOG`, `COG_x`, `Heading_x`).
# - **Number of Sequences**: The number of sequences generated from the raw data.
#
# In this case, each sequence consists of **60 time steps**, and the sequence length does not vary.
#
# ### Why Use Sliding Window?
# - **Consistent Length**: Having sequences of a constant length helps the model learn consistent patterns across time.
# - **Temporal Dependencies**: The sliding window captures how the data evolves over time by looking at overlapping segments.
# - **Efficient Training**: The technique allows the model to train on overlapping portions of the data, making better use of available data.
