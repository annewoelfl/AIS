# %% [markdown]
# ## Explanations below

# %%
import os
import shutil
import pandas as pd

# Define the source and destination folders
source_folder = '../5_Data_Pipeline/time_sets_st_shortened'
destination_folder = '../5_Data_Pipeline/input/under_way_sailing'

# Ensure destination folder exists
os.makedirs(destination_folder, exist_ok=True)

# Iterate over each file in the source folder
for filename in os.listdir(source_folder):
    # Check if the file is a CSV file
    if filename.endswith('.csv'):
        file_path = os.path.join(source_folder, filename)
        
        # Try to read the CSV file
        try:
            df = pd.read_csv(file_path)

            # Check if 'Navigational status' column exists and contains the value 'Underway sailing'
            if 'Navigational status' in df.columns and 'Under way sailing' in df['Navigational status'].values:
                # If the condition is met, copy the file to the destination folder
                shutil.copy(file_path, os.path.join(destination_folder, filename))
                print(f"Copied: {filename}")
        except Exception as e:
            print(f"Could not process {filename}: {e}")

print("Script execution completed.")
# Out:
# Copied: filtered_211210280_20240610_0622-20240610_0637_standardized_10s.csv
# Copied: filtered_211210280_20240610_0652-20240610_0707_standardized_10s.csv
# Copied: filtered_211210280_20240610_0707-20240610_0722_standardized_10s.csv
# Copied: filtered_211210280_20240610_0752-20240610_0807_standardized_10s.csv
# Copied: filtered_211210280_20240610_0837-20240610_0852_standardized_10s.csv
# Copied: filtered_211210280_20240610_0852-20240610_0907_standardized_10s.csv
# Copied: filtered_211210280_20240610_0907-20240610_0922_standardized_10s.csv
# Copied: filtered_211210280_20240610_0922-20240610_0937_standardized_10s.csv
# Copied: filtered_211210280_20240610_0937-20240610_0952_standardized_10s.csv
# Copied: filtered_211215170_20240530_0547-20240530_0602_standardized_10s.csv
# Copied: filtered_211215170_20240530_0602-20240530_0617_standardized_10s.csv
# Copied: filtered_211215170_20240530_0617-20240530_0632_standardized_10s.csv
# Copied: filtered_211215170_20240530_0632-20240530_0647_standardized_10s.csv
# Copied: filtered_211215170_20240530_0747-20240530_0802_standardized_10s.csv
# Copied: filtered_211215170_20240530_0802-20240530_0817_standardized_10s.csv
# Copied: filtered_211215170_20240530_0817-20240530_0832_standardized_10s.csv
# Copied: filtered_211215170_20240530_0832-20240530_0847_standardized_10s.csv
# Copied: filtered_211215170_20240530_0932-20240530_0947_standardized_10s.csv
# Copied: filtered_211237730_20240525_2257-20240525_2312_standardized_10s.csv
# Copied: filtered_211237730_20240525_2327-20240525_2342_standardized_10s.csv
# Copied: filtered_211237730_20240525_2342-20240525_2357_standardized_10s.csv
# Copied: filtered_211237730_20240526_0027-20240526_0042_standardized_10s.csv
# Copied: filtered_211237730_20240526_0042-20240526_0057_standardized_10s.csv
# Copied: filtered_211237730_20240526_0057-20240526_0112_standardized_10s.csv
# Copied: filtered_211237730_20240526_0112-20240526_0127_standardized_10s.csv
# Copied: filtered_211237730_20240526_0142-20240526_0157_standardized_10s.csv
# Copied: filtered_211237730_20240526_0212-20240526_0227_standardized_10s.csv
# Copied: filtered_211237730_20240526_0242-20240526_0257_standardized_10s.csv
# Copied: filtered_211237730_20240526_0257-20240526_0312_standardized_10s.csv
# Copied: filtered_211237730_20240526_0312-20240526_0327_standardized_10s.csv
# Copied: filtered_211237730_20240526_0327-20240526_0342_standardized_10s.csv
# Copied: filtered_211237730_20240526_0342-20240526_0357_standardized_10s.csv
# Copied: filtered_211237730_20240606_0645-20240606_0700_standardized_10s.csv
# Copied: filtered_211237730_20240606_0700-20240606_0715_standardized_10s.csv
# Copied: filtered_211237730_20240606_0715-20240606_0730_standardized_10s.csv
# Copied: filtered_211237730_20240606_0730-20240606_0745_standardized_10s.csv
# Copied: filtered_211237730_20240606_0815-20240606_0830_standardized_10s.csv
# Copied: filtered_211237730_20240606_0830-20240606_0845_standardized_10s.csv
# Copied: filtered_211237730_20240606_0900-20240606_0915_standardized_10s.csv
# Copied: filtered_211237730_20240606_0930-20240606_0945_standardized_10s.csv
# Copied: filtered_211237730_20240606_0945-20240606_1000_standardized_10s.csv
# Copied: filtered_211237730_20240606_1000-20240606_1015_standardized_10s.csv
# Copied: filtered_211237730_20240606_1015-20240606_1030_standardized_10s.csv
# Copied: filtered_211237730_20240606_1030-20240606_1045_standardized_10s.csv
# Copied: filtered_211237730_20240606_1045-20240606_1100_standardized_10s.csv
# Copied: filtered_211237730_20240606_1100-20240606_1115_standardized_10s.csv
# Copied: filtered_211237730_20240606_1115-20240606_1130_standardized_10s.csv
# Copied: filtered_211237730_20240606_1130-20240606_1145_standardized_10s.csv
# Copied: filtered_211237730_20240606_1200-20240606_1215_standardized_10s.csv
# Copied: filtered_211249130_20240422_0832-20240422_0847_standardized_10s.csv
# Copied: filtered_211249130_20240422_0947-20240422_1002_standardized_10s.csv
# Copied: filtered_211249130_20240422_1017-20240422_1032_standardized_10s.csv
# Copied: filtered_211249130_20240422_1102-20240422_1117_standardized_10s.csv
# Copied: filtered_211249130_20240422_1132-20240422_1147_standardized_10s.csv
# Copied: filtered_211249130_20240422_1147-20240422_1202_standardized_10s.csv
# Copied: filtered_211249130_20240422_1202-20240422_1217_standardized_10s.csv
# Copied: filtered_211249130_20240422_1217-20240422_1232_standardized_10s.csv
# Copied: filtered_211249130_20240422_1247-20240422_1302_standardized_10s.csv
# Copied: filtered_211249130_20240422_1302-20240422_1317_standardized_10s.csv
# Copied: filtered_211249130_20240422_1317-20240422_1332_standardized_10s.csv
# Copied: filtered_211249130_20240423_0447-20240423_0502_standardized_10s.csv
# Copied: filtered_211895440_20240628_1248-20240628_1303_standardized_10s.csv
# Copied: filtered_211895440_20240628_1303-20240628_1317_standardized_10s.csv
# Copied: filtered_211895440_20240628_1318-20240628_1332_standardized_10s.csv
# Copied: filtered_211895440_20240628_1333-20240628_1348_standardized_10s.csv
# Copied: filtered_211895440_20240628_1348-20240628_1402_standardized_10s.csv
# Copied: filtered_211895440_20240628_1403-20240628_1417_standardized_10s.csv
# Copied: filtered_211895440_20240628_1433-20240628_1448_standardized_10s.csv
# Copied: filtered_211895440_20240628_1448-20240628_1502_standardized_10s.csv
# Copied: filtered_218768000_20240616_2355-20240617_0010_standardized_10s.csv
# Copied: filtered_218768000_20240617_0010-20240617_0025_standardized_10s.csv
# Copied: filtered_218768000_20240617_0040-20240617_0055_standardized_10s.csv
# Copied: filtered_218768000_20240617_0140-20240617_0155_standardized_10s.csv
# Copied: filtered_218768000_20240617_0155-20240617_0210_standardized_10s.csv
# Copied: filtered_218768000_20240617_0210-20240617_0225_standardized_10s.csv
# Copied: filtered_218768000_20240617_0225-20240617_0240_standardized_10s.csv
# Copied: filtered_218768000_20240617_0255-20240617_0310_standardized_10s.csv
# Copied: filtered_218768000_20240617_0310-20240617_0325_standardized_10s.csv
# Copied: filtered_218768000_20240617_0325-20240617_0340_standardized_10s.csv
# Copied: filtered_218768000_20240617_0340-20240617_0355_standardized_10s.csv
# Copied: filtered_218768000_20240617_0355-20240617_0410_standardized_10s.csv
# Copied: filtered_218768000_20240617_0410-20240617_0425_standardized_10s.csv
# Copied: filtered_218768000_20240617_0425-20240617_0440_standardized_10s.csv
# Copied: filtered_218768000_20240617_0440-20240617_0455_standardized_10s.csv
# Copied: filtered_218768000_20240617_0510-20240617_0525_standardized_10s.csv
# Copied: filtered_218768000_20240617_0540-20240617_0555_standardized_10s.csv
# Copied: filtered_218768000_20240617_0610-20240617_0625_standardized_10s.csv
# Copied: filtered_218768000_20240617_0640-20240617_0655_standardized_10s.csv
# Copied: filtered_218768000_20240617_0655-20240617_0710_standardized_10s.csv
# Copied: filtered_218768000_20240617_0710-20240617_0725_standardized_10s.csv
# Copied: filtered_218768000_20240617_0725-20240617_0740_standardized_10s.csv
# Copied: filtered_218768000_20240617_0740-20240617_0755_standardized_10s.csv
# Copied: filtered_218768000_20240617_0755-20240617_0810_standardized_10s.csv
# Copied: filtered_218768000_20240617_0825-20240617_0840_standardized_10s.csv
# Copied: filtered_218768000_20240617_0840-20240617_0855_standardized_10s.csv
# Copied: filtered_218768000_20240617_0855-20240617_0910_standardized_10s.csv
# Copied: filtered_218768000_20240617_0910-20240617_0925_standardized_10s.csv
# Copied: filtered_218768000_20240617_0925-20240617_0940_standardized_10s.csv
# Copied: filtered_218768000_20240617_0940-20240617_0955_standardized_10s.csv
# Copied: filtered_218768000_20240617_0955-20240617_1010_standardized_10s.csv
# Copied: filtered_218768000_20240617_1010-20240617_1025_standardized_10s.csv
# Copied: filtered_218768000_20240621_1310-20240621_1325_standardized_10s.csv
# Copied: filtered_218768000_20240621_1325-20240621_1340_standardized_10s.csv
# Copied: filtered_218768000_20240621_1340-20240621_1355_standardized_10s.csv
# Copied: filtered_218768000_20240621_1425-20240621_1440_standardized_10s.csv
# Copied: filtered_218768000_20240621_1440-20240621_1455_standardized_10s.csv
# Copied: filtered_218768000_20240621_1455-20240621_1510_standardized_10s.csv
# Copied: filtered_218768000_20240621_1510-20240621_1525_standardized_10s.csv
# Copied: filtered_218768000_20240621_1525-20240621_1540_standardized_10s.csv
# Copied: filtered_218768000_20240621_1540-20240621_1555_standardized_10s.csv
# Copied: filtered_218768000_20240621_1610-20240621_1625_standardized_10s.csv
# Copied: filtered_218768000_20240621_1625-20240621_1640_standardized_10s.csv
# Copied: filtered_218768000_20240621_1655-20240621_1710_standardized_10s.csv
# Copied: filtered_218768000_20240621_1725-20240621_1740_standardized_10s.csv
# Copied: filtered_218768000_20240621_1740-20240621_1755_standardized_10s.csv
# Copied: filtered_218768000_20240623_0410-20240623_0425_standardized_10s.csv
# Copied: filtered_218768000_20240623_0425-20240623_0440_standardized_10s.csv
# Copied: filtered_218768000_20240623_0440-20240623_0455_standardized_10s.csv
# Copied: filtered_218768000_20240623_0510-20240623_0525_standardized_10s.csv
# Copied: filtered_218768000_20240623_0525-20240623_0540_standardized_10s.csv
# Copied: filtered_218768000_20240623_0540-20240623_0555_standardized_10s.csv
# Copied: filtered_218768000_20240623_0555-20240623_0610_standardized_10s.csv
# Copied: filtered_218768000_20240623_0610-20240623_0625_standardized_10s.csv
# Copied: filtered_218768000_20240623_0625-20240623_0640_standardized_10s.csv
# Copied: filtered_218768000_20240623_0655-20240623_0710_standardized_10s.csv
# Copied: filtered_218768000_20240623_0725-20240623_0740_standardized_10s.csv
# Copied: filtered_218768000_20240623_0740-20240623_0755_standardized_10s.csv
# Copied: filtered_218768000_20240623_0755-20240623_0810_standardized_10s.csv
# Copied: filtered_218768000_20240623_0810-20240623_0825_standardized_10s.csv
# Copied: filtered_218768000_20240623_0825-20240623_0840_standardized_10s.csv
# Copied: filtered_218768000_20240623_0840-20240623_0855_standardized_10s.csv
# Copied: filtered_218768000_20240623_0855-20240623_0910_standardized_10s.csv
# Copied: filtered_218768000_20240623_0910-20240623_0925_standardized_10s.csv
# Copied: filtered_218768000_20240623_0940-20240623_0955_standardized_10s.csv
# Copied: filtered_218768000_20240623_0955-20240623_1010_standardized_10s.csv
# Copied: filtered_219001275_20240321_2221-20240321_2235_standardized_10s.csv
# Copied: filtered_219001275_20240321_2251-20240321_2306_standardized_10s.csv
# Copied: filtered_219001275_20240322_0006-20240322_0021_standardized_10s.csv
# Copied: filtered_219001275_20240322_0051-20240322_0105_standardized_10s.csv
# Copied: filtered_219001275_20240322_0121-20240322_0136_standardized_10s.csv
# Copied: filtered_219001275_20240322_0221-20240322_0236_standardized_10s.csv
# Copied: filtered_219001275_20240322_0251-20240322_0305_standardized_10s.csv
# Copied: filtered_219001275_20240322_0306-20240322_0321_standardized_10s.csv
# Copied: filtered_219001275_20240322_0321-20240322_0336_standardized_10s.csv
# Copied: filtered_219001275_20240322_0406-20240322_0420_standardized_10s.csv
# Copied: filtered_219001275_20240322_0421-20240322_0436_standardized_10s.csv
# Copied: filtered_219001275_20240322_0451-20240322_0505_standardized_10s.csv
# Copied: filtered_219001275_20240322_0506-20240322_0520_standardized_10s.csv
# Copied: filtered_219001275_20240322_0521-20240322_0536_standardized_10s.csv
# Copied: filtered_219001275_20240322_0536-20240322_0550_standardized_10s.csv
# Copied: filtered_219001275_20240322_0551-20240322_0605_standardized_10s.csv
# Copied: filtered_219001275_20240322_0621-20240322_0635_standardized_10s.csv
# Copied: filtered_219001275_20240322_0651-20240322_0706_standardized_10s.csv
# Copied: filtered_219001275_20240322_0721-20240322_0735_standardized_10s.csv
# Copied: filtered_219001275_20240322_0736-20240322_0750_standardized_10s.csv
# Copied: filtered_219001275_20240323_0436-20240323_0451_standardized_10s.csv
# Copied: filtered_219001275_20240323_0621-20240323_0636_standardized_10s.csv
# Copied: filtered_219001275_20240323_0636-20240323_0651_standardized_10s.csv
# Copied: filtered_219001275_20240323_0651-20240323_0706_standardized_10s.csv
# Copied: filtered_219001275_20240325_1851-20240325_1906_standardized_10s.csv
# Copied: filtered_219001275_20240325_1906-20240325_1921_standardized_10s.csv
# Copied: filtered_219001275_20240325_1921-20240325_1936_standardized_10s.csv
# Copied: filtered_219001275_20240325_1936-20240325_1951_standardized_10s.csv
# Copied: filtered_219001275_20240325_1951-20240325_2006_standardized_10s.csv
# Copied: filtered_219001275_20240325_2006-20240325_2021_standardized_10s.csv
# Copied: filtered_219001275_20240325_2036-20240325_2051_standardized_10s.csv
# Copied: filtered_219001275_20240325_2106-20240325_2121_standardized_10s.csv
# Copied: filtered_219001275_20240325_2121-20240325_2136_standardized_10s.csv
# Copied: filtered_219001275_20240325_2151-20240325_2206_standardized_10s.csv
# Copied: filtered_219001275_20240325_2206-20240325_2221_standardized_10s.csv
# Copied: filtered_219001275_20240325_2236-20240325_2251_standardized_10s.csv
# Copied: filtered_219001275_20240325_2251-20240325_2306_standardized_10s.csv
# Copied: filtered_219001275_20240325_2336-20240325_2351_standardized_10s.csv
# Copied: filtered_219001275_20240325_2351-20240326_0006_standardized_10s.csv
# Copied: filtered_219001275_20240326_0021-20240326_0036_standardized_10s.csv
# Copied: filtered_219001275_20240326_0106-20240326_0121_standardized_10s.csv
# Copied: filtered_219001275_20240326_0121-20240326_0136_standardized_10s.csv
# Copied: filtered_219001275_20240326_0136-20240326_0151_standardized_10s.csv
# Copied: filtered_219001275_20240326_0221-20240326_0236_standardized_10s.csv
# Copied: filtered_219001275_20240326_0236-20240326_0251_standardized_10s.csv
# Copied: filtered_219001275_20240326_0251-20240326_0306_standardized_10s.csv
# Copied: filtered_219001275_20240326_0351-20240326_0406_standardized_10s.csv
# Copied: filtered_219001275_20240326_0406-20240326_0421_standardized_10s.csv
# Copied: filtered_219001275_20240326_0421-20240326_0436_standardized_10s.csv
# Copied: filtered_219001275_20240326_0451-20240326_0506_standardized_10s.csv
# Copied: filtered_219001275_20240326_0521-20240326_0536_standardized_10s.csv
# Copied: filtered_219001275_20240326_0551-20240326_0606_standardized_10s.csv
# Copied: filtered_219001275_20240326_0606-20240326_0621_standardized_10s.csv
# Copied: filtered_219009417_20240524_1041-20240524_1056_standardized_10s.csv
# Copied: filtered_219027298_20240524_0522-20240524_0537_standardized_10s.csv
# Copied: filtered_219027298_20240524_0535-20240524_0550_standardized_10s.csv
# Copied: filtered_219027298_20240524_0537-20240524_0552_standardized_10s.csv
# Copied: filtered_219027298_20240524_0550-20240524_0605_standardized_10s.csv
# Copied: filtered_219027298_20240524_0552-20240524_0607_standardized_10s.csv
# Copied: filtered_219027298_20240524_0652-20240524_0707_standardized_10s.csv
# Copied: filtered_219027298_20240524_0705-20240524_0720_standardized_10s.csv
# Copied: filtered_219027298_20240524_0707-20240524_0722_standardized_10s.csv
# Copied: filtered_219027298_20240524_0722-20240524_0737_standardized_10s.csv
# Copied: filtered_219027298_20240524_0735-20240524_0750_standardized_10s.csv
# Copied: filtered_219027298_20240524_0737-20240524_0752_standardized_10s.csv
# Copied: filtered_219027298_20240524_0750-20240524_0805_standardized_10s.csv
# Copied: filtered_219027298_20240524_0820-20240524_0835_standardized_10s.csv
# Copied: filtered_219027298_20240524_0852-20240524_0907_standardized_10s.csv
# Copied: filtered_219027298_20240524_0905-20240524_0919_standardized_10s.csv
# Copied: filtered_219027298_20240524_0907-20240524_0922_standardized_10s.csv
# Copied: filtered_219027298_20240524_0920-20240524_0935_standardized_10s.csv
# Copied: filtered_219027298_20240524_0922-20240524_0937_standardized_10s.csv
# Copied: filtered_219027298_20240524_1005-20240524_1019_standardized_10s.csv
# Copied: filtered_219027298_20240524_1007-20240524_1022_standardized_10s.csv
# Copied: filtered_219027298_20240524_1020-20240524_1035_standardized_10s.csv
# Copied: filtered_219027298_20240524_1022-20240524_1037_standardized_10s.csv
# Copied: filtered_219027298_20240524_1105-20240524_1119_standardized_10s.csv
# Copied: filtered_219027298_20240524_1107-20240524_1122_standardized_10s.csv
# Copied: filtered_219027298_20240524_1135-20240524_1150_standardized_10s.csv
# Copied: filtered_219027298_20240524_1137-20240524_1152_standardized_10s.csv
# Copied: filtered_219027298_20240524_1220-20240524_1235_standardized_10s.csv
# Copied: filtered_219027298_20240524_1222-20240524_1237_standardized_10s.csv
# Copied: filtered_219027298_20240524_1252-20240524_1307_standardized_10s.csv
# Copied: filtered_219027298_20240524_1305-20240524_1320_standardized_10s.csv
# Copied: filtered_219027298_20240524_1307-20240524_1322_standardized_10s.csv
# Copied: filtered_219027298_20240524_1320-20240524_1335_standardized_10s.csv
# Copied: filtered_219027298_20240524_1322-20240524_1337_standardized_10s.csv
# Copied: filtered_219027298_20240524_1335-20240524_1350_standardized_10s.csv
# Copied: filtered_219027298_20240524_1337-20240524_1352_standardized_10s.csv
# Copied: filtered_219029579_20240302_1741-20240302_1756_standardized_10s.csv
# Copied: filtered_219029579_20240329_0211-20240329_0226_standardized_10s.csv
# Copied: filtered_219029579_20240408_0240-20240408_0255_standardized_10s.csv
# Copied: filtered_219029579_20240410_0655-20240410_0710_standardized_10s.csv
# Copied: filtered_219029579_20240417_1640-20240417_1655_standardized_10s.csv
# Copied: filtered_219029785_20240521_0707-20240521_0722_standardized_10s.csv
# Copied: filtered_219029785_20240526_1952-20240526_2007_standardized_10s.csv
# Copied: filtered_219030593_20240305_0852-20240305_0907_standardized_10s.csv
# Copied: filtered_219030593_20240619_1612-20240619_1627_standardized_10s.csv
# Copied: filtered_219030593_20240620_1612-20240620_1627_standardized_10s.csv
# Copied: filtered_219032932_20240301_0538-20240301_0553_standardized_10s.csv
# Copied: filtered_219032932_20240301_0553-20240301_0608_standardized_10s.csv
# Copied: filtered_219032932_20240301_0608-20240301_0623_standardized_10s.csv
# Copied: filtered_219032932_20240301_0838-20240301_0853_standardized_10s.csv
# Copied: filtered_219032932_20240301_0908-20240301_0923_standardized_10s.csv
# Copied: filtered_219032932_20240303_2108-20240303_2123_standardized_10s.csv
# Copied: filtered_219032932_20240303_2138-20240303_2153_standardized_10s.csv
# Copied: filtered_219032932_20240304_1623-20240304_1638_standardized_10s.csv
# Copied: filtered_219032932_20240304_1638-20240304_1653_standardized_10s.csv
# Copied: filtered_219032932_20240304_1653-20240304_1708_standardized_10s.csv
# Copied: filtered_219032932_20240304_1723-20240304_1738_standardized_10s.csv
# Copied: filtered_219032932_20240304_1738-20240304_1753_standardized_10s.csv
# Copied: filtered_219032932_20240304_1753-20240304_1808_standardized_10s.csv
# Copied: filtered_219032932_20240304_2308-20240304_2323_standardized_10s.csv
# Copied: filtered_219032932_20240304_2323-20240304_2338_standardized_10s.csv
# Copied: filtered_219032932_20240304_2338-20240304_2353_standardized_10s.csv
# Copied: filtered_219032932_20240304_2353-20240305_0008_standardized_10s.csv
# Copied: filtered_219032932_20240305_0008-20240305_0023_standardized_10s.csv
# Copied: filtered_219032932_20240305_0038-20240305_0053_standardized_10s.csv
# Copied: filtered_219032932_20240305_0108-20240305_0123_standardized_10s.csv
# Copied: filtered_219032932_20240305_0123-20240305_0138_standardized_10s.csv
# Copied: filtered_219032932_20240305_1823-20240305_1838_standardized_10s.csv
# Copied: filtered_219032932_20240305_1838-20240305_1853_standardized_10s.csv
# Copied: filtered_219032932_20240305_1853-20240305_1908_standardized_10s.csv
# Copied: filtered_219032932_20240305_1938-20240305_1953_standardized_10s.csv
# Copied: filtered_219032932_20240305_1953-20240305_2008_standardized_10s.csv
# Copied: filtered_219032932_20240306_2238-20240306_2253_standardized_10s.csv
# Copied: filtered_219032932_20240307_0023-20240307_0038_standardized_10s.csv
# Copied: filtered_219032932_20240307_0253-20240307_0308_standardized_10s.csv
# Copied: filtered_219032932_20240307_0308-20240307_0323_standardized_10s.csv
# Copied: filtered_219032932_20240307_0353-20240307_0408_standardized_10s.csv
# Copied: filtered_219032932_20240307_0423-20240307_0438_standardized_10s.csv
# Copied: filtered_219032932_20240308_0223-20240308_0238_standardized_10s.csv
# Copied: filtered_219032932_20240309_0808-20240309_0823_standardized_10s.csv
# Copied: filtered_219032932_20240310_1408-20240310_1423_standardized_10s.csv
# Copied: filtered_219032932_20240313_0753-20240313_0808_standardized_10s.csv
# Copied: filtered_219032932_20240316_0723-20240316_0738_standardized_10s.csv
# Copied: filtered_219032932_20240316_0808-20240316_0823_standardized_10s.csv
# Copied: filtered_219032932_20240318_2008-20240318_2023_standardized_10s.csv
# Copied: filtered_219032932_20240319_1323-20240319_1338_standardized_10s.csv
# Copied: filtered_219032932_20240320_1638-20240320_1653_standardized_10s.csv
# Copied: filtered_219032932_20240320_1838-20240320_1853_standardized_10s.csv
# Copied: filtered_219032932_20240321_0053-20240321_0108_standardized_10s.csv
# Copied: filtered_219032932_20240323_1408-20240323_1423_standardized_10s.csv
# Copied: filtered_219032932_20240323_1453-20240323_1508_standardized_10s.csv
# Copied: filtered_219032932_20240328_0323-20240328_0338_standardized_10s.csv
# Copied: filtered_219032932_20240401_0530-20240401_0545_standardized_10s.csv
# Copied: filtered_219032932_20240403_0015-20240403_0030_standardized_10s.csv
# Copied: filtered_219032932_20240403_1345-20240403_1400_standardized_10s.csv
# Copied: filtered_219032932_20240403_1430-20240403_1445_standardized_10s.csv
# Copied: filtered_219032932_20240403_1515-20240403_1530_standardized_10s.csv
# Copied: filtered_219032932_20240403_2000-20240403_2015_standardized_10s.csv
# Copied: filtered_219032932_20240403_2130-20240403_2145_standardized_10s.csv
# Copied: filtered_219032932_20240403_2315-20240403_2330_standardized_10s.csv
# Copied: filtered_219032932_20240404_0330-20240404_0345_standardized_10s.csv
# Copied: filtered_219032932_20240404_0415-20240404_0430_standardized_10s.csv
# Copied: filtered_219032932_20240404_0745-20240404_0800_standardized_10s.csv
# Copied: filtered_219032932_20240404_0830-20240404_0845_standardized_10s.csv
# Copied: filtered_219032932_20240404_0900-20240404_0915_standardized_10s.csv
# Copied: filtered_219032932_20240404_2215-20240404_2230_standardized_10s.csv
# Copied: filtered_219032932_20240405_0100-20240405_0115_standardized_10s.csv
# Copied: filtered_219032932_20240405_0630-20240405_0645_standardized_10s.csv
# Copied: filtered_219032932_20240405_1515-20240405_1530_standardized_10s.csv
# Copied: filtered_219032932_20240406_1945-20240406_2000_standardized_10s.csv
# Copied: filtered_219032932_20240407_1100-20240407_1115_standardized_10s.csv
# Copied: filtered_219032932_20240407_1200-20240407_1215_standardized_10s.csv
# Copied: filtered_219032932_20240407_1715-20240407_1730_standardized_10s.csv
# Copied: filtered_219032932_20240407_1800-20240407_1815_standardized_10s.csv
# Copied: filtered_219032932_20240407_2130-20240407_2145_standardized_10s.csv
# Copied: filtered_219032932_20240407_2315-20240407_2330_standardized_10s.csv
# Copied: filtered_219032932_20240408_0645-20240408_0700_standardized_10s.csv
# Copied: filtered_219032932_20240408_0845-20240408_0900_standardized_10s.csv
# Copied: filtered_219032932_20240408_1745-20240408_1800_standardized_10s.csv
# Copied: filtered_219032932_20240408_2000-20240408_2015_standardized_10s.csv
# Copied: filtered_219032932_20240409_2015-20240409_2030_standardized_10s.csv
# Copied: filtered_219032932_20240409_2100-20240409_2115_standardized_10s.csv
# Copied: filtered_219032932_20240411_0030-20240411_0045_standardized_10s.csv
# Copied: filtered_219032932_20240411_0815-20240411_0830_standardized_10s.csv
# Copied: filtered_219032932_20240411_1745-20240411_1800_standardized_10s.csv
# Copied: filtered_219032932_20240411_1815-20240411_1830_standardized_10s.csv
# Copied: filtered_219032932_20240411_1930-20240411_1945_standardized_10s.csv
# Copied: filtered_219032932_20240412_0000-20240412_0015_standardized_10s.csv
# Copied: filtered_219032932_20240412_0430-20240412_0445_standardized_10s.csv
# Copied: filtered_219032932_20240412_2300-20240412_2315_standardized_10s.csv
# Copied: filtered_219032932_20240413_2115-20240413_2130_standardized_10s.csv
# Copied: filtered_219032932_20240415_1015-20240415_1030_standardized_10s.csv
# Copied: filtered_219032932_20240415_1315-20240415_1330_standardized_10s.csv
# Copied: filtered_219032932_20240415_1400-20240415_1415_standardized_10s.csv
# Copied: filtered_219032932_20240416_0215-20240416_0230_standardized_10s.csv
# Copied: filtered_219032932_20240416_1615-20240416_1630_standardized_10s.csv
# Copied: filtered_219032932_20240417_2115-20240417_2130_standardized_10s.csv
# Copied: filtered_219032932_20240417_2130-20240417_2145_standardized_10s.csv
# Copied: filtered_219032932_20240417_2145-20240417_2200_standardized_10s.csv
# Copied: filtered_219032932_20240417_2200-20240417_2215_standardized_10s.csv
# Copied: filtered_219032932_20240417_2215-20240417_2230_standardized_10s.csv
# Copied: filtered_219032932_20240417_2230-20240417_2245_standardized_10s.csv
# Copied: filtered_219032932_20240417_2245-20240417_2300_standardized_10s.csv
# Copied: filtered_219032932_20240418_0900-20240418_0915_standardized_10s.csv
# Copied: filtered_219032932_20240418_0915-20240418_0930_standardized_10s.csv
# Copied: filtered_219032932_20240418_0930-20240418_0945_standardized_10s.csv
# Copied: filtered_219032932_20240418_0945-20240418_1000_standardized_10s.csv
# Copied: filtered_219032932_20240418_1000-20240418_1015_standardized_10s.csv
# Copied: filtered_219032932_20240418_1030-20240418_1045_standardized_10s.csv
# Copied: filtered_219032932_20240418_1045-20240418_1100_standardized_10s.csv
# Copied: filtered_219032932_20240418_1100-20240418_1115_standardized_10s.csv
# Copied: filtered_219032932_20240418_1415-20240418_1430_standardized_10s.csv
# Copied: filtered_219032932_20240418_1500-20240418_1515_standardized_10s.csv
# Copied: filtered_219032932_20240418_1530-20240418_1545_standardized_10s.csv
# Copied: filtered_219032932_20240418_1545-20240418_1600_standardized_10s.csv
# Copied: filtered_219032932_20240418_1730-20240418_1745_standardized_10s.csv
# Copied: filtered_219032932_20240418_1745-20240418_1800_standardized_10s.csv
# Copied: filtered_219032932_20240418_1800-20240418_1815_standardized_10s.csv
# Copied: filtered_219032932_20240418_1815-20240418_1830_standardized_10s.csv
# Copied: filtered_219032932_20240418_2115-20240418_2130_standardized_10s.csv
# Copied: filtered_219032932_20240418_2130-20240418_2145_standardized_10s.csv
# Copied: filtered_219032932_20240418_2145-20240418_2200_standardized_10s.csv
# Copied: filtered_219032932_20240418_2200-20240418_2215_standardized_10s.csv
# Copied: filtered_219032932_20240418_2230-20240418_2245_standardized_10s.csv
# Copied: filtered_219032932_20240418_2245-20240418_2300_standardized_10s.csv
# Copied: filtered_219032932_20240418_2300-20240418_2315_standardized_10s.csv
# Copied: filtered_219032932_20240418_2315-20240418_2330_standardized_10s.csv
# Copied: filtered_219032932_20240418_2330-20240418_2345_standardized_10s.csv
# Copied: filtered_219032932_20240418_2345-20240419_0000_standardized_10s.csv
# Copied: filtered_219032932_20240419_0000-20240419_0015_standardized_10s.csv
# Copied: filtered_219032932_20240419_0015-20240419_0030_standardized_10s.csv
# Copied: filtered_219032932_20240420_1230-20240420_1245_standardized_10s.csv
# Copied: filtered_219032932_20240420_1300-20240420_1315_standardized_10s.csv
# Copied: filtered_219032932_20240420_1315-20240420_1330_standardized_10s.csv
# Copied: filtered_219032932_20240420_1330-20240420_1345_standardized_10s.csv
# Copied: filtered_219032932_20240420_1400-20240420_1414_standardized_10s.csv
# Copied: filtered_219032932_20240420_1415-20240420_1430_standardized_10s.csv
# Copied: filtered_219032932_20240420_1430-20240420_1445_standardized_10s.csv
# Copied: filtered_219032932_20240420_1445-20240420_1500_standardized_10s.csv
# Copied: filtered_219032932_20240420_1500-20240420_1515_standardized_10s.csv
# Copied: filtered_219032932_20240420_1515-20240420_1530_standardized_10s.csv
# Copied: filtered_219032932_20240420_1530-20240420_1545_standardized_10s.csv
# Copied: filtered_219032932_20240420_1545-20240420_1600_standardized_10s.csv
# Copied: filtered_219032932_20240420_1600-20240420_1615_standardized_10s.csv
# Copied: filtered_219032932_20240420_2330-20240420_2345_standardized_10s.csv
# Copied: filtered_219032932_20240420_2345-20240421_0000_standardized_10s.csv
# Copied: filtered_219032932_20240421_0000-20240421_0015_standardized_10s.csv
# Copied: filtered_219032932_20240421_0045-20240421_0100_standardized_10s.csv
# Copied: filtered_219032932_20240421_0100-20240421_0115_standardized_10s.csv
# Copied: filtered_219032932_20240421_0500-20240421_0515_standardized_10s.csv
# Copied: filtered_219032932_20240421_0515-20240421_0530_standardized_10s.csv
# Copied: filtered_219032932_20240421_0530-20240421_0545_standardized_10s.csv
# Copied: filtered_219032932_20240421_0545-20240421_0600_standardized_10s.csv
# Copied: filtered_219032932_20240421_0615-20240421_0630_standardized_10s.csv
# Copied: filtered_219032932_20240421_0630-20240421_0645_standardized_10s.csv
# Copied: filtered_219032932_20240421_1000-20240421_1015_standardized_10s.csv
# Copied: filtered_219032932_20240421_1015-20240421_1030_standardized_10s.csv
# Copied: filtered_219032932_20240421_1030-20240421_1045_standardized_10s.csv
# Copied: filtered_219032932_20240421_1645-20240421_1700_standardized_10s.csv
# Copied: filtered_219032932_20240421_1700-20240421_1715_standardized_10s.csv
# Copied: filtered_219032932_20240421_2200-20240421_2215_standardized_10s.csv
# Copied: filtered_219032932_20240421_2215-20240421_2230_standardized_10s.csv
# Copied: filtered_219032932_20240421_2245-20240421_2300_standardized_10s.csv
# Copied: filtered_219032932_20240421_2300-20240421_2315_standardized_10s.csv
# Copied: filtered_219032932_20240421_2315-20240421_2330_standardized_10s.csv
# Copied: filtered_219032932_20240421_2330-20240421_2345_standardized_10s.csv
# Copied: filtered_219032932_20240421_2345-20240422_0000_standardized_10s.csv
# Copied: filtered_219032932_20240422_0330-20240422_0345_standardized_10s.csv
# Copied: filtered_219032932_20240422_0345-20240422_0400_standardized_10s.csv
# Copied: filtered_219032932_20240422_1915-20240422_1930_standardized_10s.csv
# Copied: filtered_219032932_20240422_1930-20240422_1945_standardized_10s.csv
# Copied: filtered_219032932_20240422_1945-20240422_2000_standardized_10s.csv
# Copied: filtered_219032932_20240422_2015-20240422_2030_standardized_10s.csv
# Copied: filtered_219032932_20240422_2030-20240422_2045_standardized_10s.csv
# Copied: filtered_219032932_20240422_2045-20240422_2100_standardized_10s.csv
# Copied: filtered_219032932_20240422_2115-20240422_2130_standardized_10s.csv
# Copied: filtered_219032932_20240422_2130-20240422_2145_standardized_10s.csv
# Copied: filtered_219032932_20240422_2145-20240422_2200_standardized_10s.csv
# Copied: filtered_219032932_20240422_2230-20240422_2245_standardized_10s.csv
# Copied: filtered_219032932_20240423_0300-20240423_0315_standardized_10s.csv
# Copied: filtered_219032932_20240423_0315-20240423_0330_standardized_10s.csv
# Copied: filtered_219032932_20240423_1645-20240423_1700_standardized_10s.csv
# Copied: filtered_219032932_20240423_1700-20240423_1715_standardized_10s.csv
# Copied: filtered_219032932_20240423_1715-20240423_1730_standardized_10s.csv
# Copied: filtered_219032932_20240423_1730-20240423_1745_standardized_10s.csv
# Copied: filtered_219032932_20240423_1745-20240423_1800_standardized_10s.csv
# Copied: filtered_219032932_20240423_1800-20240423_1815_standardized_10s.csv
# Copied: filtered_219032932_20240424_0600-20240424_0615_standardized_10s.csv
# Copied: filtered_219032932_20240424_0615-20240424_0630_standardized_10s.csv
# Copied: filtered_219032932_20240424_0630-20240424_0645_standardized_10s.csv
# Copied: filtered_219032932_20240424_0645-20240424_0700_standardized_10s.csv
# Copied: filtered_219032932_20240424_0700-20240424_0715_standardized_10s.csv
# Copied: filtered_219032932_20240424_0715-20240424_0730_standardized_10s.csv
# Copied: filtered_219032932_20240424_0730-20240424_0745_standardized_10s.csv
# Copied: filtered_219032932_20240424_0800-20240424_0815_standardized_10s.csv
# Copied: filtered_219032932_20240424_0830-20240424_0845_standardized_10s.csv
# Copied: filtered_219032932_20240424_1715-20240424_1730_standardized_10s.csv
# Copied: filtered_219032932_20240424_1730-20240424_1745_standardized_10s.csv
# Copied: filtered_219032932_20240424_1745-20240424_1800_standardized_10s.csv
# Copied: filtered_219032932_20240424_1930-20240424_1945_standardized_10s.csv
# Copied: filtered_219032932_20240425_1030-20240425_1045_standardized_10s.csv
# Copied: filtered_219032932_20240425_1045-20240425_1100_standardized_10s.csv
# Copied: filtered_219032932_20240425_1100-20240425_1115_standardized_10s.csv
# Copied: filtered_219032932_20240425_1115-20240425_1130_standardized_10s.csv
# Copied: filtered_219032932_20240425_1145-20240425_1200_standardized_10s.csv
# Copied: filtered_219032932_20240425_1200-20240425_1215_standardized_10s.csv
# Copied: filtered_219032932_20240426_1000-20240426_1015_standardized_10s.csv
# Copied: filtered_219032932_20240426_1015-20240426_1030_standardized_10s.csv
# Copied: filtered_219032932_20240426_1030-20240426_1045_standardized_10s.csv
# Copied: filtered_219032932_20240426_1045-20240426_1100_standardized_10s.csv
# Copied: filtered_219032932_20240426_1100-20240426_1115_standardized_10s.csv
# Copied: filtered_219032932_20240426_1115-20240426_1130_standardized_10s.csv
# Copied: filtered_219032932_20240426_1130-20240426_1145_standardized_10s.csv
# Copied: filtered_219032932_20240426_1145-20240426_1200_standardized_10s.csv
# Copied: filtered_219032932_20240426_2100-20240426_2115_standardized_10s.csv
# Copied: filtered_219032932_20240426_2115-20240426_2130_standardized_10s.csv
# Copied: filtered_219032932_20240426_2130-20240426_2145_standardized_10s.csv
# Copied: filtered_219032932_20240427_0600-20240427_0615_standardized_10s.csv
# Copied: filtered_219032932_20240427_0615-20240427_0630_standardized_10s.csv
# Copied: filtered_219032932_20240427_0630-20240427_0645_standardized_10s.csv
# Copied: filtered_219032932_20240427_0700-20240427_0715_standardized_10s.csv
# Copied: filtered_219032932_20240427_0715-20240427_0730_standardized_10s.csv
# Copied: filtered_219032932_20240427_0730-20240427_0745_standardized_10s.csv
# Copied: filtered_219032932_20240427_0745-20240427_0800_standardized_10s.csv
# Copied: filtered_219032932_20240427_0800-20240427_0815_standardized_10s.csv
# Copied: filtered_219032932_20240427_1830-20240427_1845_standardized_10s.csv
# Copied: filtered_219032932_20240427_1845-20240427_1900_standardized_10s.csv
# Copied: filtered_219032932_20240427_1900-20240427_1915_standardized_10s.csv
# Copied: filtered_219032932_20240428_0015-20240428_0030_standardized_10s.csv
# Copied: filtered_219032932_20240428_0900-20240428_0915_standardized_10s.csv
# Copied: filtered_219032932_20240428_0915-20240428_0930_standardized_10s.csv
# Copied: filtered_219032932_20240428_0930-20240428_0945_standardized_10s.csv
# Copied: filtered_219032932_20240428_0945-20240428_1000_standardized_10s.csv
# Copied: filtered_219032932_20240428_1430-20240428_1445_standardized_10s.csv
# Copied: filtered_219032932_20240428_1445-20240428_1500_standardized_10s.csv
# Copied: filtered_219032932_20240428_1500-20240428_1515_standardized_10s.csv
# Copied: filtered_219032932_20240428_1515-20240428_1530_standardized_10s.csv
# Copied: filtered_219032932_20240428_1530-20240428_1545_standardized_10s.csv
# Copied: filtered_219032932_20240429_1800-20240429_1815_standardized_10s.csv
# Copied: filtered_219032932_20240429_1815-20240429_1830_standardized_10s.csv
# Copied: filtered_219032932_20240429_1845-20240429_1900_standardized_10s.csv
# Copied: filtered_219032932_20240429_1900-20240429_1915_standardized_10s.csv
# Copied: filtered_219032932_20240430_0245-20240430_0300_standardized_10s.csv
# Copied: filtered_219032932_20240430_0300-20240430_0315_standardized_10s.csv
# Copied: filtered_219032932_20240430_0315-20240430_0330_standardized_10s.csv
# Copied: filtered_219032932_20240430_2200-20240430_2215_standardized_10s.csv
# Copied: filtered_219032932_20240430_2215-20240430_2230_standardized_10s.csv
# Copied: filtered_219032932_20240430_2230-20240430_2245_standardized_10s.csv
# Copied: filtered_219032932_20240430_2300-20240430_2315_standardized_10s.csv
# Copied: filtered_219032932_20240430_2315-20240430_2330_standardized_10s.csv
# Copied: filtered_219032932_20240430_2330-20240430_2345_standardized_10s.csv
# Copied: filtered_219032932_20240519_0000-20240519_0015_standardized_10s.csv
# Copied: filtered_219032932_20240519_0015-20240519_0030_standardized_10s.csv
# Copied: filtered_219032932_20240519_0545-20240519_0600_standardized_10s.csv
# Copied: filtered_219032932_20240519_0600-20240519_0615_standardized_10s.csv
# Copied: filtered_219032932_20240519_0630-20240519_0645_standardized_10s.csv
# Copied: filtered_219032932_20240519_1100-20240519_1115_standardized_10s.csv
# Copied: filtered_219032932_20240519_1115-20240519_1130_standardized_10s.csv
# Copied: filtered_219032932_20240519_1300-20240519_1315_standardized_10s.csv
# Copied: filtered_219032932_20240519_1315-20240519_1330_standardized_10s.csv
# Copied: filtered_219032932_20240519_2000-20240519_2015_standardized_10s.csv
# Copied: filtered_219032932_20240519_2015-20240519_2030_standardized_10s.csv
# Copied: filtered_219032932_20240519_2030-20240519_2045_standardized_10s.csv
# Copied: filtered_219032932_20240519_2045-20240519_2100_standardized_10s.csv
# Copied: filtered_219032932_20240520_0245-20240520_0300_standardized_10s.csv
# Copied: filtered_219032932_20240520_0300-20240520_0315_standardized_10s.csv
# Copied: filtered_219032932_20240520_0445-20240520_0500_standardized_10s.csv
# Copied: filtered_219032932_20240520_1145-20240520_1200_standardized_10s.csv
# Copied: filtered_219032932_20240520_1200-20240520_1215_standardized_10s.csv
# Copied: filtered_219032932_20240520_1215-20240520_1230_standardized_10s.csv
# Copied: filtered_219032932_20240520_1230-20240520_1245_standardized_10s.csv
# Copied: filtered_219032932_20240520_1245-20240520_1300_standardized_10s.csv
# Copied: filtered_219032932_20240520_1300-20240520_1315_standardized_10s.csv
# Copied: filtered_219032932_20240520_1345-20240520_1400_standardized_10s.csv
# Copied: filtered_219032932_20240520_1400-20240520_1414_standardized_10s.csv
# Copied: filtered_219032932_20240520_2130-20240520_2145_standardized_10s.csv
# Copied: filtered_219032932_20240520_2200-20240520_2215_standardized_10s.csv
# Copied: filtered_219032932_20240521_0645-20240521_0700_standardized_10s.csv
# Copied: filtered_219032932_20240521_0700-20240521_0715_standardized_10s.csv
# Copied: filtered_219032932_20240521_1100-20240521_1115_standardized_10s.csv
# Copied: filtered_219032932_20240521_1115-20240521_1130_standardized_10s.csv
# Copied: filtered_219032932_20240521_1145-20240521_1200_standardized_10s.csv
# Copied: filtered_219043000_20240305_2018-20240305_2033_standardized_10s.csv
# Copied: filtered_219043000_20240305_2033-20240305_2048_standardized_10s.csv
# Copied: filtered_219043000_20240305_2048-20240305_2103_standardized_10s.csv
# Copied: filtered_219043000_20240305_2103-20240305_2118_standardized_10s.csv
# Copied: filtered_219043000_20240305_2118-20240305_2133_standardized_10s.csv
# Copied: filtered_219043000_20240305_2133-20240305_2148_standardized_10s.csv
# Copied: filtered_219043000_20240305_2148-20240305_2203_standardized_10s.csv
# Copied: filtered_219043000_20240305_2203-20240305_2218_standardized_10s.csv
# Copied: filtered_219043000_20240305_2218-20240305_2233_standardized_10s.csv
# Copied: filtered_219043000_20240305_2233-20240305_2248_standardized_10s.csv
# Copied: filtered_219043000_20240305_2248-20240305_2303_standardized_10s.csv
# Copied: filtered_219043000_20240305_2303-20240305_2318_standardized_10s.csv
# Copied: filtered_219043000_20240305_2318-20240305_2333_standardized_10s.csv
# Copied: filtered_219043000_20240305_2333-20240305_2348_standardized_10s.csv
# Copied: filtered_219043000_20240305_2348-20240306_0003_standardized_10s.csv
# Copied: filtered_219043000_20240306_0003-20240306_0018_standardized_10s.csv
# Copied: filtered_219329000_20240305_0305-20240305_0320_standardized_10s.csv
# Copied: filtered_219417000_20240415_1043-20240415_1058_standardized_10s.csv
# Copied: filtered_219417000_20240415_1143-20240415_1158_standardized_10s.csv
# Copied: filtered_219417000_20240415_1213-20240415_1228_standardized_10s.csv
# Copied: filtered_220003000_20240619_1023-20240619_1038_standardized_10s.csv
# Copied: filtered_220003000_20240619_1038-20240619_1053_standardized_10s.csv
# Copied: filtered_220003000_20240619_1053-20240619_1108_standardized_10s.csv
# Copied: filtered_220003000_20240619_1108-20240619_1123_standardized_10s.csv
# Copied: filtered_220003000_20240619_1123-20240619_1138_standardized_10s.csv
# Copied: filtered_220003000_20240619_1138-20240619_1153_standardized_10s.csv
# Copied: filtered_220003000_20240619_1153-20240619_1208_standardized_10s.csv
# Copied: filtered_220003000_20240619_1208-20240619_1223_standardized_10s.csv
# Copied: filtered_220003000_20240619_1223-20240619_1238_standardized_10s.csv
# Copied: filtered_220003000_20240619_1238-20240619_1253_standardized_10s.csv
# Copied: filtered_220003000_20240619_1253-20240619_1308_standardized_10s.csv
# Copied: filtered_220003000_20240619_1308-20240619_1323_standardized_10s.csv
# Copied: filtered_220003000_20240619_1323-20240619_1338_standardized_10s.csv
# Copied: filtered_220003000_20240619_1338-20240619_1353_standardized_10s.csv
# Copied: filtered_220003000_20240619_1408-20240619_1423_standardized_10s.csv
# Copied: filtered_220141000_20240626_1240-20240626_1255_standardized_10s.csv
# Copied: filtered_229964000_20240328_0133-20240328_0148_standardized_10s.csv
# Copied: filtered_231036000_20240424_2119-20240424_2134_standardized_10s.csv
# Copied: filtered_231036000_20240427_1649-20240427_1704_standardized_10s.csv
# Copied: filtered_231036000_20240427_1719-20240427_1734_standardized_10s.csv
# Copied: filtered_231036000_20240427_1749-20240427_1804_standardized_10s.csv
# Copied: filtered_231036000_20240427_1819-20240427_1834_standardized_10s.csv
# Copied: filtered_231036000_20240427_1834-20240427_1849_standardized_10s.csv
# Copied: filtered_231036000_20240427_1849-20240427_1904_standardized_10s.csv
# Copied: filtered_231036000_20240427_1904-20240427_1919_standardized_10s.csv
# Copied: filtered_231036000_20240427_1919-20240427_1934_standardized_10s.csv
# Copied: filtered_231036000_20240427_1934-20240427_1949_standardized_10s.csv
# Copied: filtered_231036000_20240427_1949-20240427_2004_standardized_10s.csv
# Copied: filtered_231036000_20240427_2004-20240427_2019_standardized_10s.csv
# Copied: filtered_231036000_20240427_2034-20240427_2049_standardized_10s.csv
# Copied: filtered_231036000_20240427_2119-20240427_2134_standardized_10s.csv
# Copied: filtered_231036000_20240427_2134-20240427_2149_standardized_10s.csv
# Copied: filtered_231036000_20240427_2149-20240427_2204_standardized_10s.csv
# Copied: filtered_231036000_20240427_2204-20240427_2219_standardized_10s.csv
# Copied: filtered_231036000_20240427_2219-20240427_2234_standardized_10s.csv
# Copied: filtered_231039000_20240526_0510-20240526_0525_standardized_10s.csv
# Copied: filtered_231039000_20240527_0640-20240527_0655_standardized_10s.csv
# Copied: filtered_231039000_20240527_0655-20240527_0710_standardized_10s.csv
# Copied: filtered_231039000_20240606_1645-20240606_1700_standardized_10s.csv
# Copied: filtered_231039000_20240606_1700-20240606_1715_standardized_10s.csv
# Copied: filtered_231039000_20240606_1715-20240606_1730_standardized_10s.csv
# Copied: filtered_231039000_20240606_1730-20240606_1745_standardized_10s.csv
# Copied: filtered_231039000_20240607_1945-20240607_2000_standardized_10s.csv
# Copied: filtered_231039000_20240607_2015-20240607_2030_standardized_10s.csv
# Copied: filtered_231861000_20240519_1211-20240519_1226_standardized_10s.csv
# Copied: filtered_231861000_20240520_1556-20240520_1611_standardized_10s.csv
# Copied: filtered_231892000_20240411_0859-20240411_0914_standardized_10s.csv
# Copied: filtered_232009818_20240308_0952-20240308_1007_standardized_10s.csv
# Copied: filtered_232009818_20240319_0752-20240319_0807_standardized_10s.csv
# Copied: filtered_232009818_20240319_0807-20240319_0822_standardized_10s.csv
# Copied: filtered_232009818_20240319_0822-20240319_0837_standardized_10s.csv
# Copied: filtered_232009818_20240319_0837-20240319_0852_standardized_10s.csv
# Copied: filtered_232009818_20240319_1207-20240319_1222_standardized_10s.csv
# Copied: filtered_232021933_20240402_0422-20240402_0437_standardized_10s.csv
# Copied: filtered_232031869_20240607_1840-20240607_1855_standardized_10s.csv
# Copied: filtered_232031869_20240607_1855-20240607_1910_standardized_10s.csv
# Copied: filtered_232031869_20240607_1910-20240607_1925_standardized_10s.csv
# Copied: filtered_232031869_20240607_1940-20240607_1955_standardized_10s.csv
# Copied: filtered_232031869_20240607_2010-20240607_2025_standardized_10s.csv
# Copied: filtered_232031869_20240607_2040-20240607_2055_standardized_10s.csv
# Copied: filtered_232031869_20240607_2055-20240607_2110_standardized_10s.csv
# Copied: filtered_232031869_20240607_2110-20240607_2125_standardized_10s.csv
# Copied: filtered_232053671_20240622_0828-20240622_0843_standardized_10s.csv
# Copied: filtered_232053671_20240622_1258-20240622_1313_standardized_10s.csv
# Copied: filtered_232053671_20240625_0213-20240625_0228_standardized_10s.csv
# Copied: filtered_232053671_20240625_0343-20240625_0358_standardized_10s.csv
# Copied: filtered_232053671_20240625_0458-20240625_0513_standardized_10s.csv
# Copied: filtered_232053671_20240625_0658-20240625_0713_standardized_10s.csv
# Copied: filtered_232053671_20240625_0813-20240625_0828_standardized_10s.csv
# Copied: filtered_232053671_20240625_1243-20240625_1258_standardized_10s.csv
# Copied: filtered_232053671_20240625_1258-20240625_1313_standardized_10s.csv
# Copied: filtered_232053671_20240625_1343-20240625_1358_standardized_10s.csv
# Copied: filtered_232053671_20240625_1528-20240625_1543_standardized_10s.csv
# Copied: filtered_232053671_20240625_1558-20240625_1613_standardized_10s.csv
# Copied: filtered_232053671_20240625_1613-20240625_1628_standardized_10s.csv
# Copied: filtered_232053671_20240625_1728-20240625_1743_standardized_10s.csv
# Copied: filtered_232053671_20240625_1758-20240625_1813_standardized_10s.csv
# Copied: filtered_235087256_20241130_0034-20241130_0049_standardized_10s.csv
# Copied: filtered_235087256_20241130_0104-20241130_0119_standardized_10s.csv
# Copied: filtered_235087256_20241130_0119-20241130_0134_standardized_10s.csv
# Copied: filtered_235102532_20240524_0406-20240524_0421_standardized_10s.csv
# Copied: filtered_235102532_20240524_0421-20240524_0436_standardized_10s.csv
# Copied: filtered_235102532_20240524_0423-20240524_0438_standardized_10s.csv
# Copied: filtered_235102532_20240524_0436-20240524_0451_standardized_10s.csv
# Copied: filtered_235102532_20240524_0438-20240524_0453_standardized_10s.csv
# Copied: filtered_235102532_20240524_0453-20240524_0508_standardized_10s.csv
# Copied: filtered_235102532_20240524_1421-20240524_1436_standardized_10s.csv
# Copied: filtered_235102532_20240524_1423-20240524_1438_standardized_10s.csv
# Copied: filtered_235102532_20240524_1436-20240524_1451_standardized_10s.csv
# Copied: filtered_235102532_20240524_1438-20240524_1453_standardized_10s.csv
# Copied: filtered_235102532_20240524_1451-20240524_1506_standardized_10s.csv
# Copied: filtered_235102532_20240524_1453-20240524_1508_standardized_10s.csv
# Copied: filtered_235102532_20240524_1506-20240524_1521_standardized_10s.csv
# Copied: filtered_235102532_20240524_1508-20240524_1523_standardized_10s.csv
# Copied: filtered_236342000_20240405_0751-20240405_0806_standardized_10s.csv
# Copied: filtered_236342000_20240405_0821-20240405_0836_standardized_10s.csv
# Copied: filtered_236342000_20240405_0837-20240405_0851_standardized_10s.csv
# Copied: filtered_236342000_20240405_0852-20240405_0906_standardized_10s.csv
# Copied: filtered_236342000_20240405_0907-20240405_0921_standardized_10s.csv
# Copied: filtered_236342000_20240405_0922-20240405_0936_standardized_10s.csv
# Copied: filtered_236342000_20240405_0937-20240405_0951_standardized_10s.csv
# ...
# Copied: filtered_257179000_20240311_1923-20240311_1938_standardized_10s.csv
# Copied: filtered_257179000_20240311_1938-20240311_1953_standardized_10s.csv
# Copied: filtered_257179000_20240311_1953-20240311_2008_standardized_10s.csv
# Copied: filtered_257179000_20240311_2008-20240311_2023_standardized_10s.csv
# Copied: filtered_257179000_20240311_2038-20240311_2053_standardized_10s.csv
# Copied: filtered_257179000_20240311_2053-20240311_2108_standardized_10s.csv
# Copied: filtered_257179000_20240311_2108-20240311_2123_standardized_10s.csv
# Copied: filtered_257179000_20240311_2123-20240311_2138_standardized_10s.csv
# Copied: filtered_257179000_20240311_2138-20240311_2153_standardized_10s.csv
# Copied: filtered_257688000_20240612_1936-20240612_1951_standardized_10s.csv
# Copied: filtered_258373000_20240522_0844-20240522_0859_standardized_10s.csv
# Copied: filtered_258373000_20240522_0929-20240522_0944_standardized_10s.csv
# Copied: filtered_258373000_20240522_0959-20240522_1014_standardized_10s.csv
# Copied: filtered_258373000_20240522_1029-20240522_1044_standardized_10s.csv
# Copied: filtered_258373000_20240522_1044-20240522_1059_standardized_10s.csv
# Copied: filtered_258373000_20240522_1059-20240522_1114_standardized_10s.csv
# Copied: filtered_258373000_20240522_1114-20240522_1129_standardized_10s.csv
# Copied: filtered_258373000_20240522_1129-20240522_1144_standardized_10s.csv
# Copied: filtered_258373000_20240522_1214-20240522_1229_standardized_10s.csv
# Copied: filtered_258373000_20240522_1229-20240522_1244_standardized_10s.csv
# Copied: filtered_258373000_20240522_1244-20240522_1259_standardized_10s.csv
# Copied: filtered_258373000_20240522_1314-20240522_1329_standardized_10s.csv
# Copied: filtered_258373000_20240522_1344-20240522_1359_standardized_10s.csv
# Copied: filtered_258373000_20240522_1429-20240522_1444_standardized_10s.csv
# Copied: filtered_258373000_20240522_1514-20240522_1529_standardized_10s.csv
# Copied: filtered_258373000_20240522_1529-20240522_1544_standardized_10s.csv
# Copied: filtered_258373000_20240522_1559-20240522_1614_standardized_10s.csv
# Copied: filtered_258373000_20240522_1614-20240522_1629_standardized_10s.csv
# Copied: filtered_258373000_20240522_1629-20240522_1644_standardized_10s.csv
# Copied: filtered_259140000_20241122_1654-20241122_1709_standardized_10s.csv
# Copied: filtered_259140000_20241122_1709-20241122_1724_standardized_10s.csv
# Copied: filtered_259140000_20241122_1739-20241122_1754_standardized_10s.csv
# Copied: filtered_259140000_20241122_1754-20241122_1809_standardized_10s.csv
# Copied: filtered_259140000_20241122_1824-20241122_1839_standardized_10s.csv
# Copied: filtered_259140000_20241122_1839-20241122_1854_standardized_10s.csv
# Copied: filtered_259140000_20241122_1909-20241122_1924_standardized_10s.csv
# Copied: filtered_259140000_20241129_2305-20241129_2320_standardized_10s.csv
# Copied: filtered_259140000_20241129_2324-20241129_2339_standardized_10s.csv
# Copied: filtered_259140000_20241130_0020-20241130_0035_standardized_10s.csv
# Copied: filtered_259140000_20241130_0024-20241130_0039_standardized_10s.csv
# Copied: filtered_259140000_20241130_0035-20241130_0050_standardized_10s.csv
# Copied: filtered_259140000_20241130_0054-20241130_0109_standardized_10s.csv
# Copied: filtered_259140000_20241130_0105-20241130_0120_standardized_10s.csv
# Copied: filtered_259140000_20241130_0109-20241130_0124_standardized_10s.csv
# Copied: filtered_259140000_20241130_0120-20241130_0135_standardized_10s.csv
# Copied: filtered_259140000_20241130_0124-20241130_0139_standardized_10s.csv
# Copied: filtered_259140000_20241130_0135-20241130_0150_standardized_10s.csv
# Copied: filtered_259140000_20241130_0139-20241130_0154_standardized_10s.csv
# Copied: filtered_259140000_20241130_0205-20241130_0220_standardized_10s.csv
# Copied: filtered_265043000_20241126_0942-20241126_0957_standardized_10s.csv
# Copied: filtered_265043000_20241128_1642-20241128_1657_standardized_10s.csv
# Copied: filtered_265043000_20241128_1712-20241128_1727_standardized_10s.csv
# Copied: filtered_265404000_20240618_0212-20240618_0227_standardized_10s.csv
# Copied: filtered_265404000_20240618_0227-20240618_0242_standardized_10s.csv
# Copied: filtered_265404000_20240618_0242-20240618_0257_standardized_10s.csv
# Copied: filtered_265404000_20240618_0257-20240618_0312_standardized_10s.csv
# Copied: filtered_265404000_20240618_0312-20240618_0327_standardized_10s.csv
# Copied: filtered_265404000_20240618_0327-20240618_0342_standardized_10s.csv
# Copied: filtered_265404000_20240618_0342-20240618_0357_standardized_10s.csv
# Copied: filtered_265404000_20240618_0357-20240618_0412_standardized_10s.csv
# Copied: filtered_265404000_20240618_0412-20240618_0427_standardized_10s.csv
# Copied: filtered_265404000_20240618_0427-20240618_0442_standardized_10s.csv
# Copied: filtered_265404000_20240618_0442-20240618_0457_standardized_10s.csv
# Copied: filtered_265404000_20240618_0457-20240618_0512_standardized_10s.csv
# Copied: filtered_265404000_20240618_0512-20240618_0527_standardized_10s.csv
# Copied: filtered_265404000_20240618_0527-20240618_0542_standardized_10s.csv
# Copied: filtered_265404000_20240618_0542-20240618_0557_standardized_10s.csv
# Copied: filtered_266263000_20240428_1927-20240428_1941_standardized_10s.csv
# Copied: filtered_266263000_20240428_1942-20240428_1957_standardized_10s.csv
# Copied: filtered_266263000_20240428_1957-20240428_2012_standardized_10s.csv
# Copied: filtered_266263000_20240428_2012-20240428_2027_standardized_10s.csv
# Copied: filtered_266263000_20240428_2027-20240428_2041_standardized_10s.csv
# Copied: filtered_266263000_20240428_2042-20240428_2057_standardized_10s.csv
# Copied: filtered_266263000_20240428_2057-20240428_2111_standardized_10s.csv
# Copied: filtered_266263000_20240428_2127-20240428_2142_standardized_10s.csv
# Copied: filtered_266263000_20240428_2142-20240428_2157_standardized_10s.csv
# Copied: filtered_266263000_20240428_2157-20240428_2212_standardized_10s.csv
# Copied: filtered_266263000_20240428_2212-20240428_2227_standardized_10s.csv
# Copied: filtered_331000409_20240624_1605-20240624_1620_standardized_10s.csv
# Copied: filtered_331769000_20240625_2123-20240625_2138_standardized_10s.csv
# Copied: filtered_331769000_20240625_2138-20240625_2153_standardized_10s.csv
# Copied: filtered_331769000_20240625_2208-20240625_2223_standardized_10s.csv
# Copied: filtered_331769000_20240625_2223-20240625_2238_standardized_10s.csv
# Copied: filtered_331769000_20240625_2238-20240625_2253_standardized_10s.csv
# Copied: filtered_341578001_20240412_2003-20240412_2018_standardized_10s.csv
# Copied: filtered_341578001_20240412_2018-20240412_2033_standardized_10s.csv
# Copied: filtered_341578001_20240412_2048-20240412_2103_standardized_10s.csv
# Copied: filtered_341578001_20240412_2118-20240412_2133_standardized_10s.csv
# Copied: filtered_341578001_20240412_2133-20240412_2148_standardized_10s.csv
# Copied: filtered_341578001_20240412_2148-20240412_2203_standardized_10s.csv
# Copied: filtered_341578001_20240413_0803-20240413_0818_standardized_10s.csv
# Copied: filtered_341578001_20240413_0818-20240413_0833_standardized_10s.csv
# Copied: filtered_341578001_20240413_0848-20240413_0903_standardized_10s.csv
# Copied: filtered_341578001_20240413_0918-20240413_0933_standardized_10s.csv
# Copied: filtered_341578001_20240413_0933-20240413_0948_standardized_10s.csv
# Copied: filtered_352001011_20240316_0737-20240316_0752_standardized_10s.csv
# Copied: filtered_352001011_20240316_0752-20240316_0807_standardized_10s.csv
# Copied: filtered_352001011_20240316_0807-20240316_0822_standardized_10s.csv
# Copied: filtered_352001011_20240316_0822-20240316_0837_standardized_10s.csv
# Copied: filtered_352001011_20240316_0837-20240316_0852_standardized_10s.csv
# Copied: filtered_352001011_20240316_0852-20240316_0907_standardized_10s.csv
# Copied: filtered_352001011_20240316_1707-20240316_1722_standardized_10s.csv
# Copied: filtered_352001011_20240316_1722-20240316_1736_standardized_10s.csv
# Copied: filtered_352001011_20240316_1737-20240316_1752_standardized_10s.csv
# Copied: filtered_352001011_20240316_1752-20240316_1807_standardized_10s.csv
# Copied: filtered_352001011_20240316_1822-20240316_1837_standardized_10s.csv
# Copied: filtered_352001011_20240316_1837-20240316_1851_standardized_10s.csv
# Copied: filtered_352001011_20240316_1852-20240316_1906_standardized_10s.csv
# Copied: filtered_352003611_20240530_0843-20240530_0857_standardized_10s.csv
# Copied: filtered_352003611_20240530_0913-20240530_0927_standardized_10s.csv
# Copied: filtered_352003611_20240530_0928-20240530_0943_standardized_10s.csv
# Copied: filtered_353190000_20240304_2202-20240304_2217_standardized_10s.csv
# Copied: filtered_353190000_20240304_2232-20240304_2247_standardized_10s.csv
# Copied: filtered_353190000_20240304_2247-20240304_2302_standardized_10s.csv
# Copied: filtered_370416000_20240522_1903-20240522_1918_standardized_10s.csv
# Copied: filtered_370416000_20240522_1933-20240522_1948_standardized_10s.csv
# Copied: filtered_370416000_20240522_1948-20240522_2003_standardized_10s.csv
# Copied: filtered_370416000_20240522_2003-20240522_2018_standardized_10s.csv
# Copied: filtered_370416000_20240522_2018-20240522_2033_standardized_10s.csv
# Copied: filtered_370416000_20240522_2033-20240522_2048_standardized_10s.csv
# Copied: filtered_370416000_20240522_2048-20240522_2103_standardized_10s.csv
# Copied: filtered_370416000_20240522_2103-20240522_2118_standardized_10s.csv
# Copied: filtered_374458000_20240418_1102-20240418_1117_standardized_10s.csv
# Copied: filtered_374458000_20240418_1132-20240418_1147_standardized_10s.csv
# Copied: filtered_374458000_20240418_1217-20240418_1232_standardized_10s.csv
# Copied: filtered_374458000_20240418_1302-20240418_1317_standardized_10s.csv
# Copied: filtered_518999239_20240622_2215-20240622_2230_standardized_10s.csv
# Copied: filtered_518999239_20240622_2230-20240622_2245_standardized_10s.csv
# Copied: filtered_518999239_20240622_2315-20240622_2330_standardized_10s.csv
# Copied: filtered_518999239_20240623_0000-20240623_0015_standardized_10s.csv
# Copied: filtered_518999239_20240623_0015-20240623_0030_standardized_10s.csv
# Copied: filtered_518999239_20240623_0045-20240623_0100_standardized_10s.csv
# Copied: filtered_518999239_20240623_0100-20240623_0115_standardized_10s.csv
# Copied: filtered_518999239_20240623_0115-20240623_0130_standardized_10s.csv
# Copied: filtered_518999239_20240623_0145-20240623_0200_standardized_10s.csv
# Copied: filtered_538006523_20240401_1127-20240401_1142_standardized_10s.csv
# Copied: filtered_538006523_20240401_1142-20240401_1157_standardized_10s.csv
# Copied: filtered_538006523_20240401_1212-20240401_1227_standardized_10s.csv
# Copied: filtered_538006523_20240401_1227-20240401_1242_standardized_10s.csv
# Copied: filtered_538007841_20240626_2212-20240626_2227_standardized_10s.csv
# Copied: filtered_538007841_20240626_2227-20240626_2242_standardized_10s.csv
# Copied: filtered_538007841_20240626_2242-20240626_2257_standardized_10s.csv
# Copied: filtered_538007841_20240626_2312-20240626_2327_standardized_10s.csv
# Copied: filtered_538007841_20240626_2327-20240626_2342_standardized_10s.csv
# Copied: filtered_538007841_20240626_2342-20240626_2357_standardized_10s.csv
# Copied: filtered_538008097_20240330_1137-20240330_1152_standardized_10s.csv
# Copied: filtered_538008097_20240330_1152-20240330_1207_standardized_10s.csv
# Copied: filtered_538008097_20240330_1222-20240330_1236_standardized_10s.csv
# Copied: filtered_538008097_20240330_1237-20240330_1252_standardized_10s.csv
# Copied: filtered_538008097_20240330_1252-20240330_1307_standardized_10s.csv
# Copied: filtered_538008097_20240330_1307-20240330_1322_standardized_10s.csv
# Copied: filtered_538008097_20240330_1337-20240330_1352_standardized_10s.csv
# Copied: filtered_538008097_20240330_1437-20240330_1452_standardized_10s.csv
# Copied: filtered_538008097_20240330_1522-20240330_1536_standardized_10s.csv
# Copied: filtered_538008971_20240412_0334-20240412_0349_standardized_10s.csv
# Copied: filtered_538008971_20240412_0349-20240412_0404_standardized_10s.csv
# Copied: filtered_538008971_20240412_0404-20240412_0419_standardized_10s.csv
# Copied: filtered_538009469_20240520_0320-20240520_0334_standardized_10s.csv
# Copied: filtered_538009469_20240520_0335-20240520_0349_standardized_10s.csv
# Copied: filtered_538009469_20240520_0405-20240520_0419_standardized_10s.csv
# Copied: filtered_538010456_20240612_2356-20240613_0011_standardized_10s.csv
# Copied: filtered_538010456_20240613_0011-20240613_0026_standardized_10s.csv
# Copied: filtered_538010456_20240613_0111-20240613_0126_standardized_10s.csv
# Copied: filtered_538010700_20240425_0045-20240425_0059_standardized_10s.csv
# Copied: filtered_538010700_20240425_0100-20240425_0114_standardized_10s.csv
# Copied: filtered_538010700_20240425_0130-20240425_0144_standardized_10s.csv
# Copied: filtered_566029000_20240429_1226-20240429_1241_standardized_10s.csv
# Copied: filtered_566029000_20240429_1241-20240429_1256_standardized_10s.csv
# Copied: filtered_566029000_20240429_1326-20240429_1341_standardized_10s.csv
# Copied: filtered_566029000_20240429_1341-20240429_1356_standardized_10s.csv
# Copied: filtered_566029000_20240429_1356-20240429_1411_standardized_10s.csv
# Copied: filtered_566029000_20240429_1411-20240429_1426_standardized_10s.csv
# Copied: filtered_566029000_20240429_1426-20240429_1441_standardized_10s.csv
# Copied: filtered_566029000_20240429_1456-20240429_1511_standardized_10s.csv
# Copied: filtered_566029000_20240429_1511-20240429_1526_standardized_10s.csv
# Copied: filtered_566029000_20240429_1611-20240429_1626_standardized_10s.csv
# Copied: filtered_566029000_20240429_1641-20240429_1656_standardized_10s.csv
# Copied: filtered_566029000_20240429_1656-20240429_1711_standardized_10s.csv
# Copied: filtered_566029000_20240429_1711-20240429_1726_standardized_10s.csv
# Copied: filtered_566029000_20240429_1726-20240429_1741_standardized_10s.csv
# Copied: filtered_574005280_20240612_1133-20240612_1148_standardized_10s.csv
# Copied: filtered_574005280_20240612_1148-20240612_1203_standardized_10s.csv
# Copied: filtered_574005280_20240612_1203-20240612_1218_standardized_10s.csv
# Copied: filtered_574005280_20240612_1233-20240612_1248_standardized_10s.csv
# Copied: filtered_574005280_20240612_1303-20240612_1318_standardized_10s.csv
# Copied: filtered_574005280_20240612_1333-20240612_1348_standardized_10s.csv
# Copied: filtered_574005280_20240612_1403-20240612_1418_standardized_10s.csv
# Copied: filtered_626450000_20240410_1155-20240410_1210_standardized_10s.csv
# Copied: filtered_626450000_20240410_1225-20240410_1240_standardized_10s.csv
# Copied: filtered_626450000_20240410_1240-20240410_1255_standardized_10s.csv
# Copied: filtered_626450000_20240410_1310-20240410_1325_standardized_10s.csv
# Copied: filtered_626450000_20240410_1325-20240410_1340_standardized_10s.csv
# Copied: filtered_626450000_20240410_1410-20240410_1425_standardized_10s.csv
# Copied: filtered_626450000_20240410_1425-20240410_1440_standardized_10s.csv
# Copied: filtered_626450000_20240410_1525-20240410_1540_standardized_10s.csv
# Copied: filtered_626450000_20240410_1555-20240410_1610_standardized_10s.csv
# Copied: filtered_626450000_20240410_1625-20240410_1640_standardized_10s.csv
# Copied: filtered_626450000_20240410_1740-20240410_1755_standardized_10s.csv
# Copied: filtered_626450000_20240410_1810-20240410_1825_standardized_10s.csv
# Copied: filtered_636017572_20240524_1015-20240524_1030_standardized_10s.csv
# Copied: filtered_636018728_20240603_1112-20240603_1127_standardized_10s.csv
# Copied: filtered_636093015_20240609_0807-20240609_0822_standardized_10s.csv
# Copied: filtered_636093015_20240609_0837-20240609_0852_standardized_10s.csv
# Copied: filtered_636093015_20240609_0852-20240609_0907_standardized_10s.csv
# Copied: filtered_636093015_20240609_0952-20240609_1007_standardized_10s.csv
# Copied: filtered_636093015_20240609_1052-20240609_1107_standardized_10s.csv
# Copied: filtered_636093015_20240609_1107-20240609_1122_standardized_10s.csv
# Copied: filtered_636093015_20240609_1152-20240609_1207_standardized_10s.csv
# Copied: filtered_636093015_20240609_1252-20240609_1307_standardized_10s.csv
# Copied: filtered_636093015_20240609_1307-20240609_1322_standardized_10s.csv
# Script execution completed.

# %%
import os
import glob
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.callbacks import Callback, EarlyStopping, ModelCheckpoint, TensorBoard
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# Global debug flag
DEBUG = True

def debug_print(message):
    """Print debugging messages when DEBUG is True."""
    if DEBUG:
        print(message)

def process_timestamp(df):
    """
    Process the Timestamp column of a DataFrame to extract cyclical time features.
    Assumes 'Timestamp' is in a parseable datetime format.
    """
    # Convert 'Timestamp' to datetime
    df['Timestamp'] = pd.to_datetime(df['Timestamp'])
    debug_print("Converted Timestamp to datetime.")

    # Extract the hour from the Timestamp
    df['hour'] = df['Timestamp'].dt.hour
    debug_print("Extracted hour from Timestamp.")

    # Apply cyclical encoding for the hour of the day
    df['hour_sin'] = np.sin(2 * np.pi * df['hour'] / 24)
    df['hour_cos'] = np.cos(2 * np.pi * df['hour'] / 24)
    debug_print("Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.")

    return df

def load_data_with_time(data_dir_sailing, data_dir_underway):
    """
    Load CSV files from two directories (one for each class) and return:
      X: NumPy array of shape (n_samples, sequence_length, n_features)
      y: NumPy array of shape (n_samples,)
    
    This version processes the 'Timestamp' column to include cyclical time features.
    """
    X, y = [], []
    
    # Get lists of CSV files for each class
    sailing_files = glob.glob(os.path.join(data_dir_sailing, '*.csv'))
    underway_files = glob.glob(os.path.join(data_dir_underway, '*.csv'))
    debug_print(f"Found {len(sailing_files)} sailing files in {data_dir_sailing}")
    debug_print(f"Found {len(underway_files)} underway files in {data_dir_underway}")
    
    # Define the required columns (include Timestamp for time features)
    required_cols = ['Timestamp', 'SOG', 'COG', 'Heading']
    
    # Process sailing files (label 0)
    for file in sailing_files:
        try:
            df = pd.read_csv(file)
            if not all(col in df.columns for col in required_cols):
                debug_print(f"File {file} missing required columns. Skipping.")
                continue
            df = process_timestamp(df)  # Process time features
            # Select features: SOG, COG, Heading, hour_sin, hour_cos
            features = df[['SOG', 'COG', 'Heading', 'hour_sin', 'hour_cos']].values
            X.append(features)
            y.append(0)
            debug_print(f"Loaded sailing file {file} with feature shape {features.shape}.")
        except Exception as e:
            debug_print(f"Error loading {file}: {e}")
    
    # Process underway files (label 1)
    for file in underway_files:
        try:
            df = pd.read_csv(file)
            if not all(col in df.columns for col in required_cols):
                debug_print(f"File {file} missing required columns. Skipping.")
                continue
            df = process_timestamp(df)
            features = df[['SOG', 'COG', 'Heading', 'hour_sin', 'hour_cos']].values
            X.append(features)
            y.append(1)
            debug_print(f"Loaded underway file {file} with feature shape {features.shape}.")
        except Exception as e:
            debug_print(f"Error loading {file}: {e}")
    
    # Convert lists to NumPy arrays
    X = np.array(X)
    y = np.array(y)
    debug_print(f"Total samples loaded: {len(X)}")
    return X, y

def undersample_data(X, y):
    """
    Undersample the majority class to match the minority class count.
    """
    debug_print("Starting undersampling process...")
    indices_class0 = np.where(y == 0)[0]
    indices_class1 = np.where(y == 1)[0]
    debug_print(f"Class 0 sample count: {len(indices_class0)}")
    debug_print(f"Class 1 sample count: {len(indices_class1)}")

    min_count = min(len(indices_class0), len(indices_class1))
    debug_print(f"Minority class count: {min_count}")

    selected_indices_class0 = np.random.choice(indices_class0, min_count, replace=False)
    selected_indices_class1 = np.random.choice(indices_class1, min_count, replace=False)

    combined_indices = np.concatenate([selected_indices_class0, selected_indices_class1])
    np.random.shuffle(combined_indices)

    X_balanced = X[combined_indices]
    y_balanced = y[combined_indices]
    debug_print(f"After undersampling, balanced data shape: X: {X_balanced.shape}, y: {y_balanced.shape}")
    return X_balanced, y_balanced

def build_improved_model(input_shape, learning_rate=0.0001):
    """
    Build and compile an improved LSTM model with debugging.
    """
    model = Sequential()
    
    # First LSTM layer (Bidirectional) with return_sequences for stacking
    model.add(Bidirectional(LSTM(64, return_sequences=True), input_shape=input_shape))
    debug_print("Added Bidirectional LSTM layer with 64 units and return_sequences=True")
    
    # Dropout for regularization
    model.add(Dropout(0.5))
    debug_print("Added Dropout layer with 50% rate after first LSTM")
    
    # Second LSTM layer (stacked)
    model.add(LSTM(32))
    debug_print("Added second LSTM layer with 32 units")
    
    # Additional Dropout layer
    model.add(Dropout(0.3))
    debug_print("Added Dropout layer with 30% rate after second LSTM")
    
    # Additional Dense layer for complex representations
    model.add(Dense(32, activation='relu'))
    debug_print("Added Dense layer with 32 units and ReLU activation")
    
    # Final Dense layer for binary classification
    model.add(Dense(1, activation='sigmoid'))
    debug_print("Added final Dense layer with sigmoid activation for binary classification")
    
    # Create an Adam optimizer with the specified learning rate
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
    
    # Compile the model
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
    debug_print("Compiled the improved model with Adam optimizer and binary crossentropy loss.")
    
    # Print model summary for debugging purposes
    debug_print("Improved model summary:")
    model.summary(print_fn=debug_print)
    
    return model

class DebugCallback(Callback):
    """Custom callback to print debug information after each epoch."""
    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        log_str = ", ".join([f"{k}: {v:.4f}" for k, v in logs.items()])
        debug_print(f"Epoch {epoch+1} - {log_str}")

def plot_learning_curves(history):
    """Plot training and validation loss and accuracy."""
    plt.figure(figsize=(12, 5))
    
    # Loss curve
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss Curve')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    
    # Accuracy curve
    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Accuracy Curve')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    
    plt.tight_layout()
    plt.show()

def evaluate_model(model, X_test, y_test):
    """Evaluate the model and display confusion matrix and classification report."""
    y_pred = (model.predict(X_test) > 0.5).astype("int32")
    
    # Generate confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                xticklabels=['Underway', 'sailing'], yticklabels=['Underway', 'sailing'])
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()
    
    # Print classification report
    print("Classification Report:")
    print(classification_report(y_test, y_pred, target_names=['Underway', 'sailing']))

def main():
    # Directories where CSV files are stored.
    data_dir_sailing = '../5_Data_Pipeline/input/under_way_sailing'
    data_dir_underway = '../5_Data_Pipeline/input/underway_using_engine'
    
    # Load the data with time features
    X, y = load_data_with_time(data_dir_sailing, data_dir_underway)
    debug_print(f"Shape of loaded data X: {X.shape}")
    debug_print(f"Shape of labels y: {y.shape}")
    
    # Undersample to balance classes
    X, y = undersample_data(X, y)
    debug_print(f"Data after undersampling - X shape: {X.shape}, y shape: {y.shape}")
    
    # Shuffle the dataset
    indices = np.arange(len(X))
    np.random.shuffle(indices)
    X = X[indices]
    y = y[indices]
    debug_print("Data has been shuffled.")
    
    # Split into training and testing sets (e.g., 80% training, 20% testing)
    split_index = int(0.8 * len(X))
    X_train, X_test = X[:split_index], X[split_index:]
    y_train, y_test = y[:split_index], y[split_index:]
    debug_print(f"Training samples: {len(X_train)}; Testing samples: {len(X_test)}")
    
    # Determine sequence length and number of features for the LSTM input
    seq_length = X_train.shape[1]
    n_features = X_train.shape[2]
    input_shape = (seq_length, n_features)
    debug_print(f"Input shape for the LSTM: {input_shape}")
    
    # Build the improved LSTM model
    model = build_improved_model(input_shape)
    
    # Define callbacks, including the custom debug callback
    callbacks = [
        DebugCallback(),
        EarlyStopping(monitor='val_accuracy', patience=20, verbose=1),
        ModelCheckpoint('best_model.h5', monitor='val_accuracy', save_best_only=True, verbose=1),
        TensorBoard(log_dir='./logs')
    ]
    
    # Train the model
    history = model.fit(
        X_train, y_train,
        epochs=200,
        batch_size=16,
        validation_data=(X_test, y_test),
        callbacks=callbacks,
        verbose=1
    )
    debug_print("Training complete.")
    
    # Evaluate the model on the test set
    loss, accuracy = model.evaluate(X_test, y_test, verbose=1)
    debug_print(f"Test Loss: {loss:.4f}, Test Accuracy: {accuracy:.4f}")
    
    # Plot learning curves and evaluate the model performance
    plot_learning_curves(history)
    evaluate_model(model, X_test, y_test)

if __name__ == '__main__':
    main()
# Out:
# Found 925 sailing files in ../5_Data_Pipeline/input/under_way_sailing
# Found 5645 underway files in ../5_Data_Pipeline/input/underway_using_engine
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211210280_20240610_0622-20240610_0637_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211210280_20240610_0652-20240610_0707_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211210280_20240610_0707-20240610_0722_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211210280_20240610_0752-20240610_0807_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211210280_20240610_0837-20240610_0852_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211210280_20240610_0852-20240610_0907_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211210280_20240610_0907-20240610_0922_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211210280_20240610_0922-20240610_0937_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211210280_20240610_0937-20240610_0952_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211215170_20240530_0547-20240530_0602_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211215170_20240530_0602-20240530_0617_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211215170_20240530_0617-20240530_0632_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211215170_20240530_0632-20240530_0647_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211215170_20240530_0747-20240530_0802_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211215170_20240530_0802-20240530_0817_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211215170_20240530_0817-20240530_0832_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211215170_20240530_0832-20240530_0847_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211215170_20240530_0932-20240530_0947_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211237730_20240525_2257-20240525_2312_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211237730_20240525_2327-20240525_2342_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211237730_20240525_2342-20240525_2357_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211237730_20240526_0027-20240526_0042_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211237730_20240526_0042-20240526_0057_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211237730_20240526_0057-20240526_0112_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211237730_20240526_0112-20240526_0127_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211237730_20240526_0142-20240526_0157_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211237730_20240526_0212-20240526_0227_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211237730_20240526_0242-20240526_0257_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211237730_20240526_0257-20240526_0312_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211237730_20240526_0312-20240526_0327_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211237730_20240526_0327-20240526_0342_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211237730_20240526_0342-20240526_0357_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211237730_20240606_0645-20240606_0700_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211237730_20240606_0700-20240606_0715_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211237730_20240606_0715-20240606_0730_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211237730_20240606_0730-20240606_0745_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211237730_20240606_0815-20240606_0830_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211237730_20240606_0830-20240606_0845_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211237730_20240606_0900-20240606_0915_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211237730_20240606_0930-20240606_0945_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211237730_20240606_0945-20240606_1000_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211237730_20240606_1000-20240606_1015_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211237730_20240606_1015-20240606_1030_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211237730_20240606_1030-20240606_1045_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211237730_20240606_1045-20240606_1100_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211237730_20240606_1100-20240606_1115_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211237730_20240606_1115-20240606_1130_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211237730_20240606_1130-20240606_1145_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211237730_20240606_1200-20240606_1215_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211249130_20240422_0832-20240422_0847_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211249130_20240422_0947-20240422_1002_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211249130_20240422_1017-20240422_1032_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211249130_20240422_1102-20240422_1117_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211249130_20240422_1132-20240422_1147_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211249130_20240422_1147-20240422_1202_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211249130_20240422_1202-20240422_1217_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211249130_20240422_1217-20240422_1232_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211249130_20240422_1247-20240422_1302_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211249130_20240422_1302-20240422_1317_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211249130_20240422_1317-20240422_1332_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211249130_20240423_0447-20240423_0502_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211895440_20240628_1248-20240628_1303_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211895440_20240628_1303-20240628_1317_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211895440_20240628_1318-20240628_1332_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211895440_20240628_1333-20240628_1348_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211895440_20240628_1348-20240628_1402_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211895440_20240628_1403-20240628_1417_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211895440_20240628_1433-20240628_1448_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_211895440_20240628_1448-20240628_1502_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240616_2355-20240617_0010_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240617_0010-20240617_0025_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240617_0040-20240617_0055_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240617_0140-20240617_0155_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240617_0155-20240617_0210_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240617_0210-20240617_0225_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240617_0225-20240617_0240_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240617_0255-20240617_0310_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240617_0310-20240617_0325_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240617_0325-20240617_0340_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240617_0340-20240617_0355_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240617_0355-20240617_0410_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240617_0410-20240617_0425_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240617_0425-20240617_0440_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240617_0440-20240617_0455_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240617_0510-20240617_0525_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240617_0540-20240617_0555_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240617_0610-20240617_0625_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240617_0640-20240617_0655_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240617_0655-20240617_0710_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240617_0710-20240617_0725_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240617_0725-20240617_0740_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240617_0740-20240617_0755_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240617_0755-20240617_0810_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240617_0825-20240617_0840_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240617_0840-20240617_0855_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240617_0855-20240617_0910_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240617_0910-20240617_0925_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240617_0925-20240617_0940_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240617_0940-20240617_0955_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240617_0955-20240617_1010_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240617_1010-20240617_1025_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240621_1310-20240621_1325_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240621_1325-20240621_1340_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240621_1340-20240621_1355_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240621_1425-20240621_1440_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240621_1440-20240621_1455_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240621_1455-20240621_1510_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240621_1510-20240621_1525_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240621_1525-20240621_1540_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240621_1540-20240621_1555_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240621_1610-20240621_1625_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240621_1625-20240621_1640_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240621_1655-20240621_1710_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240621_1725-20240621_1740_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240621_1740-20240621_1755_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240623_0410-20240623_0425_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240623_0425-20240623_0440_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240623_0440-20240623_0455_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240623_0510-20240623_0525_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240623_0525-20240623_0540_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240623_0540-20240623_0555_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240623_0555-20240623_0610_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240623_0610-20240623_0625_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240623_0625-20240623_0640_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240623_0655-20240623_0710_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240623_0725-20240623_0740_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240623_0740-20240623_0755_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240623_0755-20240623_0810_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240623_0810-20240623_0825_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240623_0825-20240623_0840_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240623_0840-20240623_0855_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240623_0855-20240623_0910_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240623_0910-20240623_0925_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240623_0940-20240623_0955_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_218768000_20240623_0955-20240623_1010_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_219001275_20240321_2221-20240321_2235_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_219001275_20240321_2251-20240321_2306_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_219001275_20240322_0006-20240322_0021_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_219001275_20240322_0051-20240322_0105_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_219001275_20240322_0121-20240322_0136_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_219001275_20240322_0221-20240322_0236_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_219001275_20240322_0251-20240322_0305_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_219001275_20240322_0306-20240322_0321_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_219001275_20240322_0321-20240322_0336_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_219001275_20240322_0406-20240322_0420_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_219001275_20240322_0421-20240322_0436_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_219001275_20240322_0451-20240322_0505_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_219001275_20240322_0506-20240322_0520_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_219001275_20240322_0521-20240322_0536_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_219001275_20240322_0536-20240322_0550_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_219001275_20240322_0551-20240322_0605_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_219001275_20240322_0621-20240322_0635_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_219001275_20240322_0651-20240322_0706_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_219001275_20240322_0721-20240322_0735_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_219001275_20240322_0736-20240322_0750_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_219001275_20240323_0436-20240323_0451_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_219001275_20240323_0621-20240323_0636_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_219001275_20240323_0636-20240323_0651_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_219001275_20240323_0651-20240323_0706_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_219001275_20240325_1851-20240325_1906_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_219001275_20240325_1906-20240325_1921_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_219001275_20240325_1921-20240325_1936_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_219001275_20240325_1936-20240325_1951_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_219001275_20240325_1951-20240325_2006_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_219001275_20240325_2006-20240325_2021_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_219001275_20240325_2036-20240325_2051_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# Loaded sailing file ../5_Data_Pipeline/input/under_way_sailing\filtered_219001275_20240325_2106-20240325_2121_standardized_10s.csv with feature shape (90, 5).
# Converted Timestamp to datetime.
# Extracted hour from Timestamp.
# Applied cyclical encoding: created 'hour_sin' and 'hour_cos'.
# ...
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (None, 90, 128)          35840
#  l)
#
#  dropout (Dropout)           (None, 90, 128)           0
#
#  lstm_1 (LSTM)               (None, 32)                20608
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense (Dense)               (None, 32)                1056
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 57,537
# Trainable params: 57,537
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
#  5/93 [>.............................] - ETA: 2s - loss: 0.7236 - accuracy: 0.4000WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0190s vs `on_train_batch_end` time: 0.0328s). Check your callbacks.
# 93/93 [==============================] - ETA: 0s - loss: 0.6988 - accuracy: 0.5000Epoch 1 - loss: 0.6988, accuracy: 0.5000, val_loss: 0.6835, val_accuracy: 0.5703
#
# Epoch 1: val_accuracy improved from -inf to 0.57027, saving model to best_model.h5
# 93/93 [==============================] - 8s 29ms/step - loss: 0.6988 - accuracy: 0.5000 - val_loss: 0.6835 - val_accuracy: 0.5703
# Epoch 2/200
# 93/93 [==============================] - ETA: 0s - loss: 0.6849 - accuracy: 0.5284Epoch 2 - loss: 0.6849, accuracy: 0.5284, val_loss: 0.6776, val_accuracy: 0.5514
#
# Epoch 2: val_accuracy did not improve from 0.57027
# 93/93 [==============================] - 1s 16ms/step - loss: 0.6849 - accuracy: 0.5284 - val_loss: 0.6776 - val_accuracy: 0.5514
# Epoch 3/200
# 90/93 [============================>.] - ETA: 0s - loss: 0.6782 - accuracy: 0.5736Epoch 3 - loss: 0.6774, accuracy: 0.5757, val_loss: 0.6747, val_accuracy: 0.5459
#
# Epoch 3: val_accuracy did not improve from 0.57027
# 93/93 [==============================] - 1s 16ms/step - loss: 0.6774 - accuracy: 0.5757 - val_loss: 0.6747 - val_accuracy: 0.5459
# Epoch 4/200
# 91/93 [============================>.] - ETA: 0s - loss: 0.6769 - accuracy: 0.5598Epoch 4 - loss: 0.6761, accuracy: 0.5622, val_loss: 0.6719, val_accuracy: 0.5622
#
# Epoch 4: val_accuracy did not improve from 0.57027
# 93/93 [==============================] - 1s 16ms/step - loss: 0.6761 - accuracy: 0.5622 - val_loss: 0.6719 - val_accuracy: 0.5622
# Epoch 5/200
# 90/93 [============================>.] - ETA: 0s - loss: 0.6683 - accuracy: 0.5764Epoch 5 - loss: 0.6686, accuracy: 0.5777, val_loss: 0.6727, val_accuracy: 0.5676
#
# Epoch 5: val_accuracy did not improve from 0.57027
# 93/93 [==============================] - 1s 15ms/step - loss: 0.6686 - accuracy: 0.5777 - val_loss: 0.6727 - val_accuracy: 0.5676
# Epoch 6/200
# 90/93 [============================>.] - ETA: 0s - loss: 0.6607 - accuracy: 0.5826Epoch 6 - loss: 0.6604, accuracy: 0.5838, val_loss: 0.6709, val_accuracy: 0.5784
#
# Epoch 6: val_accuracy improved from 0.57027 to 0.57838, saving model to best_model.h5
# 93/93 [==============================] - 2s 16ms/step - loss: 0.6604 - accuracy: 0.5838 - val_loss: 0.6709 - val_accuracy: 0.5784
# Epoch 7/200
# 91/93 [============================>.] - ETA: 0s - loss: 0.6617 - accuracy: 0.5804Epoch 7 - loss: 0.6628, accuracy: 0.5791, val_loss: 0.6707, val_accuracy: 0.5811
#
# Epoch 7: val_accuracy improved from 0.57838 to 0.58108, saving model to best_model.h5
# 93/93 [==============================] - 2s 16ms/step - loss: 0.6628 - accuracy: 0.5791 - val_loss: 0.6707 - val_accuracy: 0.5811
# Epoch 8/200
# 92/93 [============================>.] - ETA: 0s - loss: 0.6599 - accuracy: 0.5883Epoch 8 - loss: 0.6599, accuracy: 0.5892, val_loss: 0.6709, val_accuracy: 0.5838
#
# Epoch 8: val_accuracy improved from 0.58108 to 0.58378, saving model to best_model.h5
# 93/93 [==============================] - 2s 17ms/step - loss: 0.6599 - accuracy: 0.5892 - val_loss: 0.6709 - val_accuracy: 0.5838
# Epoch 9/200
# 91/93 [============================>.] - ETA: 0s - loss: 0.6538 - accuracy: 0.5920Epoch 9 - loss: 0.6547, accuracy: 0.5912, val_loss: 0.6657, val_accuracy: 0.5757
#
# Epoch 9: val_accuracy did not improve from 0.58378
# 93/93 [==============================] - 2s 18ms/step - loss: 0.6547 - accuracy: 0.5912 - val_loss: 0.6657 - val_accuracy: 0.5757
# Epoch 10/200
# 90/93 [============================>.] - ETA: 0s - loss: 0.6532 - accuracy: 0.6104Epoch 10 - loss: 0.6531, accuracy: 0.6095, val_loss: 0.6664, val_accuracy: 0.5811
#
# Epoch 10: val_accuracy did not improve from 0.58378
# 93/93 [==============================] - 2s 18ms/step - loss: 0.6531 - accuracy: 0.6095 - val_loss: 0.6664 - val_accuracy: 0.5811
# Epoch 11/200
# 91/93 [============================>.] - ETA: 0s - loss: 0.6534 - accuracy: 0.5982Epoch 11 - loss: 0.6519, accuracy: 0.6000, val_loss: 0.6617, val_accuracy: 0.6351
#
# Epoch 11: val_accuracy improved from 0.58378 to 0.63514, saving model to best_model.h5
# 93/93 [==============================] - 2s 16ms/step - loss: 0.6519 - accuracy: 0.6000 - val_loss: 0.6617 - val_accuracy: 0.6351
# Epoch 12/200
# 90/93 [============================>.] - ETA: 0s - loss: 0.6465 - accuracy: 0.6160Epoch 12 - loss: 0.6457, accuracy: 0.6203, val_loss: 0.6566, val_accuracy: 0.6216
#
# Epoch 12: val_accuracy did not improve from 0.63514
# 93/93 [==============================] - 1s 16ms/step - loss: 0.6457 - accuracy: 0.6203 - val_loss: 0.6566 - val_accuracy: 0.6216
# Epoch 13/200
# 91/93 [============================>.] - ETA: 0s - loss: 0.6285 - accuracy: 0.6538Epoch 13 - loss: 0.6291, accuracy: 0.6527, val_loss: 0.6569, val_accuracy: 0.6351
#
# Epoch 13: val_accuracy did not improve from 0.63514
# 93/93 [==============================] - 1s 16ms/step - loss: 0.6291 - accuracy: 0.6527 - val_loss: 0.6569 - val_accuracy: 0.6351
# Epoch 14/200
# 92/93 [============================>.] - ETA: 0s - loss: 0.6351 - accuracy: 0.6359Epoch 14 - loss: 0.6355, accuracy: 0.6351, val_loss: 0.6560, val_accuracy: 0.6486
#
# Epoch 14: val_accuracy improved from 0.63514 to 0.64865, saving model to best_model.h5
# 93/93 [==============================] - 1s 16ms/step - loss: 0.6355 - accuracy: 0.6351 - val_loss: 0.6560 - val_accuracy: 0.6486
# Epoch 15/200
# 90/93 [============================>.] - ETA: 0s - loss: 0.6334 - accuracy: 0.6444Epoch 15 - loss: 0.6335, accuracy: 0.6453, val_loss: 0.6549, val_accuracy: 0.6324
#
# Epoch 15: val_accuracy did not improve from 0.64865
# 93/93 [==============================] - 1s 16ms/step - loss: 0.6335 - accuracy: 0.6453 - val_loss: 0.6549 - val_accuracy: 0.6324
# Epoch 16/200
# 93/93 [==============================] - ETA: 0s - loss: 0.6258 - accuracy: 0.6372Epoch 16 - loss: 0.6258, accuracy: 0.6372, val_loss: 0.6630, val_accuracy: 0.6216
#
# Epoch 16: val_accuracy did not improve from 0.64865
# 93/93 [==============================] - 2s 18ms/step - loss: 0.6258 - accuracy: 0.6372 - val_loss: 0.6630 - val_accuracy: 0.6216
# Epoch 17/200
# 93/93 [==============================] - ETA: 0s - loss: 0.6141 - accuracy: 0.6574Epoch 17 - loss: 0.6141, accuracy: 0.6574, val_loss: 0.6539, val_accuracy: 0.6432
#
# Epoch 17: val_accuracy did not improve from 0.64865
# 93/93 [==============================] - 2s 18ms/step - loss: 0.6141 - accuracy: 0.6574 - val_loss: 0.6539 - val_accuracy: 0.6432
# Epoch 18/200
# 91/93 [============================>.] - ETA: 0s - loss: 0.6258 - accuracy: 0.6449Epoch 18 - loss: 0.6256, accuracy: 0.6439, val_loss: 0.6562, val_accuracy: 0.6541
#
# Epoch 18: val_accuracy improved from 0.64865 to 0.65405, saving model to best_model.h5
# 93/93 [==============================] - 2s 17ms/step - loss: 0.6256 - accuracy: 0.6439 - val_loss: 0.6562 - val_accuracy: 0.6541
# Epoch 19/200
# 89/93 [===========================>..] - ETA: 0s - loss: 0.6220 - accuracy: 0.6440Epoch 19 - loss: 0.6215, accuracy: 0.6459, val_loss: 0.6715, val_accuracy: 0.6216
#
# Epoch 19: val_accuracy did not improve from 0.65405
# 93/93 [==============================] - 1s 16ms/step - loss: 0.6215 - accuracy: 0.6459 - val_loss: 0.6715 - val_accuracy: 0.6216
# Epoch 20/200
# 93/93 [==============================] - ETA: 0s - loss: 0.6123 - accuracy: 0.6696Epoch 20 - loss: 0.6123, accuracy: 0.6696, val_loss: 0.6796, val_accuracy: 0.6216
#
# Epoch 20: val_accuracy did not improve from 0.65405
# 93/93 [==============================] - 2s 18ms/step - loss: 0.6123 - accuracy: 0.6696 - val_loss: 0.6796 - val_accuracy: 0.6216
# Epoch 21/200
# 91/93 [============================>.] - ETA: 0s - loss: 0.6030 - accuracy: 0.6861Epoch 21 - loss: 0.6032, accuracy: 0.6851, val_loss: 0.6695, val_accuracy: 0.6189
#
# Epoch 21: val_accuracy did not improve from 0.65405
# 93/93 [==============================] - 2s 19ms/step - loss: 0.6032 - accuracy: 0.6851 - val_loss: 0.6695 - val_accuracy: 0.6189
# Epoch 22/200
# 90/93 [============================>.] - ETA: 0s - loss: 0.6065 - accuracy: 0.6736Epoch 22 - loss: 0.6058, accuracy: 0.6757, val_loss: 0.6660, val_accuracy: 0.5973
#
# Epoch 22: val_accuracy did not improve from 0.65405
# 93/93 [==============================] - 2s 18ms/step - loss: 0.6058 - accuracy: 0.6757 - val_loss: 0.6660 - val_accuracy: 0.5973
# Epoch 23/200
# 90/93 [============================>.] - ETA: 0s - loss: 0.6050 - accuracy: 0.6826Epoch 23 - loss: 0.6081, accuracy: 0.6770, val_loss: 0.6720, val_accuracy: 0.6000
#
# Epoch 23: val_accuracy did not improve from 0.65405
# 93/93 [==============================] - 2s 18ms/step - loss: 0.6081 - accuracy: 0.6770 - val_loss: 0.6720 - val_accuracy: 0.6000
# Epoch 24/200
# 90/93 [============================>.] - ETA: 0s - loss: 0.6040 - accuracy: 0.6694Epoch 24 - loss: 0.6029, accuracy: 0.6696, val_loss: 0.6608, val_accuracy: 0.6405
#
# Epoch 24: val_accuracy did not improve from 0.65405
# 93/93 [==============================] - 2s 17ms/step - loss: 0.6029 - accuracy: 0.6696 - val_loss: 0.6608 - val_accuracy: 0.6405
# Epoch 25/200
# 93/93 [==============================] - ETA: 0s - loss: 0.5873 - accuracy: 0.6993Epoch 25 - loss: 0.5873, accuracy: 0.6993, val_loss: 0.6715, val_accuracy: 0.6351
#
# Epoch 25: val_accuracy did not improve from 0.65405
# 93/93 [==============================] - 2s 16ms/step - loss: 0.5873 - accuracy: 0.6993 - val_loss: 0.6715 - val_accuracy: 0.6351
# Epoch 26/200
# 92/93 [============================>.] - ETA: 0s - loss: 0.5997 - accuracy: 0.6821Epoch 26 - loss: 0.6001, accuracy: 0.6804, val_loss: 0.6721, val_accuracy: 0.6378
#
# Epoch 26: val_accuracy did not improve from 0.65405
# 93/93 [==============================] - 2s 18ms/step - loss: 0.6001 - accuracy: 0.6804 - val_loss: 0.6721 - val_accuracy: 0.6378
# Epoch 27/200
# 93/93 [==============================] - ETA: 0s - loss: 0.5945 - accuracy: 0.6899Epoch 27 - loss: 0.5945, accuracy: 0.6899, val_loss: 0.6697, val_accuracy: 0.6270
#
# Epoch 27: val_accuracy did not improve from 0.65405
# 93/93 [==============================] - 2s 18ms/step - loss: 0.5945 - accuracy: 0.6899 - val_loss: 0.6697 - val_accuracy: 0.6270
# Epoch 28/200
# 90/93 [============================>.] - ETA: 0s - loss: 0.5845 - accuracy: 0.6986Epoch 28 - loss: 0.5845, accuracy: 0.7000, val_loss: 0.6856, val_accuracy: 0.6027
#
# Epoch 28: val_accuracy did not improve from 0.65405
# 93/93 [==============================] - 1s 16ms/step - loss: 0.5845 - accuracy: 0.7000 - val_loss: 0.6856 - val_accuracy: 0.6027
# Epoch 29/200
# 92/93 [============================>.] - ETA: 0s - loss: 0.5952 - accuracy: 0.6834Epoch 29 - loss: 0.5951, accuracy: 0.6824, val_loss: 0.6748, val_accuracy: 0.6486
#
# Epoch 29: val_accuracy did not improve from 0.65405
# 93/93 [==============================] - 1s 16ms/step - loss: 0.5951 - accuracy: 0.6824 - val_loss: 0.6748 - val_accuracy: 0.6486
# Epoch 30/200
# 91/93 [============================>.] - ETA: 0s - loss: 0.5807 - accuracy: 0.6978Epoch 30 - loss: 0.5811, accuracy: 0.6966, val_loss: 0.6733, val_accuracy: 0.6351
#
# Epoch 30: val_accuracy did not improve from 0.65405
# 93/93 [==============================] - 2s 18ms/step - loss: 0.5811 - accuracy: 0.6966 - val_loss: 0.6733 - val_accuracy: 0.6351
# Epoch 31/200
# 92/93 [============================>.] - ETA: 0s - loss: 0.5711 - accuracy: 0.7106Epoch 31 - loss: 0.5729, accuracy: 0.7081, val_loss: 0.6697, val_accuracy: 0.6324
#
# Epoch 31: val_accuracy did not improve from 0.65405
# 93/93 [==============================] - 1s 16ms/step - loss: 0.5729 - accuracy: 0.7081 - val_loss: 0.6697 - val_accuracy: 0.6324
# Epoch 32/200
# 92/93 [============================>.] - ETA: 0s - loss: 0.5745 - accuracy: 0.6997Epoch 32 - loss: 0.5741, accuracy: 0.7000, val_loss: 0.6883, val_accuracy: 0.6000
#
# Epoch 32: val_accuracy did not improve from 0.65405
# 93/93 [==============================] - 2s 18ms/step - loss: 0.5741 - accuracy: 0.7000 - val_loss: 0.6883 - val_accuracy: 0.6000
# Epoch 33/200
# 91/93 [============================>.] - ETA: 0s - loss: 0.5827 - accuracy: 0.7033Epoch 33 - loss: 0.5812, accuracy: 0.7047, val_loss: 0.6818, val_accuracy: 0.6405
#
# Epoch 33: val_accuracy did not improve from 0.65405
# 93/93 [==============================] - 2s 18ms/step - loss: 0.5812 - accuracy: 0.7047 - val_loss: 0.6818 - val_accuracy: 0.6405
# Epoch 34/200
# 90/93 [============================>.] - ETA: 0s - loss: 0.5632 - accuracy: 0.7083Epoch 34 - loss: 0.5640, accuracy: 0.7074, val_loss: 0.6859, val_accuracy: 0.6405
#
# Epoch 34: val_accuracy did not improve from 0.65405
# 93/93 [==============================] - 1s 16ms/step - loss: 0.5640 - accuracy: 0.7074 - val_loss: 0.6859 - val_accuracy: 0.6405
# Epoch 35/200
# 92/93 [============================>.] - ETA: 0s - loss: 0.5647 - accuracy: 0.7106Epoch 35 - loss: 0.5642, accuracy: 0.7108, val_loss: 0.6823, val_accuracy: 0.6541
#
# Epoch 35: val_accuracy did not improve from 0.65405
# 93/93 [==============================] - 2s 16ms/step - loss: 0.5642 - accuracy: 0.7108 - val_loss: 0.6823 - val_accuracy: 0.6541
# Epoch 36/200
# 89/93 [===========================>..] - ETA: 0s - loss: 0.5768 - accuracy: 0.6987Epoch 36 - loss: 0.5739, accuracy: 0.7007, val_loss: 0.6744, val_accuracy: 0.6324
#
# Epoch 36: val_accuracy did not improve from 0.65405
# 93/93 [==============================] - 2s 18ms/step - loss: 0.5739 - accuracy: 0.7007 - val_loss: 0.6744 - val_accuracy: 0.6324
# Epoch 37/200
# 91/93 [============================>.] - ETA: 0s - loss: 0.5660 - accuracy: 0.7150Epoch 37 - loss: 0.5658, accuracy: 0.7142, val_loss: 0.6731, val_accuracy: 0.6378
#
# Epoch 37: val_accuracy did not improve from 0.65405
# 93/93 [==============================] - 1s 16ms/step - loss: 0.5658 - accuracy: 0.7142 - val_loss: 0.6731 - val_accuracy: 0.6378
# Epoch 38/200
# 91/93 [============================>.] - ETA: 0s - loss: 0.5625 - accuracy: 0.7081Epoch 38 - loss: 0.5625, accuracy: 0.7081, val_loss: 0.6961, val_accuracy: 0.6514
#
# Epoch 38: val_accuracy did not improve from 0.65405
# 93/93 [==============================] - 2s 17ms/step - loss: 0.5625 - accuracy: 0.7081 - val_loss: 0.6961 - val_accuracy: 0.6514
# Epoch 38: early stopping
# Training complete.
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6961 - accuracy: 0.6514
# Test Loss: 0.6961, Test Accuracy: 0.6514
# 12/12 [==============================] - 1s 10ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#     Underway       0.67      0.62      0.64       187
#      sailing       0.64      0.68      0.66       183
#
#     accuracy                           0.65       370
#    macro avg       0.65      0.65      0.65       370
# weighted avg       0.65      0.65      0.65       370

# %%
# Save the model
model.save("navstat_classifier_binary_sail.h5")

# %% [markdown]
# # Explanation:
#
# ### 1. **Loading CSV Files from the Folder:**
#    - The function loops through the CSV files in the given folder, one by one. It reads each CSV file using `pandas.read_csv()` and processes the data.
#    - These CSV files contain the vessel's movement data with columns like `SOG`, `COG`, and `Heading`.
#
#    **Example of data loaded from a CSV file:**
#
#    | Timestamp | SOG | COG  | Heading |
#    |-----------|-----|------|---------|
#    | 00:00     | 5.4 | 45   | 60      |
#    | 00:01     | 5.6 | 47   | 61      |
#    | 00:02     | 5.7 | 50   | 62      |
#    | ...       | ... | ...  | ...     |
#
#    Here, **SOG** is the speed of the vessel, **COG** is the course (direction), and **Heading** is the heading angle.
#
# ### 2. **Normalization of `SOG` (Speed Over Ground):**
#    - The `SOG` column is normalized using a `MinMaxScaler`, which scales all values to a range between 0 and 1.
#    - **Normalization** is important because it brings different feature scales (e.g., speed vs. angle) to a similar range, making the training process more efficient.
#
#    **Before normalization:**
#
#    | Timestamp | SOG | COG  | Heading |
#    |-----------|-----|------|---------|
#    | 00:00     | 5.4 | 45   | 60      |
#    | 00:01     | 5.6 | 47   | 61      |
#
#    **After normalization:**
#
#    The new values for `SOG` are calculated using:
#    \[
#    \text{Normalized SOG} = \frac{\text{SOG} - \text{min(SOG)}}{\text{max(SOG)} - \text{min(SOG)}}
#    \]
#
#    | Timestamp | Normalized SOG | COG  | Heading |
#    |-----------|----------------|------|---------|
#    | 00:00     | 0.00           | 45   | 60      |
#    | 00:01     | 0.33           | 47   | 61      |
#
# ### 3. **Cyclic Encoding of `COG` and `Heading`:**
#    - Both `COG` (Course Over Ground) and `Heading` are angular values, and as such, they have a **cyclic nature**: 0 degrees is the same as 360 degrees.
#    - To properly handle this, **sine** and **cosine** transformations are applied:
#      \[
#      \text{COG}_x = \sin(\text{COG})
#      \]
#      \[
#      \text{COG}_y = \cos(\text{COG})
#      \]
#      Similarly for `Heading`:
#      \[
#      \text{Heading}_x = \sin(\text{Heading})
#      \]
#      \[
#      \text{Heading}_y = \cos(\text{Heading})
#      \]
#    - These transformations convert the angular values into two components that are easier for the model to learn from and capture cyclic relationships.
#
#    **Example before and after cyclic encoding:**
#
#    - **Before** (COG = 350 degrees, Heading = 10 degrees):
#
#    | Timestamp | COG | Heading |
#    |-----------|-----|---------|
#    | 00:00     | 350 | 10      |
#
#    - **After** (Apply sine and cosine transformations):
#
#    | Timestamp | COG_x      | COG_y      | Heading_x  | Heading_y  |
#    |-----------|------------|------------|------------|------------|
#    | 00:00     | 0.1745     | 0.9848     | 0.1736     | 0.9848     |
#
# ### 4. **Selecting Relevant Features:**
#    - After encoding the `COG` and `Heading`, the relevant features are selected: `SOG`, `COG_x`, `COG_y`, `Heading_x`, and `Heading_y`.
#    - These features represent the vessel's speed and directional information in a form that the LSTM model can process.
#
#    **Features selected for each time step:**
#
#    | Timestamp | Normalized SOG | COG_x      | COG_y      | Heading_x  | Heading_y  |
#    |-----------|----------------|------------|------------|------------|------------|
#    | 00:00     | 0.00           | 0.1745     | 0.9848     | 0.1736     | 0.9848     |
#
# ### 5. **Creating Sequences:**
#    - The LSTM model requires input data in the form of sequences (i.e., multiple time steps). Here, a sliding window approach is used to create sequences of `sequence_length` (e.g., 60 time steps).
#    - For each sequence of 60 time steps, the features for those 60 steps are stacked into a 3D array (time steps, features per time step, and the number of sequences).
#    - This helps the model learn patterns over time (e.g., how the vessel's behavior changes over an hour).
#
#    **Example of sequences:**
#
#    For a sequence length of 3, if the first 3 time steps look like this:
#
#    | Timestamp | Normalized SOG | COG_x      | COG_y      | Heading_x  | Heading_y  |
#    |-----------|----------------|------------|------------|------------|------------|
#    | 00:00     | 0.00           | 0.1745     | 0.9848     | 0.1736     | 0.9848     |
#    | 00:01     | 0.33           | 0.1736     | 0.9848     | 0.1732     | 0.9849     |
#    | 00:02     | 0.50           | 0.1727     | 0.9850     | 0.1725     | 0.9850     |
#
#    The model will receive a sequence of these 3 time steps as input for training.
#
# ### 6. **Labeling the Sequences:**
#    - Each sequence is labeled with a binary value, depending on the activity of the vessel:
#      - **0** for "underway using engine".
#      - **1** for "engaged in sailing".
#    - This label helps the model learn the relationship between the features and the vessel's activity.
#
# ### 7. **Loading and Combining Data:**
#    - The function `load_and_preprocess_data` is called twice, once for the "underway" data and once for the "sailing" data.
#    - After processing, the resulting feature arrays (`data_underway` and `data_sailing`) are concatenated together to form the complete dataset `X`, and their corresponding labels (`labels_underway` and `labels_sailing`) are concatenated to form the labels array `y`.
#
# ### Final Data Structure:
#    After combining the data, you end up with:
#
#    - **X**: A 3D array where each element represents a sequence of features (e.g., 60 time steps × 5 features per step = 300 features per sequence).
#
#    - **y**: A 1D array with binary labels (0 or 1) indicating the vessel activity for each sequence.
#
# ---
#
# ### **Visualization of Sequences:**
#
# Here’s how the sequences would look when plotted for `SOG`, `COG_x`, and `Heading_x` for a few time steps:
#
# #### Example:
#
# - **Sequence Data (3 time steps):**
#
#   - `SOG`: [0.00, 0.33, 0.50]
#   - `COG_x`: [0.1745, 0.1736, 0.1727]
#   - `Heading_x`: [0.1736, 0.1732, 0.1725]

# %%
# Example sequences, like explained above.

import matplotlib.pyplot as plt

time_steps = [0, 1, 2]
SOG = [0.00, 0.33, 0.50]
COG_x = [0.1745, 0.1736, 0.1727]
Heading_x = [0.1736, 0.1732, 0.1725]

plt.figure(figsize=(12, 4))

plt.subplot(1, 3, 1)
plt.plot(time_steps, SOG, label="SOG", color="blue")
plt.title("SOG over Time")
plt.xlabel("Time Steps")
plt.ylabel("Normalized SOG")

plt.subplot(1, 3, 2)
plt.plot(time_steps, COG_x, label="COG_x", color="green")
plt.title("COG_x over Time")
plt.xlabel("Time Steps")
plt.ylabel("COG_x")

plt.subplot(1, 3, 3)
plt.plot(time_steps, Heading_x, label="Heading_x", color="red")
plt.title("Heading_x over Time")
plt.xlabel("Time Steps")
plt.ylabel("Heading_x")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Sliding Window in Sequence Creation
#
# In the current model setup, the **sliding window** approach is used to create sequences of a fixed length. This means that the **length of each sequence is constant** throughout the model's training process.
#
# ### What is the Sliding Window Approach?
#
# The sliding window technique extracts **overlapping sequences** from the raw time series data. The key idea is that the **window size** (i.e., the number of time steps per sequence) remains constant, and the window "slides" over the data to generate sequences.
#
# ### Key Points:
# 1. **Fixed Sequence Length**:
#    - The length of each sequence remains **constant**. In this case, the sequence length is defined by the `sequence_length` parameter (e.g., 60 time steps).
#    - This means every sequence the model receives has exactly the same number of time steps, no matter where the window starts.
#
# 2. **Sliding Window**:
#    - As the window moves across the dataset, each new sequence will **overlap** with the previous one by all but one time step.
#    - The window shifts one time step at a time, ensuring that each sequence captures information over a fixed duration.
#
# ### Example:
# Let’s assume we have raw data sampled every minute, and we set `sequence_length = 60`, meaning each sequence will consist of 60 time steps. If the raw data is as follows:
#
# | Timestamp | SOG | COG | Heading |
# |-----------|-----|-----|---------|
# | 00:00     | 5.4 | 45  | 60      |
# | 00:01     | 5.6 | 47  | 61      |
# | ...       | ... | ... | ...     |
# | 00:59     | 5.7 | 50  | 62      |
# | 01:00     | 5.8 | 52  | 63      |
#
# Then the sliding window works as follows:
# - **First sequence**: Consists of data from `00:00` to `00:59` (60 time steps).
# - **Second sequence**: Starts at `00:01` and goes to `01:00` (another 60 time steps).
# - **Third sequence**: Starts at `00:02` and goes to `01:01` (another 60 time steps), and so on.
#
# ### Sequence Structure:
# For each sequence, the LSTM model will receive a 3D array with:
# - **Time Steps (e.g., 60)**: The number of time steps per sequence.
# - **Features per Time Step (e.g., 5)**: The number of features recorded for each time step (like `SOG`, `COG_x`, `Heading_x`).
# - **Number of Sequences**: The number of sequences generated from the raw data.
#
# In this case, each sequence consists of **60 time steps**, and the sequence length does not vary.
#
# ### Why Use Sliding Window?
# - **Consistent Length**: Having sequences of a constant length helps the model learn consistent patterns across time.
# - **Temporal Dependencies**: The sliding window captures how the data evolves over time by looking at overlapping segments.
# - **Efficient Training**: The technique allows the model to train on overlapping portions of the data, making better use of available data.
