# %% [markdown]
# ## LSTM Model to predict vessel status
#
# ## Table of Contents
# 1. [Description](#model-selection)
# 2. [Further Datapreparation](#further-datapreparation)
# 3. [Model Script](#model-script)
# 4. [Detailed Explanations](#explanation)

# %% [markdown]
# ## Model Selection
#
# The problem at hand is a binary classification task to predict the navigational status of vessels: "Under way using engine" versus "Engaged in fishing." After experimenting with various approaches, including Random Forest and CNN, an LSTM-based neural network was chosen for its ability to model sequential dependencies in time-series data. The LSTM architecture was selected due to its effectiveness in capturing temporal patterns in features such as Speed Over Ground (SOG), Course Over Ground (COG), and Heading.
#
# ---
#
# ## Feature Engineering
#
# Feature engineering was a critical step in preparing the dataset for modeling. Key steps included:
#
# 1. **Normalization**: SOG values were normalized using MinMaxScaler to ensure all features were on a similar scale.
# 2. **Cyclical Encoding**: Circular features like COG and Heading were encoded using sine and cosine transformations to preserve their cyclical nature.
# 3. **Sequence Creation**: Each input sequence was created with a fixed length of 60 time steps, corresponding to 1 hour of data sampled at 1-minute intervals.
# 4. **Initial Course Adjustment**: The initial COG was subtracted from all COG and Heading values to standardize the directionality across sequences.
#
# ---
#
# ## Hyperparameter Tuning
#
# Hyperparameter tuning was conducted using a combination of manual experimentation and automated tools like Keras Tuner. Key hyperparameters tuned included:
#
# 1. **Number of LSTM Layers and Units**: Experiments with single and multi-layer LSTM architectures led to the final choice of two LSTM layers with 64 and 32 units, respectively.
# 2. **Dropout Rates**: Dropout rates of 0.3 were applied after each LSTM layer to mitigate overfitting.
# 3. **Batch Size and Learning Rate**: A batch size of 32 and the Adam optimizer with default learning rates provided the best results.
# 4. **Activation Functions**: The final output layer used a sigmoid activation function for binary classification.
#
# ---
#
# ## Implementation
#
# The LSTM model was implemented using TensorFlow/Keras. The architecture consisted of:
#
# - Two LSTM layers (64 and 32 units) with return sequences enabled for the first layer.
# - Dropout layers after each LSTM layer.
# - A Dense layer with 32 units and ReLU activation.
# - A final Dense layer with a sigmoid activation function for binary classification.
#
# Training was conducted with early stopping to monitor validation loss, with a patience of 10 epochs to prevent overfitting. The model was trained for up to 200 epochs, with validation split set to 20% of the training data.
#
# ---
#
# ## Evaluation Metrics
#
# The model’s performance was evaluated using:
#
# 1. **Accuracy**: Achieved a test accuracy of 0.99.
# 2. **F1 Score**: Recorded an F1 score of 0.99, indicating a balance between precision and recall.
# 3. **Precision and Recall**: Precision and recall scores were 0.99 and 0.98, respectively, demonstrating the model’s ability to minimize false positives and false negatives.
# 4. **Confusion Matrix**: Highlighted the model’s ability to correctly classify both classes with minimal misclassifications.
# 5. **ROC Curve and AUC**: The AUC of 0.99 indicated excellent model discrimination.
#
# ---
#
# ## Comparative Analysis
#
# The LSTM model outperformed other approaches, including:
#
# 1. **Baseline Random Forest Model**: Achieved an accuracy of 0.68–0.78, but struggled to recognize certain classes and lacked temporal modeling capabilities.
# 2. **CNN Architecture**: While capable of capturing spatial patterns, the CNN overfitted and did not leverage temporal dependencies effectively.
# 3. **Flattened Data Approach**: Flattening sequences into vectors led to faster computation but resulted in overfitting and lower generalization performance.
#
# The final LSTM model’s ability to capture temporal dependencies, combined with robust feature engineering and careful hyperparameter tuning, resulted in a significant performance improvement, making it the best-performing model for this task.

# %% [markdown]
# ## Further Datapreparation

# %%
import os
import shutil
import pandas as pd

# Define the source and destination folders
source_folder = '../5_Data_Pipeline/time_sets_st_shortened'
destination_folder = '../5_Data_Pipeline/input/underway_using_engine'

# Ensure destination folder exists
os.makedirs(destination_folder, exist_ok=True)

# Iterate over each file in the source folder
for filename in os.listdir(source_folder):
    # Check if the file is a CSV file
    if filename.endswith('.csv'):
        file_path = os.path.join(source_folder, filename)
        
        # Try to read the CSV file
        try:
            df = pd.read_csv(file_path)

            # Check if 'Navigational status' column exists and contains the value 'Underway using engine'
            if 'Navigational status' in df.columns and 'Under way using engine' in df['Navigational status'].values:
                # If the condition is met, copy the file to the destination folder
                shutil.copy(file_path, os.path.join(destination_folder, filename))
                # print(f"Copied: {filename}")
        except Exception as e:
            print(f"Could not process {filename}: {e}")

print("Script execution completed.")
# Out:
# Script execution completed.

# %% [markdown]
# ## Model Script

# %%
import os
import glob
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.callbacks import Callback, EarlyStopping, ModelCheckpoint, TensorBoard

# Global debug flag
DEBUG = True

def debug_print(message):
    """Print debugging messages when DEBUG is True."""
    if DEBUG:
        print(message)

def load_data(data_dir_fishing, data_dir_underway):
    """
    Load CSV files from two directories (one for each class) and return:
      X: NumPy array of shape (n_samples, sequence_length, n_features)
      y: NumPy array of shape (n_samples,)
      
    Assumes each CSV file has the same number of time steps and columns:
      Timestamp, Navigational status, SOG, COG, Heading
    Only SOG, COG, and Heading are used as features.
    """
    X, y = [], []
    
    # Get lists of CSV files for each class
    fishing_files = glob.glob(os.path.join(data_dir_fishing, '*.csv'))
    underway_files = glob.glob(os.path.join(data_dir_underway, '*.csv'))
    debug_print(f"Found {len(fishing_files)} fishing files in {data_dir_fishing}")
    debug_print(f"Found {len(underway_files)} underway files in {data_dir_underway}")
    
    # Define the required columns for the features
    required_cols = ['SOG', 'COG', 'Heading']
    
    # Process fishing files (label 0)
    for file in fishing_files:
        try:
            df = pd.read_csv(file)
            if not all(col in df.columns for col in required_cols):
                debug_print(f"File {file} missing required columns. Skipping.")
                continue
            features = df[required_cols].values
            X.append(features)
            y.append(0)
            #debug_print(f"Loaded file {file} with shape {features.shape} as class 0 (Fishing).")
        except Exception as e:
            debug_print(f"Error loading {file}: {e}")
    
    # Process underway files (label 1)
    for file in underway_files:
        try:
            df = pd.read_csv(file)
            if not all(col in df.columns for col in required_cols):
                debug_print(f"File {file} missing required columns. Skipping.")
                continue
            features = df[required_cols].values
            X.append(features)
            y.append(1)
            #debug_print(f"Loaded file {file} with shape {features.shape} as class 1 (Underway).")
        except Exception as e:
            debug_print(f"Error loading {file}: {e}")
    
    # Convert lists to NumPy arrays
    X = np.array(X)
    y = np.array(y)
    debug_print(f"Total samples loaded: {len(X)}")
    return X, y

def build_improved_model(input_shape):
    """
    Build and compile an improved LSTM model with additional layers and debugging.
    
    Parameters:
      input_shape: tuple (sequence_length, n_features)
    
    Returns:
      A compiled Keras model.
    """
    model = Sequential()
    
    # First LSTM layer (Bidirectional) with return_sequences for stacking
    model.add(Bidirectional(LSTM(64, return_sequences=True), input_shape=input_shape))
    debug_print("Added Bidirectional LSTM layer with 64 units and return_sequences=True")
    
    # Dropout for regularization
    model.add(Dropout(0.5))
    debug_print("Added Dropout layer with 50% rate after first LSTM")
    
    # Second LSTM layer (stacked)
    model.add(LSTM(32))
    debug_print("Added second LSTM layer with 32 units (default return_sequences=False)")
    
    # Additional Dropout layer
    model.add(Dropout(0.3))
    debug_print("Added Dropout layer with 30% rate after second LSTM")
    
    # Additional Dense layer for complex representations
    model.add(Dense(32, activation='relu'))
    debug_print("Added Dense layer with 32 units and ReLU activation")
    
    # Final Dense layer for binary classification
    model.add(Dense(1, activation='sigmoid'))
    debug_print("Added final Dense layer with sigmoid activation for binary classification")
    
    # Compile the model
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    debug_print("Compiled the improved model with Adam optimizer and binary crossentropy loss.")
    
    # Print model summary for debugging purposes
    debug_print("Improved model summary:")
    model.summary(print_fn=debug_print)
    
    return model

class DebugCallback(Callback):
    """Custom callback to print debug information after each epoch."""
    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        log_str = ", ".join([f"{k}: {v:.4f}" for k, v in logs.items()])
        debug_print(f"Epoch {epoch+1} - {log_str}")

def main():
    # Directories where CSV files are stored.
    data_dir_fishing = '../5_Data_Pipeline/input/engaged_in_fishing'
    data_dir_underway = '../5_Data_Pipeline/input/underway_using_engine'
    
    # Load the data
    X, y = load_data(data_dir_fishing, data_dir_underway)
    debug_print(f"Shape of loaded data X: {X.shape}")
    debug_print(f"Shape of labels y: {y.shape}")
    
    # Shuffle the dataset
    indices = np.arange(len(X))
    np.random.shuffle(indices)
    X = X[indices]
    y = y[indices]
    debug_print("Data has been shuffled.")
    
    # Split into training and testing sets (e.g., 80% training, 20% testing)
    split_index = int(0.8 * len(X))
    X_train, X_test = X[:split_index], X[split_index:]
    y_train, y_test = y[:split_index], y[split_index:]
    debug_print(f"Training samples: {len(X_train)}; Testing samples: {len(X_test)}")
    
    # Check sequence length and feature count.
    seq_length = X_train.shape[1]
    n_features = X_train.shape[2]
    input_shape = (seq_length, n_features)
    debug_print(f"Input shape for the LSTM: {input_shape}")
    
    # Build the improved LSTM model
    model = build_improved_model(input_shape)
    
    # Define callbacks including the custom debug callback
    callbacks = [
        DebugCallback(),
        EarlyStopping(monitor='val_accuracy', patience=20, verbose=1),
        ModelCheckpoint('best_model.h5', monitor='val_accuracy', save_best_only=True, verbose=1),
        TensorBoard(log_dir='./logs')
    ]
    
    # Train the model
    history = model.fit(
        X_train, y_train,
        epochs=200,
        batch_size=16,
        validation_data=(X_test, y_test),
        callbacks=callbacks,
        verbose=1
    )
    debug_print("Training complete.")
    
    # Evaluate the model on the test set
    loss, accuracy = model.evaluate(X_test, y_test, verbose=1)
    debug_print(f"Test Loss: {loss:.4f}, Test Accuracy: {accuracy:.4f}")

if __name__ == '__main__':
    main()
# Out:
# Found 6944 fishing files in ../5_Data_Pipeline/input/engaged_in_fishing
# Found 13913 underway files in ../5_Data_Pipeline/input/underway_using_engine
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_205106000_20240427_2203-20240428_0003_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_205144000_20240322_2306-20240323_0106_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_205144000_20240406_1805-20240406_2005_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_205144000_20240523_0325-20240523_0525_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_205144000_20240620_2313-20240621_0113_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_205144000_20240622_1913-20240622_2113_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_205144000_20240625_0113-20240625_0313_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_205144000_20240628_0113-20240628_0313_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_205144000_20241130_0526-20241130_0725_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_205208000_20240327_0115-20240327_0314_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_205453000_20240605_2349-20240606_0149_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_205465000_20240415_1405-20240415_1605_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_205681000_20240406_2142-20240406_2342_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_205689000_20241127_0907-20241127_1107_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_205743000_20240328_2016-20240328_2216_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_205769000_20240417_1618-20240417_1818_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_205769000_20240525_2042-20240525_2242_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_205769000_20240527_2242-20240528_0041_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_205770000_20240316_0545-20240316_0745_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_205770000_20240317_2145-20240317_2345_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_205770000_20240318_1408-20240318_1608_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_205771000_20240305_1132-20240305_1332_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_205771000_20240330_0732-20240330_0932_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_205771000_20240620_0831-20240620_1031_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_205772000_20240330_0041-20240330_0241_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_207138000_20240306_0957-20240306_1157_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_207138000_20240604_1428-20240604_1627_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209008000_20240609_2142-20240609_2342_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209014000_20240527_0026-20240527_0226_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209014000_20240608_1622-20240608_1822_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209075000_20240306_1021-20240306_1221_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209075000_20240524_2125-20240524_2325_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209114000_20240523_2124-20240523_2324_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209114000_20240605_2257-20240606_0057_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209114000_20240614_2257-20240615_0057_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209114000_20240615_0057-20240615_0257_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209168000_20240314_1537-20240314_1737_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209168000_20241126_0921-20241126_1121_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209184000_20240302_0455-20240302_0655_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209184000_20240418_1935-20240418_2135_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209184000_20240527_1758-20240527_1958_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209184000_20240605_0000-20240605_0200_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209184000_20240619_1800-20240619_1959_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209207000_20240311_0721-20240311_0921_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209207000_20240311_0921-20240311_1121_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209207000_20240317_2321-20240318_0121_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209207000_20240318_0121-20240318_0321_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209207000_20240328_1521-20240328_1721_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209207000_20240328_1721-20240328_1921_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209207000_20240407_2238-20240408_0038_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209207000_20240408_0038-20240408_0238_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209207000_20241130_0904-20241130_1103_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209211000_20240306_0317-20240306_0517_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209217000_20240520_1006-20240520_1206_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209217000_20240523_1439-20240523_1639_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209217000_20240523_1639-20240523_1839_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209217000_20240621_0213-20240621_0413_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209221000_20240611_1757-20240611_1957_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209223000_20240521_2253-20240522_0053_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209223000_20240628_0349-20240628_0549_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209239000_20240530_0041-20240530_0241_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209239000_20240605_1850-20240605_2049_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209275000_20240316_1654-20240316_1854_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209275000_20240316_1854-20240316_2054_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209275000_20240316_2054-20240316_2254_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209275000_20240316_2254-20240317_0054_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209275000_20240317_0054-20240317_0254_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209275000_20240317_0254-20240317_0454_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209275000_20240317_0454-20240317_0654_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209275000_20240317_0654-20240317_0854_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209275000_20240328_0656-20240328_0856_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209275000_20240328_0856-20240328_1056_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209275000_20240329_0455-20240329_0654_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209275000_20240405_2111-20240405_2311_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209275000_20240420_1511-20240420_1711_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209275000_20240421_0511-20240421_0711_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209275000_20240519_0730-20240519_0930_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209297000_20240302_2119-20240302_2318_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209313000_20240419_0344-20240419_0544_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209313000_20240616_1842-20240616_2042_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209314000_20240528_0332-20240528_0532_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209318000_20240424_1055-20240424_1255_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209318000_20240602_0954-20240602_1154_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209325000_20240626_0552-20240626_0752_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209332000_20240320_0455-20240320_0655_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209332000_20240327_1048-20240327_1248_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209332000_20240327_1248-20240327_1448_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209332000_20240327_1448-20240327_1648_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209332000_20240420_0111-20240420_0311_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209332000_20240525_1235-20240525_1435_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209332000_20240528_0541-20240528_0741_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209332000_20240528_0742-20240528_0941_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209332000_20240612_0329-20240612_0529_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209332000_20240621_1529-20240621_1729_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209336000_20240317_2004-20240317_2204_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209336000_20240321_0804-20240321_1004_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209336000_20240412_2110-20240412_2310_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209336000_20241123_0918-20241123_1118_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209341000_20240303_0701-20240303_0900_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209341000_20240525_0856-20240525_1055_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209391000_20240302_2119-20240302_2319_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209391000_20240302_2319-20240303_0119_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209391000_20240303_0119-20240303_0319_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209415000_20240410_0012-20240410_0212_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209415000_20240519_1410-20240519_1610_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209415000_20240521_1610-20240521_1810_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209415000_20240610_0813-20240610_1013_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209488000_20240520_1108-20240520_1307_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209507000_20240305_0647-20240305_0847_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209507000_20241126_1104-20241126_1304_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209525000_20240304_1122-20240304_1322_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209525000_20240408_2239-20240409_0039_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209525000_20240416_0931-20240416_1130_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209525000_20240416_1131-20240416_1330_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209525000_20240417_2039-20240417_2239_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209525000_20240423_1931-20240423_2130_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209525000_20240424_1639-20240424_1839_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209525000_20240520_0929-20240520_1129_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209525000_20240602_1218-20240602_1418_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209531000_20240310_1915-20240310_2115_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209535000_20240309_0350-20240309_0550_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209535000_20240418_1421-20240418_1621_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209535000_20240527_1235-20240527_1435_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209535000_20240607_0033-20240607_0233_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209535000_20240609_0833-20240609_1033_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209535000_20240620_2033-20240620_2233_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209535000_20240629_1633-20240629_1833_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209536000_20240318_1400-20240318_1600_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209536000_20240318_1600-20240318_1800_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209536000_20240321_0000-20240321_0159_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209536000_20240321_0200-20240321_0359_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209536000_20240404_1449-20240404_1649_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209536000_20240404_1649-20240404_1849_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209536000_20240421_0649-20240421_0849_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209536000_20240427_1049-20240427_1249_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209536000_20240525_1628-20240525_1828_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209536000_20240525_1828-20240525_2027_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209536000_20240528_0028-20240528_0228_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209536000_20240528_0228-20240528_0428_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209541000_20240314_1303-20240314_1503_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209541000_20240320_2103-20240320_2303_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209541000_20240405_1932-20240405_2132_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209541000_20240406_0932-20240406_1132_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209541000_20240408_1332-20240408_1532_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209541000_20240418_1532-20240418_1732_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209541000_20240425_1532-20240425_1732_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209541000_20240427_1732-20240427_1932_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209541000_20240626_1834-20240626_2034_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209577000_20240323_1039-20240323_1239_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209577000_20240414_0240-20240414_0440_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209583000_20240318_2315-20240319_0115_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209583000_20240319_0115-20240319_0315_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209583000_20240615_1250-20240615_1450_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209583000_20240624_0850-20240624_1050_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209583000_20240629_0050-20240629_0250_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209608000_20240413_1340-20240413_1540_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209608000_20241128_1310-20241128_1510_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209610000_20240520_0312-20240520_0511_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209621000_20241125_1312-20241125_1512_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209644000_20240423_0502-20240423_0702_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209658000_20240302_1624-20240302_1824_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209658000_20240307_0424-20240307_0624_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209658000_20240311_0224-20240311_0424_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209658000_20240618_0356-20240618_0555_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209659000_20240320_1329-20240320_1529_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209659000_20240603_2152-20240603_2352_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209662000_20240522_1755-20240522_1955_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209662000_20240522_1955-20240522_2155_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209662000_20240523_1500-20240523_1700_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209671000_20240307_0328-20240307_0528_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209671000_20240324_1528-20240324_1728_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209671000_20240401_0329-20240401_0529_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209671000_20240429_2129-20240429_2329_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209671000_20240520_0242-20240520_0442_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209671000_20240527_0042-20240527_0242_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209671000_20240604_2029-20240604_2229_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209671000_20240615_1430-20240615_1629_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209671000_20241126_1442-20241126_1642_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209672000_20240308_1827-20240308_2026_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209672000_20240310_1827-20240310_2026_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209672000_20240413_1939-20240413_2139_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209708000_20240629_1609-20240629_1809_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209708000_20241128_0318-20241128_0518_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209710000_20240428_0624-20240428_0824_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209710000_20240531_0800-20240531_1000_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209710000_20240531_1000-20240531_1200_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209715000_20240310_2141-20240310_2341_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209715000_20240310_2341-20240311_0141_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209715000_20240327_1941-20240327_2141_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209715000_20240404_0141-20240404_0341_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209715000_20240404_0341-20240404_0541_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209715000_20240404_1821-20240404_2021_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209715000_20240417_1341-20240417_1541_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209715000_20240417_1541-20240417_1741_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209715000_20240418_0821-20240418_1021_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209715000_20240526_2144-20240526_2344_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209715000_20240530_1544-20240530_1744_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209715000_20240607_0937-20240607_1137_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209715000_20240628_0002-20240628_0202_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209715000_20240628_1337-20240628_1537_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209717000_20240301_1724-20240301_1924_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209717000_20240408_0527-20240408_0727_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209717000_20240531_1307-20240531_1507_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209726000_20241122_0718-20241122_0918_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209734000_20240316_2344-20240317_0144_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209734000_20240530_1604-20240530_1804_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209734000_20240613_2131-20240613_2331_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209734000_20240613_2331-20240614_0131_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209734000_20240614_0131-20240614_0331_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209734000_20240615_0329-20240615_0529_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209850000_20240316_2222-20240317_0022_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209882000_20240412_1415-20240412_1615_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209882000_20240412_1615-20240412_1815_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209882000_20240605_0356-20240605_0555_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209882000_20240614_1956-20240614_2156_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209892000_20240303_0103-20240303_0303_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209892000_20240303_0304-20240303_0503_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209903000_20240531_0245-20240531_0445_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209903000_20240606_0557-20240606_0757_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209903000_20240611_0957-20240611_1157_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209903000_20240622_0557-20240622_0757_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209917000_20240306_0259-20240306_0459_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209917000_20240608_2244-20240609_0044_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209917000_20240613_0044-20240613_0244_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209917000_20240628_2044-20240628_2244_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209938000_20240521_1455-20240521_1655_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209938000_20240522_1134-20240522_1333_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209938000_20240522_1334-20240522_1533_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209938000_20240522_1534-20240522_1734_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209938000_20240523_1534-20240523_1733_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209938000_20240523_1734-20240523_1934_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209938000_20240524_1255-20240524_1455_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209968000_20240308_1153-20240308_1352_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209968000_20240618_0429-20240618_0629_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209982000_20240328_0857-20240328_1057_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209982000_20240328_1057-20240328_1257_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209982000_20240328_1257-20240328_1457_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209982000_20240331_0457-20240331_0657_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209982000_20240331_0657-20240331_0857_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209982000_20240620_0050-20240620_0250_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209982000_20240622_1850-20240622_2050_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209989000_20240408_2223-20240409_0023_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_209992000_20240603_2312-20240604_0112_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_210014000_20240521_2218-20240522_0018_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_210017000_20240319_1910-20240319_2110_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_210028000_20240421_1810-20240421_2010_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_210041000_20240324_2242-20240325_0042_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_210041000_20240325_0042-20240325_0242_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_210041000_20240325_0242-20240325_0442_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_210041000_20240325_0442-20240325_0642_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_210041000_20240329_0115-20240329_0315_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_210041000_20240602_1000-20240602_1200_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_210046000_20240628_1716-20240628_1916_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_210046000_20240628_1917-20240628_2116_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_210046000_20240628_2117-20240628_2316_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_210046000_20240628_2317-20240629_0116_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_210046000_20240629_0116-20240629_0316_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_210048000_20240428_2050-20240428_2250_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_210048000_20240430_1650-20240430_1850_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_210048000_20240624_0037-20240624_0237_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_210048000_20241129_2030-20241129_2229_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_210051000_20240301_1448-20240301_1648_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_210051000_20240302_2028-20240302_2228_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_210051000_20240302_2228-20240303_0028_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_210051000_20240303_0028-20240303_0228_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_210051000_20240328_0428-20240328_0628_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_210051000_20240328_0628-20240328_0828_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_210051000_20240425_1404-20240425_1604_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_210051000_20240425_1604-20240425_1804_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_210051000_20240520_1108-20240520_1308_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_210051000_20240520_1308-20240520_1508_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_210051000_20240520_1508-20240520_1708_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_210051000_20240601_1320-20240601_1520_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_210051000_20240601_1520-20240601_1720_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_210051000_20240601_1720-20240601_1920_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_210051000_20240605_1521-20240605_1720_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_210056000_20240530_2244-20240531_0044_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_210059000_20240427_0642-20240427_0842_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_210061000_20240311_1826-20240311_2026_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_210075000_20240420_1218-20240420_1418_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# Loaded file ../5_Data_Pipeline/input/underway_using_engine\filtered_210075000_20240420_1418-20240420_1618_standardized_60s.csv with shape (120, 3) as class 1 (Underway).
# ...
# Epoch 43/200
# 1041/1043 [============================>.] - ETA: 0s - loss: 0.3029 - accuracy: 0.8674Epoch 43 - loss: 0.3031, accuracy: 0.8674, val_loss: 0.3296, val_accuracy: 0.8483
#
# Epoch 43: val_loss did not improve from 0.30130
# 1043/1043 [==============================] - 23s 22ms/step - loss: 0.3031 - accuracy: 0.8674 - val_loss: 0.3296 - val_accuracy: 0.8483
# Epoch 44/200
# 1040/1043 [============================>.] - ETA: 0s - loss: 0.3070 - accuracy: 0.8675Epoch 44 - loss: 0.3072, accuracy: 0.8675, val_loss: 0.3151, val_accuracy: 0.8629
#
# Epoch 44: val_loss did not improve from 0.30130
# 1043/1043 [==============================] - 23s 22ms/step - loss: 0.3072 - accuracy: 0.8675 - val_loss: 0.3151 - val_accuracy: 0.8629
# Epoch 45/200
# 1043/1043 [==============================] - ETA: 0s - loss: 0.3064 - accuracy: 0.8675Epoch 45 - loss: 0.3064, accuracy: 0.8675, val_loss: 0.3215, val_accuracy: 0.8629
#
# Epoch 45: val_loss did not improve from 0.30130
# 1043/1043 [==============================] - 24s 23ms/step - loss: 0.3064 - accuracy: 0.8675 - val_loss: 0.3215 - val_accuracy: 0.8629
# Epoch 46/200
# 1042/1043 [============================>.] - ETA: 0s - loss: 0.3016 - accuracy: 0.8655Epoch 46 - loss: 0.3017, accuracy: 0.8655, val_loss: 0.3228, val_accuracy: 0.8600
#
# Epoch 46: val_loss did not improve from 0.30130
# 1043/1043 [==============================] - 23s 22ms/step - loss: 0.3017 - accuracy: 0.8655 - val_loss: 0.3228 - val_accuracy: 0.8600
# Epoch 47/200
# 1041/1043 [============================>.] - ETA: 0s - loss: 0.3032 - accuracy: 0.8680Epoch 47 - loss: 0.3032, accuracy: 0.8680, val_loss: 0.3152, val_accuracy: 0.8629
#
# Epoch 47: val_loss did not improve from 0.30130
# 1043/1043 [==============================] - 23s 22ms/step - loss: 0.3032 - accuracy: 0.8680 - val_loss: 0.3152 - val_accuracy: 0.8629
# Epoch 48/200
# 1042/1043 [============================>.] - ETA: 0s - loss: 0.2969 - accuracy: 0.8728Epoch 48 - loss: 0.2969, accuracy: 0.8728, val_loss: 0.3040, val_accuracy: 0.8713
#
# Epoch 48: val_loss did not improve from 0.30130
# 1043/1043 [==============================] - 23s 23ms/step - loss: 0.2969 - accuracy: 0.8728 - val_loss: 0.3040 - val_accuracy: 0.8713
# Epoch 49/200
# 1043/1043 [==============================] - ETA: 0s - loss: 0.3081 - accuracy: 0.8660Epoch 49 - loss: 0.3081, accuracy: 0.8660, val_loss: 0.3079, val_accuracy: 0.8679
#
# Epoch 49: val_loss did not improve from 0.30130
# 1043/1043 [==============================] - 23s 22ms/step - loss: 0.3081 - accuracy: 0.8660 - val_loss: 0.3079 - val_accuracy: 0.8679
# Epoch 50/200
# 1042/1043 [============================>.] - ETA: 0s - loss: 0.2983 - accuracy: 0.8693Epoch 50 - loss: 0.2982, accuracy: 0.8694, val_loss: 0.3311, val_accuracy: 0.8579
#
# Epoch 50: val_loss did not improve from 0.30130
# 1043/1043 [==============================] - 23s 22ms/step - loss: 0.2982 - accuracy: 0.8694 - val_loss: 0.3311 - val_accuracy: 0.8579
# Epoch 51/200
# 1043/1043 [==============================] - ETA: 0s - loss: 0.2985 - accuracy: 0.8693Epoch 51 - loss: 0.2985, accuracy: 0.8693, val_loss: 0.3132, val_accuracy: 0.8706
#
# Epoch 51: val_loss did not improve from 0.30130
# 1043/1043 [==============================] - 23s 22ms/step - loss: 0.2985 - accuracy: 0.8693 - val_loss: 0.3132 - val_accuracy: 0.8706
# Epoch 52/200
# 1043/1043 [==============================] - ETA: 0s - loss: 0.2944 - accuracy: 0.8732Epoch 52 - loss: 0.2944, accuracy: 0.8732, val_loss: 0.3189, val_accuracy: 0.8653
#
# Epoch 52: val_loss did not improve from 0.30130
# 1043/1043 [==============================] - 24s 23ms/step - loss: 0.2944 - accuracy: 0.8732 - val_loss: 0.3189 - val_accuracy: 0.8653
# Epoch 53/200
# 1043/1043 [==============================] - ETA: 0s - loss: 0.2995 - accuracy: 0.8683Epoch 53 - loss: 0.2995, accuracy: 0.8683, val_loss: 0.3162, val_accuracy: 0.8686
#
# Epoch 53: val_loss did not improve from 0.30130
# 1043/1043 [==============================] - 23s 22ms/step - loss: 0.2995 - accuracy: 0.8683 - val_loss: 0.3162 - val_accuracy: 0.8686
# Epoch 54/200
# 1043/1043 [==============================] - ETA: 0s - loss: 0.2969 - accuracy: 0.8710Epoch 54 - loss: 0.2969, accuracy: 0.8710, val_loss: 0.3047, val_accuracy: 0.8674
#
# Epoch 54: val_loss did not improve from 0.30130
# 1043/1043 [==============================] - 24s 23ms/step - loss: 0.2969 - accuracy: 0.8710 - val_loss: 0.3047 - val_accuracy: 0.8674
# Epoch 55/200
# 1042/1043 [============================>.] - ETA: 0s - loss: 0.2964 - accuracy: 0.8730Epoch 55 - loss: 0.2965, accuracy: 0.8729, val_loss: 0.3086, val_accuracy: 0.8643
#
# Epoch 55: val_loss did not improve from 0.30130
# 1043/1043 [==============================] - 23s 22ms/step - loss: 0.2965 - accuracy: 0.8729 - val_loss: 0.3086 - val_accuracy: 0.8643
# Epoch 56/200
# 1041/1043 [============================>.] - ETA: 0s - loss: 0.2971 - accuracy: 0.8716Epoch 56 - loss: 0.2970, accuracy: 0.8717, val_loss: 0.3018, val_accuracy: 0.8730
#
# Epoch 56: val_loss did not improve from 0.30130
# 1043/1043 [==============================] - 24s 23ms/step - loss: 0.2970 - accuracy: 0.8717 - val_loss: 0.3018 - val_accuracy: 0.8730
# Epoch 57/200
# 1041/1043 [============================>.] - ETA: 0s - loss: 0.2955 - accuracy: 0.8720Epoch 57 - loss: 0.2954, accuracy: 0.8722, val_loss: 0.2999, val_accuracy: 0.8763
#
# Epoch 57: val_loss improved from 0.30130 to 0.29985, saving model to best_model.h5
# 1043/1043 [==============================] - 23s 22ms/step - loss: 0.2954 - accuracy: 0.8722 - val_loss: 0.2999 - val_accuracy: 0.8763
# Epoch 58/200
# 1043/1043 [==============================] - ETA: 0s - loss: 0.2965 - accuracy: 0.8713Epoch 58 - loss: 0.2965, accuracy: 0.8713, val_loss: 0.3100, val_accuracy: 0.8780
#
# Epoch 58: val_loss did not improve from 0.29985
# 1043/1043 [==============================] - 23s 22ms/step - loss: 0.2965 - accuracy: 0.8713 - val_loss: 0.3100 - val_accuracy: 0.8780
# Epoch 59/200
# 1043/1043 [==============================] - ETA: 0s - loss: 0.2920 - accuracy: 0.8753Epoch 59 - loss: 0.2920, accuracy: 0.8753, val_loss: 0.3065, val_accuracy: 0.8739
#
# Epoch 59: val_loss did not improve from 0.29985
# 1043/1043 [==============================] - 23s 22ms/step - loss: 0.2920 - accuracy: 0.8753 - val_loss: 0.3065 - val_accuracy: 0.8739
# Epoch 60/200
# 1042/1043 [============================>.] - ETA: 0s - loss: 0.2955 - accuracy: 0.8705Epoch 60 - loss: 0.2955, accuracy: 0.8705, val_loss: 0.3402, val_accuracy: 0.8461
#
# Epoch 60: val_loss did not improve from 0.29985
# 1043/1043 [==============================] - 23s 22ms/step - loss: 0.2955 - accuracy: 0.8705 - val_loss: 0.3402 - val_accuracy: 0.8461
# Epoch 61/200
# 1040/1043 [============================>.] - ETA: 0s - loss: 0.2956 - accuracy: 0.8707Epoch 61 - loss: 0.2956, accuracy: 0.8707, val_loss: 0.3082, val_accuracy: 0.8727
#
# Epoch 61: val_loss did not improve from 0.29985
# 1043/1043 [==============================] - 23s 22ms/step - loss: 0.2956 - accuracy: 0.8707 - val_loss: 0.3082 - val_accuracy: 0.8727
# Epoch 62/200
# 1043/1043 [==============================] - ETA: 0s - loss: 0.2936 - accuracy: 0.8731Epoch 62 - loss: 0.2936, accuracy: 0.8731, val_loss: 0.3047, val_accuracy: 0.8710
#
# Epoch 62: val_loss did not improve from 0.29985
# 1043/1043 [==============================] - 23s 22ms/step - loss: 0.2936 - accuracy: 0.8731 - val_loss: 0.3047 - val_accuracy: 0.8710
# Epoch 63/200
# 1043/1043 [==============================] - ETA: 0s - loss: 0.2896 - accuracy: 0.8750Epoch 63 - loss: 0.2896, accuracy: 0.8750, val_loss: 0.3118, val_accuracy: 0.8696
#
# Epoch 63: val_loss did not improve from 0.29985
# 1043/1043 [==============================] - 23s 22ms/step - loss: 0.2896 - accuracy: 0.8750 - val_loss: 0.3118 - val_accuracy: 0.8696
# Epoch 64/200
# 1042/1043 [============================>.] - ETA: 0s - loss: 0.2947 - accuracy: 0.8745Epoch 64 - loss: 0.2946, accuracy: 0.8746, val_loss: 0.3033, val_accuracy: 0.8734
#
# Epoch 64: val_loss did not improve from 0.29985
# 1043/1043 [==============================] - 23s 22ms/step - loss: 0.2946 - accuracy: 0.8746 - val_loss: 0.3033 - val_accuracy: 0.8734
# Epoch 65/200
# 1042/1043 [============================>.] - ETA: 0s - loss: 0.2869 - accuracy: 0.8788Epoch 65 - loss: 0.2868, accuracy: 0.8788, val_loss: 0.3019, val_accuracy: 0.8802
#
# Epoch 65: val_loss did not improve from 0.29985
# 1043/1043 [==============================] - 24s 23ms/step - loss: 0.2868 - accuracy: 0.8788 - val_loss: 0.3019 - val_accuracy: 0.8802
# Epoch 66/200
# 1042/1043 [============================>.] - ETA: 0s - loss: 0.2910 - accuracy: 0.8739Epoch 66 - loss: 0.2910, accuracy: 0.8740, val_loss: 0.3107, val_accuracy: 0.8653
#
# Epoch 66: val_loss did not improve from 0.29985
# 1043/1043 [==============================] - 24s 23ms/step - loss: 0.2910 - accuracy: 0.8740 - val_loss: 0.3107 - val_accuracy: 0.8653
# Epoch 67/200
# 1041/1043 [============================>.] - ETA: 0s - loss: 0.2909 - accuracy: 0.8733Epoch 67 - loss: 0.2910, accuracy: 0.8732, val_loss: 0.3045, val_accuracy: 0.8730
#
# Epoch 67: val_loss did not improve from 0.29985
# 1043/1043 [==============================] - 23s 22ms/step - loss: 0.2910 - accuracy: 0.8732 - val_loss: 0.3045 - val_accuracy: 0.8730
# Epoch 68/200
# 1042/1043 [============================>.] - ETA: 0s - loss: 0.2919 - accuracy: 0.8724Epoch 68 - loss: 0.2920, accuracy: 0.8723, val_loss: 0.3117, val_accuracy: 0.8730
#
# Epoch 68: val_loss did not improve from 0.29985
# 1043/1043 [==============================] - 23s 22ms/step - loss: 0.2920 - accuracy: 0.8723 - val_loss: 0.3117 - val_accuracy: 0.8730
# Epoch 69/200
# 1041/1043 [============================>.] - ETA: 0s - loss: 0.2915 - accuracy: 0.8733Epoch 69 - loss: 0.2913, accuracy: 0.8733, val_loss: 0.3115, val_accuracy: 0.8639
#
# Epoch 69: val_loss did not improve from 0.29985
# 1043/1043 [==============================] - 23s 22ms/step - loss: 0.2913 - accuracy: 0.8733 - val_loss: 0.3115 - val_accuracy: 0.8639
# Epoch 70/200
# 1040/1043 [============================>.] - ETA: 0s - loss: 0.2871 - accuracy: 0.8775Epoch 70 - loss: 0.2872, accuracy: 0.8774, val_loss: 0.3299, val_accuracy: 0.8603
#
# Epoch 70: val_loss did not improve from 0.29985
# 1043/1043 [==============================] - 23s 22ms/step - loss: 0.2872 - accuracy: 0.8774 - val_loss: 0.3299 - val_accuracy: 0.8603
# Epoch 71/200
# 1042/1043 [============================>.] - ETA: 0s - loss: 0.2949 - accuracy: 0.8730Epoch 71 - loss: 0.2949, accuracy: 0.8729, val_loss: 0.3109, val_accuracy: 0.8660
#
# Epoch 71: val_loss did not improve from 0.29985
# 1043/1043 [==============================] - 23s 22ms/step - loss: 0.2949 - accuracy: 0.8729 - val_loss: 0.3109 - val_accuracy: 0.8660
# Epoch 72/200
# 1041/1043 [============================>.] - ETA: 0s - loss: 0.2886 - accuracy: 0.8753Epoch 72 - loss: 0.2884, accuracy: 0.8753, val_loss: 0.3074, val_accuracy: 0.8737
#
# Epoch 72: val_loss did not improve from 0.29985
# 1043/1043 [==============================] - 23s 22ms/step - loss: 0.2884 - accuracy: 0.8753 - val_loss: 0.3074 - val_accuracy: 0.8737
# Epoch 73/200
# 1041/1043 [============================>.] - ETA: 0s - loss: 0.2900 - accuracy: 0.8747Epoch 73 - loss: 0.2899, accuracy: 0.8747, val_loss: 0.3146, val_accuracy: 0.8655
#
# Epoch 73: val_loss did not improve from 0.29985
# 1043/1043 [==============================] - 23s 22ms/step - loss: 0.2899 - accuracy: 0.8747 - val_loss: 0.3146 - val_accuracy: 0.8655
# Epoch 74/200
# 1043/1043 [==============================] - ETA: 0s - loss: 0.2901 - accuracy: 0.8746Epoch 74 - loss: 0.2901, accuracy: 0.8746, val_loss: 0.3084, val_accuracy: 0.8684
#
# Epoch 74: val_loss did not improve from 0.29985
# 1043/1043 [==============================] - 23s 22ms/step - loss: 0.2901 - accuracy: 0.8746 - val_loss: 0.3084 - val_accuracy: 0.8684
# Epoch 75/200
# 1041/1043 [============================>.] - ETA: 0s - loss: 0.2871 - accuracy: 0.8766Epoch 75 - loss: 0.2872, accuracy: 0.8765, val_loss: 0.3024, val_accuracy: 0.8725
#
# Epoch 75: val_loss did not improve from 0.29985
# 1043/1043 [==============================] - 23s 22ms/step - loss: 0.2872 - accuracy: 0.8765 - val_loss: 0.3024 - val_accuracy: 0.8725
# Epoch 76/200
# 1040/1043 [============================>.] - ETA: 0s - loss: 0.2881 - accuracy: 0.8763Epoch 76 - loss: 0.2881, accuracy: 0.8764, val_loss: 0.3127, val_accuracy: 0.8749
#
# Epoch 76: val_loss did not improve from 0.29985
# 1043/1043 [==============================] - 23s 22ms/step - loss: 0.2881 - accuracy: 0.8764 - val_loss: 0.3127 - val_accuracy: 0.8749
# Epoch 77/200
# 1042/1043 [============================>.] - ETA: 0s - loss: 0.2882 - accuracy: 0.8755Epoch 77 - loss: 0.2883, accuracy: 0.8754, val_loss: 0.3143, val_accuracy: 0.8651
#
# Epoch 77: val_loss did not improve from 0.29985
# 1043/1043 [==============================] - 23s 22ms/step - loss: 0.2883 - accuracy: 0.8754 - val_loss: 0.3143 - val_accuracy: 0.8651
# Epoch 78/200
# 1043/1043 [==============================] - ETA: 0s - loss: 0.2867 - accuracy: 0.8766Epoch 78 - loss: 0.2867, accuracy: 0.8766, val_loss: 0.3116, val_accuracy: 0.8713
#
# Epoch 78: val_loss did not improve from 0.29985
# 1043/1043 [==============================] - 23s 22ms/step - loss: 0.2867 - accuracy: 0.8766 - val_loss: 0.3116 - val_accuracy: 0.8713
# Epoch 79/200
# 1043/1043 [==============================] - ETA: 0s - loss: 0.2857 - accuracy: 0.8749Epoch 79 - loss: 0.2857, accuracy: 0.8749, val_loss: 0.3270, val_accuracy: 0.8545
#
# Epoch 79: val_loss did not improve from 0.29985
# 1043/1043 [==============================] - 23s 22ms/step - loss: 0.2857 - accuracy: 0.8749 - val_loss: 0.3270 - val_accuracy: 0.8545
# Epoch 80/200
# 1042/1043 [============================>.] - ETA: 0s - loss: 0.2885 - accuracy: 0.8719Epoch 80 - loss: 0.2884, accuracy: 0.8720, val_loss: 0.3178, val_accuracy: 0.8641
#
# Epoch 80: val_loss did not improve from 0.29985
# 1043/1043 [==============================] - 23s 22ms/step - loss: 0.2884 - accuracy: 0.8720 - val_loss: 0.3178 - val_accuracy: 0.8641
# Epoch 81/200
# 1041/1043 [============================>.] - ETA: 0s - loss: 0.2916 - accuracy: 0.8710Epoch 81 - loss: 0.2917, accuracy: 0.8711, val_loss: 0.3105, val_accuracy: 0.8737
#
# Epoch 81: val_loss did not improve from 0.29985
# 1043/1043 [==============================] - 23s 22ms/step - loss: 0.2917 - accuracy: 0.8711 - val_loss: 0.3105 - val_accuracy: 0.8737
# Epoch 82/200
# 1042/1043 [============================>.] - ETA: 0s - loss: 0.2876 - accuracy: 0.8757Epoch 82 - loss: 0.2876, accuracy: 0.8757, val_loss: 0.3127, val_accuracy: 0.8703
#
# Epoch 82: val_loss did not improve from 0.29985
# 1043/1043 [==============================] - 23s 23ms/step - loss: 0.2876 - accuracy: 0.8757 - val_loss: 0.3127 - val_accuracy: 0.8703
# Epoch 83/200
# 1043/1043 [==============================] - ETA: 0s - loss: 0.2847 - accuracy: 0.8761Epoch 83 - loss: 0.2847, accuracy: 0.8761, val_loss: 0.3130, val_accuracy: 0.8648
#
# Epoch 83: val_loss did not improve from 0.29985
# 1043/1043 [==============================] - 23s 22ms/step - loss: 0.2847 - accuracy: 0.8761 - val_loss: 0.3130 - val_accuracy: 0.8648
# Epoch 84/200
# 1043/1043 [==============================] - ETA: 0s - loss: 0.2865 - accuracy: 0.8742Epoch 84 - loss: 0.2865, accuracy: 0.8742, val_loss: 0.3155, val_accuracy: 0.8653
#
# Epoch 84: val_loss did not improve from 0.29985
# 1043/1043 [==============================] - 23s 22ms/step - loss: 0.2865 - accuracy: 0.8742 - val_loss: 0.3155 - val_accuracy: 0.8653
# Epoch 85/200
# 1042/1043 [============================>.] - ETA: 0s - loss: 0.2819 - accuracy: 0.8797Epoch 85 - loss: 0.2822, accuracy: 0.8796, val_loss: 0.3109, val_accuracy: 0.8696
#
# Epoch 85: val_loss did not improve from 0.29985
# 1043/1043 [==============================] - 23s 22ms/step - loss: 0.2822 - accuracy: 0.8796 - val_loss: 0.3109 - val_accuracy: 0.8696
# Epoch 85: early stopping
# Training complete.
# 131/131 [==============================] - 2s 11ms/step - loss: 0.3109 - accuracy: 0.8696
# Test Loss: 0.3109, Test Accuracy: 0.8696

# %%
# Save the model
model.save("navigational_status_classifier.h5")

# %% [markdown]
# # Explanation
#
# ### 1. **Loading CSV Files from the Folder:**
#    - The function loops through the CSV files in the given folder, one by one. It reads each CSV file using `pandas.read_csv()` and processes the data.
#    - These CSV files contain the vessel's movement data with columns like `SOG`, `COG`, and `Heading`.
#
#    **Example of data loaded from a CSV file:**
#
#    | Timestamp | SOG | COG  | Heading |
#    |-----------|-----|------|---------|
#    | 00:00     | 5.4 | 45   | 60      |
#    | 00:01     | 5.6 | 47   | 61      |
#    | 00:02     | 5.7 | 50   | 62      |
#    | ...       | ... | ...  | ...     |
#
#    Here, **SOG** is the speed of the vessel, **COG** is the course (direction), and **Heading** is the heading angle.
#
# ### 2. **Normalization of `SOG` (Speed Over Ground):**
#    - The `SOG` column is normalized using a `MinMaxScaler`, which scales all values to a range between 0 and 1.
#    - **Normalization** is important because it brings different feature scales (e.g., speed vs. angle) to a similar range, making the training process more efficient.
#
#    **Before normalization:**
#
#    | Timestamp | SOG | COG  | Heading |
#    |-----------|-----|------|---------|
#    | 00:00     | 5.4 | 45   | 60      |
#    | 00:01     | 5.6 | 47   | 61      |
#
#    **After normalization:**
#
#    The new values for `SOG` are calculated using:
#    \[
#    \text{Normalized SOG} = \frac{\text{SOG} - \text{min(SOG)}}{\text{max(SOG)} - \text{min(SOG)}}
#    \]
#
#    | Timestamp | Normalized SOG | COG  | Heading |
#    |-----------|----------------|------|---------|
#    | 00:00     | 0.00           | 45   | 60      |
#    | 00:01     | 0.33           | 47   | 61      |
#
# ### 3. **Cyclic Encoding of `COG` and `Heading`:**
#    - Both `COG` (Course Over Ground) and `Heading` are angular values, and as such, they have a **cyclic nature**: 0 degrees is the same as 360 degrees.
#    - To properly handle this, **sine** and **cosine** transformations are applied:
#      \[
#      \text{COG}_x = \sin(\text{COG})
#      \]
#      \[
#      \text{COG}_y = \cos(\text{COG})
#      \]
#      Similarly for `Heading`:
#      \[
#      \text{Heading}_x = \sin(\text{Heading})
#      \]
#      \[
#      \text{Heading}_y = \cos(\text{Heading})
#      \]
#    - These transformations convert the angular values into two components that are easier for the model to learn from and capture cyclic relationships.
#
#    **Example before and after cyclic encoding:**
#
#    - **Before** (COG = 350 degrees, Heading = 10 degrees):
#
#    | Timestamp | COG | Heading |
#    |-----------|-----|---------|
#    | 00:00     | 350 | 10      |
#
#    - **After** (Apply sine and cosine transformations):
#
#    | Timestamp | COG_x      | COG_y      | Heading_x  | Heading_y  |
#    |-----------|------------|------------|------------|------------|
#    | 00:00     | 0.1745     | 0.9848     | 0.1736     | 0.9848     |
#
# ### 4. **Selecting Relevant Features:**
#    - After encoding the `COG` and `Heading`, the relevant features are selected: `SOG`, `COG_x`, `COG_y`, `Heading_x`, and `Heading_y`.
#    - These features represent the vessel's speed and directional information in a form that the LSTM model can process.
#
#    **Features selected for each time step:**
#
#    | Timestamp | Normalized SOG | COG_x      | COG_y      | Heading_x  | Heading_y  |
#    |-----------|----------------|------------|------------|------------|------------|
#    | 00:00     | 0.00           | 0.1745     | 0.9848     | 0.1736     | 0.9848     |
#
# ### 5. **Creating Sequences:**
#    - The LSTM model requires input data in the form of sequences (i.e., multiple time steps). Here, a sliding window approach is used to create sequences of `sequence_length` (e.g., 60 time steps).
#    - For each sequence of 60 time steps, the features for those 60 steps are stacked into a 3D array (time steps, features per time step, and the number of sequences).
#    - This helps the model learn patterns over time (e.g., how the vessel's behavior changes over an hour).
#
#    **Example of sequences:**
#
#    For a sequence length of 3, if the first 3 time steps look like this:
#
#    | Timestamp | Normalized SOG | COG_x      | COG_y      | Heading_x  | Heading_y  |
#    |-----------|----------------|------------|------------|------------|------------|
#    | 00:00     | 0.00           | 0.1745     | 0.9848     | 0.1736     | 0.9848     |
#    | 00:01     | 0.33           | 0.1736     | 0.9848     | 0.1732     | 0.9849     |
#    | 00:02     | 0.50           | 0.1727     | 0.9850     | 0.1725     | 0.9850     |
#
#    The model will receive a sequence of these 3 time steps as input for training.
#
# ### 6. **Labeling the Sequences:**
#    - Each sequence is labeled with a binary value, depending on the activity of the vessel:
#      - **0** for "underway using engine".
#      - **1** for "engaged in fishing".
#    - This label helps the model learn the relationship between the features and the vessel's activity.
#
# ### 7. **Loading and Combining Data:**
#    - The function `load_and_preprocess_data` is called twice, once for the "underway" data and once for the "fishing" data.
#    - After processing, the resulting feature arrays (`data_underway` and `data_fishing`) are concatenated together to form the complete dataset `X`, and their corresponding labels (`labels_underway` and `labels_fishing`) are concatenated to form the labels array `y`.
#
# ### Final Data Structure:
#    After combining the data, you end up with:
#
#    - **X**: A 3D array where each element represents a sequence of features (e.g., 60 time steps × 5 features per step = 300 features per sequence).
#
#    - **y**: A 1D array with binary labels (0 or 1) indicating the vessel activity for each sequence.
#
# ---
#
# ### **Visualization of Sequences:**
#
# Here’s how the sequences would look when plotted for `SOG`, `COG_x`, and `Heading_x` for a few time steps:
#
# #### Example:
#
# - **Sequence Data (3 time steps):**
#
#   - `SOG`: [0.00, 0.33, 0.50]
#   - `COG_x`: [0.1745, 0.1736, 0.1727]
#   - `Heading_x`: [0.1736, 0.1732, 0.1725]

# %%
# Example sequences, like explained above.

import matplotlib.pyplot as plt

time_steps = [0, 1, 2]
SOG = [0.00, 0.33, 0.50]
COG_x = [0.1745, 0.1736, 0.1727]
Heading_x = [0.1736, 0.1732, 0.1725]

plt.figure(figsize=(12, 4))

plt.subplot(1, 3, 1)
plt.plot(time_steps, SOG, label="SOG", color="blue")
plt.title("SOG over Time")
plt.xlabel("Time Steps")
plt.ylabel("Normalized SOG")

plt.subplot(1, 3, 2)
plt.plot(time_steps, COG_x, label="COG_x", color="green")
plt.title("COG_x over Time")
plt.xlabel("Time Steps")
plt.ylabel("COG_x")

plt.subplot(1, 3, 3)
plt.plot(time_steps, Heading_x, label="Heading_x", color="red")
plt.title("Heading_x over Time")
plt.xlabel("Time Steps")
plt.ylabel("Heading_x")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Sliding Window in Sequence Creation
#
# In the current model setup, the **sliding window** approach is used to create sequences of a fixed length. This means that the **length of each sequence is constant** throughout the model's training process.
#
# ### What is the Sliding Window Approach?
#
# The sliding window technique extracts **overlapping sequences** from the raw time series data. The key idea is that the **window size** (i.e., the number of time steps per sequence) remains constant, and the window "slides" over the data to generate sequences.
#
# ### Key Points:
# 1. **Fixed Sequence Length**:
#    - The length of each sequence remains **constant**. In this case, the sequence length is defined by the `sequence_length` parameter (e.g., 60 time steps).
#    - This means every sequence the model receives has exactly the same number of time steps, no matter where the window starts.
#
# 2. **Sliding Window**:
#    - As the window moves across the dataset, each new sequence will **overlap** with the previous one by all but one time step.
#    - The window shifts one time step at a time, ensuring that each sequence captures information over a fixed duration.
#
# ### Example:
# Let’s assume we have raw data sampled every minute, and we set `sequence_length = 60`, meaning each sequence will consist of 60 time steps. If the raw data is as follows:
#
# | Timestamp | SOG | COG | Heading |
# |-----------|-----|-----|---------|
# | 00:00     | 5.4 | 45  | 60      |
# | 00:01     | 5.6 | 47  | 61      |
# | ...       | ... | ... | ...     |
# | 00:59     | 5.7 | 50  | 62      |
# | 01:00     | 5.8 | 52  | 63      |
#
# Then the sliding window works as follows:
# - **First sequence**: Consists of data from `00:00` to `00:59` (60 time steps).
# - **Second sequence**: Starts at `00:01` and goes to `01:00` (another 60 time steps).
# - **Third sequence**: Starts at `00:02` and goes to `01:01` (another 60 time steps), and so on.
#
# ### Sequence Structure:
# For each sequence, the LSTM model will receive a 3D array with:
# - **Time Steps (e.g., 60)**: The number of time steps per sequence.
# - **Features per Time Step (e.g., 5)**: The number of features recorded for each time step (like `SOG`, `COG_x`, `Heading_x`).
# - **Number of Sequences**: The number of sequences generated from the raw data.
#
# In this case, each sequence consists of **60 time steps**, and the sequence length does not vary.
#
# ### Why Use Sliding Window?
# - **Consistent Length**: Having sequences of a constant length helps the model learn consistent patterns across time.
# - **Temporal Dependencies**: The sliding window captures how the data evolves over time by looking at overlapping segments.
# - **Efficient Training**: The technique allows the model to train on overlapping portions of the data, making better use of available data.
